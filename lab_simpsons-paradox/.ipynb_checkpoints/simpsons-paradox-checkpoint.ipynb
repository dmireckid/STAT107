# %% [markdown]
# # lab_simpsons-paradox
#
# Hi Data Scientists,
#
# Welcome to the third lab!  In this lab, you will explore using pandas to explore real-word datasets and find if Simpson's Paradox appears in several different datasets.
#
#
# ### Labs are Collaborative
#
# In your lab section (right now!), find a person or two around you and form a group.  Work on this together, making sure all of you understand each component of the lab.
#
#
# ### Getting Help
#
# Remember, there are a lot of ways to get help if you find yourself stuck:
#
# 1. In lab section, your TA, CAs, and your peers are here for you!
#
#
# 2. On the course Piazza page: https://piazza.com/illinois/fall2019/stat107
#
#
# 3. Office Hours:
#
#   - Open office hours **every Monday, Wednesday, Thursday, and Friday** from 4:00pm - 6:30pm in 23 Illini Hall
#
#   - Prof. Wade + Prof. Karle are available every Wednesday from 8:30am - 10:00am in 2215 Siebel Center

# %% [markdown]
# # Puzzle 1: Homecoming Date Night
#
# Imagine you and your partner are trying to find the perfect restaurant for a homecoming date night dinner!  Knowing this process can lead to hours of arguments, you seek out the answer to all of life’s questions: *online reviews*.
#
# The dataset `Black Dog Reviews.csv` (already provided for you as part of the lab code you checked out from git) contains data showing all of the males and females that have reviewed Black Dog in the past year and whether or not they recommended it.  The dataset `Papa Dels Reviews.csv` contains the same information for Papa Dels.
#
#
# ## 1.1: Data Cleaning
#
# Unfortunately, this data was not as tidy as all of our data has been so far. :(
#
# - Open `Black Dog Reviews.csv` and `Papa Dels Reviews.csv` CSV file using any program that can edit spreadsheets.  This can be Microsoft Excel (if you have it installed) or you can upload it to Google Drive and edit it with Google Sheets.
# - Modify the file to ensure all rows that in the `Gender` column has the same value for the two gender categories (as `Male` and `Female`) found in this dataset.
# - Finally, make sure to save the file as a CSV so you can used your cleaned dataset for this lab.
#
#
# ## 1.2. Loading Your DataSet
#
# Load the DataSets you just cleaned into Python:

# %%
# Import the pandas library as pd
import pandas as pd

# %%
df_black_dog = pd.read_csv("Black Dog Reviews.csv")
df_black_dog
# Out:
#     Gender Recommend Black Dog  Unnamed: 2  Unnamed: 3  Unnamed: 4  \
# 0     Male                 Yes         NaN         NaN         NaN
# 1     Male                 Yes         NaN         NaN         NaN
# 2     Male                 Yes         NaN         NaN         NaN
# 3     Male                 Yes         NaN         NaN         NaN
# 4     Male                 Yes         NaN         NaN         NaN
# 5     Male                  No         NaN         NaN         NaN
# 6     Male                  No         NaN         NaN         NaN
# 7     Male                  No         NaN         NaN         NaN
# 8     Male                  No         NaN         NaN         NaN
# 9     Male                  No         NaN         NaN         NaN
# 10    Male                  No         NaN         NaN         NaN
# 11    Male                  No         NaN         NaN         NaN
# 12    Male                  No         NaN         NaN         NaN
# 13    Male                  No         NaN         NaN         NaN
# 14    Male                  No         NaN         NaN         NaN
# 15  Female                 Yes         NaN         NaN         NaN
# 16  Female                 Yes         NaN         NaN         NaN
# 17  Female                 Yes         NaN         NaN         NaN
# 18  Female                 Yes         NaN         NaN         NaN
# 19  Female                 Yes         NaN         NaN         NaN
# 20  Female                 Yes         NaN         NaN         NaN
# 21  Female                 Yes         NaN         NaN         NaN
# 22  Female                 Yes         NaN         NaN         NaN
# 23  Female                 Yes         NaN         NaN         NaN
# 24  Female                 Yes         NaN         NaN         NaN
# 25  Female                 Yes         NaN         NaN         NaN
# 26  Female                 Yes         NaN         NaN         NaN
# 27  Female                 Yes         NaN         NaN         NaN
# 28  Female                 Yes         NaN         NaN         NaN
# 29  Female                 Yes         NaN         NaN         NaN
# 30  Female                 Yes         NaN         NaN         NaN
# 31  Female                 Yes         NaN         NaN         NaN
# 32  Female                 Yes         NaN         NaN         NaN
# 33  Female                 Yes         NaN         NaN         NaN
# 34  Female                 Yes         NaN         NaN         NaN
# 35  Female                  No         NaN         NaN         NaN
# 36  Female                  No         NaN         NaN         NaN
# 37  Female                  No         NaN         NaN         NaN
# 38  Female                  No         NaN         NaN         NaN
# 39  Female                  No         NaN         NaN         NaN
#
#     Unnamed: 5  Unnamed: 6  Unnamed: 7
# 0          NaN         NaN         NaN
# 1          NaN         NaN         NaN
# 2          NaN         NaN         NaN
# 3          NaN         NaN         NaN
# 4          NaN         NaN         NaN
# 5          NaN         NaN         NaN
# 6          NaN         NaN         NaN
# 7          NaN         NaN         NaN
# 8          NaN         NaN         NaN
# 9          NaN         NaN         NaN
# 10         NaN         NaN         NaN
# 11         NaN         NaN         NaN
# 12         NaN         NaN         NaN
# 13         NaN         NaN         NaN
# 14         NaN         NaN         NaN
# 15         NaN         NaN         NaN
# 16         NaN         NaN         NaN
# 17         NaN         NaN         NaN
# 18         NaN         NaN         NaN
# 19         NaN         NaN         NaN
# 20         NaN         NaN         NaN
# 21         NaN         NaN         NaN
# 22         NaN         NaN         NaN
# 23         NaN         NaN         NaN
# 24         NaN         NaN         NaN
# 25         NaN         NaN         NaN
# 26         NaN         NaN         NaN
# 27         NaN         NaN         NaN
# 28         NaN         NaN         NaN
# 29         NaN         NaN         NaN
# 30         NaN         NaN         NaN
# 31         NaN         NaN         NaN
# 32         NaN         NaN         NaN
# 33         NaN         NaN         NaN
# 34         NaN         NaN         NaN
# 35         NaN         NaN         NaN
# 36         NaN         NaN         NaN
# 37         NaN         NaN         NaN
# 38         NaN         NaN         NaN
# 39         NaN         NaN         NaN

# %%
## == TEST CASES for Puzzle 1.2 ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any error our output, you PASSED all test cases!
# - If this cell results in any errors, check you previous cell, make changes, and RE-RUN your code and then this cell.

assert(len(df_black_dog) == 40), "The dataframe does not appear to have correct dataset loaded"

# %%
df_papa_del = pd.read_csv("Papa Dels Reviews.csv")
df_papa_del
# Out:
#     Gender Recommend Papa Dels
# 0     Male                 Yes
# 1     Male                 Yes
# 2     Male                 Yes
# 3     Male                 Yes
# 4     Male                 Yes
# 5     Male                 Yes
# 6     Male                 Yes
# 7     Male                 Yes
# 8     Male                 Yes
# 9     Male                 Yes
# 10    Male                 Yes
# 11    Male                 Yes
# 12    Male                 Yes
# 13    Male                 Yes
# 14    Male                 Yes
# 15    Male                 Yes
# 16    Male                 Yes
# 17    Male                 Yes
# 18    Male                  No
# 19    Male                  No
# 20    Male                  No
# 21    Male                  No
# 22    Male                  No
# 23    Male                  No
# 24    Male                  No
# 25    Male                  No
# 26    Male                  No
# 27    Male                  No
# 28    Male                  No
# 29    Male                  No
# 30    Male                  No
# 31    Male                  No
# 32    Male                  No
# 33    Male                  No
# 34    Male                  No
# 35    Male                  No
# 36  Female                 Yes
# 37  Female                 Yes
# 38  Female                 Yes
# 39  Female                 Yes
# 40  Female                 Yes
# 41  Female                 Yes
# 42  Female                 Yes
# 43  Female                 Yes
# 44  Female                 Yes
# 45  Female                  No

# %%
## == TEST CASES for Puzzle 1.2 ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any error our output, you PASSED all test cases!
# - If this cell results in any errors, check you previous cell, make changes, and RE-RUN your code and then this cell.

assert(len(df_papa_del) == 46), "The dataframe does not appear to have correct dataset loaded"

# %% [markdown]
# ## 1.3. Analysis
#
# We want to use the Black Dog dataset to calculate the percentage of women who recommended Black Dog.  Then calculate the percentage of men who recommended Black Dog:

# %%
black_dog_female = df_black_dog[(df_black_dog["Gender"]=="Female") & (df_black_dog["Recommend Black Dog"]=="Yes")]
black_dog_f = df_black_dog[df_black_dog["Gender"]=="Female"]
black_dog_female_percent = len(black_dog_female) / len(black_dog_f)

black_dog_female_percent
# Out:
# 0.8

# %%
## == TEST CASES for Puzzle 1.3 ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any error our output, you PASSED all test cases!
# - If this cell results in any errors, check you previous cell, make changes, and RE-RUN your code and then this cell.

assert(black_dog_female_percent == 0.8), "The percentage of Female who recommended Black Dog does not appear to have correct calculated"

# %%
black_dog_male = df_black_dog[(df_black_dog["Gender"]=="Male") & (df_black_dog["Recommend Black Dog"]=="Yes")]
black_dog_m = df_black_dog[df_black_dog["Gender"]=="Male"]
black_dog_male_percent = len(black_dog_male) / len(black_dog_m)

black_dog_male_percent
# Out:
# 0.3333333333333333

# %%
## == TEST CASES for Puzzle 1.3 ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any error our output, you PASSED all test cases!
# - If this cell results in any errors, check you previous cell, make changes, and RE-RUN your code and then this cell.

assert(black_dog_male_percent == (1/3)), "The percentage of Male who recommended Black Dog does not appear to have correct calculated"

# %% [markdown]
# Similarly, use the Papa Dels dataset to calculate the percentage of women who recommended Papa Dels.  Then calculate the percentage of men who recommended Papa Dels:

# %%
papa_dels_female = df_papa_del[(df_papa_del["Gender"]=="Female") & (df_papa_del["Recommend Papa Dels"]=="Yes")]
papa_dels_f = df_papa_del[df_papa_del["Gender"]=="Female"]
papa_dels_female_percent = len(papa_dels_female) / len(papa_dels_f)



papa_dels_female_percent
# Out:
# 0.9

# %%
## == TEST CASES for Puzzle 1.3 ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any error our output, you PASSED all test cases!
# - If this cell results in any errors, check you previous cell, make changes, and RE-RUN your code and then this cell.

assert(papa_dels_female_percent == 0.9), "The percentage of Female who recommended Papa Dels does not appear to have correctly calculated"

# %%
papa_dels_male = df_papa_del[(df_papa_del["Gender"]=="Male") & (df_papa_del["Recommend Papa Dels"]=="Yes")]
papa_dels_m = df_papa_del[df_papa_del["Gender"]=="Male"]
papa_dels_male_percent = len(papa_dels_male) / len(papa_dels_m)
papa_dels_male_percent
# Out:
# 0.5

# %%
## == TEST CASES for Puzzle 1.3 ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any error our output, you PASSED all test cases!
# - If this cell results in any errors, check you previous cell, make changes, and RE-RUN your code and then this cell.

assert(papa_dels_male_percent == 0.5), "The percentage of Male who recommended Papa Dels does not appear to have correct calculated"

# %% [markdown]
# ### Observe the Results
#
# Run the following cell to format all of your answers as a DataFrame:

# %%
pd.DataFrame( [
    {'Female': black_dog_female_percent, 'Male': black_dog_male_percent },
    {'Female': papa_dels_female_percent, 'Male': papa_dels_male_percent },    
], index=['Black Dog', 'Papa Dels'])
# Out:
#            Female      Male
# Black Dog     0.8  0.333333
# Papa Dels     0.9  0.500000

# %% [markdown]
# ❓ **Question** ❓: Should your homecoming date night be at Black Dog or Papa Dels?
#
# - Does "Black Dog" (Row #1) have higher values or "Papa Dels" (Row #2) have higher values?
#
#     - Papa Dels (Row #2) has higher values

# %% [markdown]
# ## 1.4. Analysis - Part 2
#
# For our final analysis, let's examine the **overall** percentage of people who recommend each restaurant:

# %%
black_dog_recommended = df_black_dog[df_black_dog["Recommend Black Dog"] == "Yes"]

black_dog_recommended_percent = len(black_dog_recommended) / len(df_black_dog)
black_dog_recommended_percent
# Out:
# 0.625

# %%
## == TEST CASES for Puzzle 1.4 ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any error our output, you PASSED all test cases!
# - If this cell results in any errors, check you previous cell, make changes, and RE-RUN your code and then this cell.

assert(black_dog_recommended_percent == 0.625), "The percentage of Overall who recommended Black Dog does not appear to have correct calculated"

# %%
papa_dels_recommended = df_papa_del[df_papa_del["Recommend Papa Dels"]=="Yes"]
papa_dels_recommended_percent = len(papa_dels_recommended) / len(df_papa_del)
papa_dels_recommended_percent
# Out:
# 0.5869565217391305

# %%
## == TEST CASES for Puzzle 1.4 ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any error our output, you PASSED all test cases!
# - If this cell results in any errors, check you previous cell, make changes, and RE-RUN your code and then this cell.

assert(papa_dels_recommended_percent == (27/46)), "The percentage of Overall who recommended Papa Dels does not appear to have correct calculated"

# %% [markdown]
# ### Observe the Results
#
# Run the following cell to format all of your answers as a DataFrame:

# %%
pd.DataFrame( [
    {'Female': black_dog_female_percent, 'Male': black_dog_male_percent, 'Overall': black_dog_recommended_percent },
    {'Female': papa_dels_female_percent, 'Male': papa_dels_male_percent, 'Overall': papa_dels_recommended_percent },
], index=['Black Dog', 'Papa Dels'] )
# Out:
#            Female      Male   Overall
# Black Dog     0.8  0.333333  0.625000
# Papa Dels     0.9  0.500000  0.586957

# %% [markdown]
# ❓ **Question** ❓: Should your homecoming date night be at Black Dog or Papa Dels?
#
# - Does "Black Dog" (Row #1) have higher values or "Papa Dels" (Row #2) have higher values for **Overall**?
#     - Black Dog (Row #1) has higher values in the Overall column

# %% [markdown]
# # Puzzle 2: Twitch and Shoes

# %% [markdown]
# From the "Hello" dataset we created on the first day of class, we picked two random questions for us to explore:
#
# - Do you view video on Twitch at least once a week?
# - How many pairs of shoes do you have?

# %% [markdown]
# ## 2.1: Load the Dataset
#
# - You can find the "Hello" dataset here (make sure to log in with your @illinois.edu address to access it): https://docs.google.com/spreadsheets/d/1LB4E89GoVi5yezEfHhopbI5BMxodSG7VvoznkaAkMAQ/edit#gid=0

# %%
# Read the hello dataset into a DataFrame
df_hello = pd.read_csv("hello.csv")
df_hello
# Out:
#            Name                                              Major  \
# 0          Wade                                   Computer Science
# 1         Karle                                         Statistics
# 2          noor                          global studies/statistics
# 3      Jonathan                                  Political Science
# 4         Clare                                         Statistics
# 5         Dhruv                                   Computer science
# 6          Alex                                            Physics
# 7         Margo                                          Chemistry
# 8       Natalia                                         Psychology
# 9    Edward/Edd                        CS, business data analysis?
# 10        Taige                                          Math + CS
# 11         Sara                                        Advertising
# 12         Zayd                                      Communication
# 13         Andy                                         Statistics
# 14         Gail                                        Art History
# 15        Jinda                                   Computer Science
# 16      Natasha                    Computer Science and Philosophy
# 17        Yijie                       Computer Science+Mathematics
# 18       steven                                       data science
# 19      Safwaan                                          Economics
# 20         Matt                                               Math
# 21        Colin                                  Actuarial Science
# 22         Katy                                         Statistics
# 23        Yosup                     Computer Science + Mathematics
# 24       Andrew                     Computer Science and Economics
# 25     Caroline                                            Finance
# 26         Eric                                       Not sure yet
# 27         Mike                                         Statistics
# 28        Chloe                             Structural Engineering
# 29       Eugene                      Statistics + Computer Science
# ..          ...                                                ...
# 136       Vivek                                   CS + Linguistics
# 137       Irene                                         Statistics
# 138   Sanskruti                                        CS and Math
# 139     Jiaming                                            Math+CS
# 140     Makayla                           Media and Cinema Studies
# 141        Andi  Computer Science + Statistics or Statistics ma...
# 142       Jason                                            History
# 143      Austin                   Computer Science and Linguistics
# 144       Colin            Econometrics and Quantitative Economics
# 145      Connor                                        Advertising
# 146        Kate                                   Computer Science
# 147        Nick                                       Econometrics
# 148        Matt                               Information Sciences
# 149       Dylan                                       Anthropology
# 150       Brian                                  Political Science
# 151         Jun                                              maths
# 152     Jessica                                         Statistics
# 153          LJ                                                NaN
# 154       David                               Information Sciences
# 155      Serena                                               Math
# 156       Sofia                                  Political Science
# 157       Donny                               Information Sciences
# 158         Ash                     Consumer Economics and Finance
# 159      Julisa                                        Mathematics
# 160        Nate                                         Statistics
# 161   Stephanie                                  Political Science
# 162       Cindy                             biomedical engineering
# 163       Talal                               Information sciences
# 164        John                             Statistics or Business
# 165      Anisha                                                Mcb
#
#     School Year     Type                 Computer  Straw Holes  Has Dogs  \
# 0         Other  Android   Windows-based computer          2.0         0
# 1         Other   iPhone  Mac OS X-based computer          1.0         0
# 2     Sophomore   iPhone  Mac OS X-based computer          1.0         0
# 3        Senior   iPhone  Mac OS X-based computer          1.0         1
# 4     Sophomore   iPhone  Mac OS X-based computer          1.0         1
# 5     Sophomore  Android   Windows-based computer          1.0         0
# 6        Junior  Android   Windows-based computer          1.0         0
# 7        Senior   iPhone  Mac OS X-based computer          0.5         1
# 8      Freshman   iPhone                    Other          1.0         0
# 9        Senior  Android     Linux-based computer          1.0         0
# 10     Freshman   iPhone   Windows-based computer          1.0         0
# 11       Junior   iPhone  Mac OS X-based computer          1.0         1
# 12       Senior  Android  Mac OS X-based computer          2.0         0
# 13       Senior   iPhone   Windows-based computer          1.0         0
# 14       Senior  Android   Windows-based computer          1.0         1
# 15        Other   iPhone  Mac OS X-based computer          1.0         0
# 16     Freshman   iPhone  Mac OS X-based computer          1.0         0
# 17     Freshman  Android  Mac OS X-based computer          2.0         0
# 18     Freshman  Android   Windows-based computer          2.0         0
# 19       Senior   iPhone  Mac OS X-based computer          1.0         0
# 20       Junior   iPhone  Mac OS X-based computer          1.0         0
# 21     Freshman   iPhone   Windows-based computer          1.0         1
# 22    Sophomore   iPhone  Mac OS X-based computer          1.0         1
# 23     Freshman  Android  Mac OS X-based computer          2.0         0
# 24       Junior   iPhone  Mac OS X-based computer          1.0         0
# 25     Freshman   iPhone  Mac OS X-based computer          1.0         1
# 26     Freshman   iPhone  Mac OS X-based computer          1.0         0
# 27       Junior  Android   Windows-based computer          1.0         1
# 28       Junior   iPhone  Mac OS X-based computer          1.0         0
# 29     Freshman   iPhone  Mac OS X-based computer          2.0         0
# ..          ...      ...                      ...          ...       ...
# 136      Senior   iPhone  Mac OS X-based computer          1.0         0
# 137      Junior   iPhone  Mac OS X-based computer          1.0         1
# 138      Senior   iPhone  Mac OS X-based computer          1.0         1
# 139   Sophomore   iPhone  Mac OS X-based computer          2.0         0
# 140    Freshman   iPhone                    Other          2.0         1
# 141   Sophomore   iPhone   Windows-based computer          1.0         1
# 142      Senior  Android   Windows-based computer          1.0         1
# 143      Junior  Android   Windows-based computer          1.0         0
# 144      Senior   iPhone  Mac OS X-based computer          1.0         0
# 145      Junior   iPhone  Mac OS X-based computer          1.0         1
# 146      Junior   iPhone  Mac OS X-based computer          1.0         1
# 147      Junior   iPhone  Mac OS X-based computer          2.0         1
# 148   Sophomore  Android     Linux-based computer          1.0         0
# 149      Senior   iPhone   Windows-based computer          1.0         1
# 150      Senior   iPhone  Mac OS X-based computer          2.0         1
# 151    Freshman   iPhone  Mac OS X-based computer          1.0         0
# 152   Sophomore   iPhone  Mac OS X-based computer          1.0         0
# 153    Freshman  Android   Windows-based computer          1.0         0
# 154   Sophomore  Android   Windows-based computer          1.0         1
# 155      Senior   iPhone  Mac OS X-based computer          2.0         0
# 156      Junior   iPhone  Mac OS X-based computer          1.0         0
# 157      Junior   iPhone   Windows-based computer          1.0         0
# 158      Junior   iPhone  Mac OS X-based computer          1.0         0
# 159   Sophomore   iPhone   Windows-based computer          2.0         0
# 160   Sophomore   iPhone   Windows-based computer          1.0         1
# 161      Junior   iPhone  Mac OS X-based computer          NaN         1
# 162      Senior  Android   Windows-based computer          1.0         1
# 163   Sophomore   iPhone   Windows-based computer          1.0         0
# 164    Freshman   iPhone   Windows-based computer          1.0         1
# 165      Junior   iPhone  Mac OS X-based computer          1.0         0
#
#      Has Cats  Has Fish  Has Chickens     ...       Has Twitch  \
# 0           1         0             0     ...                0
# 1           0         0             0     ...                0
# 2           0         0             0     ...                0
# 3           1         0             0     ...                0
# 4           0         0             0     ...                0
# 5           0         0             0     ...                1
# 6           0         0             0     ...                0
# 7           0         0             0     ...                0
# 8           0         0             0     ...                0
# 9           0         0             0     ...                1
# 10          1         0             0     ...                1
# 11          0         0             0     ...                0
# 12          1         0             0     ...                0
# 13          0         0             0     ...                1
# 14          0         0             0     ...                0
# 15          0         0             0     ...                0
# 16          0         0             0     ...                0
# 17          0         0             0     ...                0
# 18          0         1             0     ...                0
# 19          0         0             0     ...                0
# 20          1         0             0     ...                0
# 21          0         0             0     ...                0
# 22          0         0             0     ...                0
# 23          0         0             0     ...                0
# 24          0         0             0     ...                0
# 25          0         0             0     ...                0
# 26          0         0             0     ...                0
# 27          0         0             0     ...                0
# 28          0         1             0     ...                0
# 29          0         0             0     ...                0
# ..        ...       ...           ...     ...              ...
# 136         0         0             0     ...                0
# 137         0         0             0     ...                0
# 138         0         0             0     ...                0
# 139         0         0             0     ...                0
# 140         0         0             0     ...                0
# 141         0         0             0     ...                1
# 142         0         0             0     ...                1
# 143         0         1             0     ...                1
# 144         0         0             0     ...                0
# 145         1         0             0     ...                0
# 146         0         0             0     ...                0
# 147         0         0             0     ...                0
# 148         0         0             0     ...                1
# 149         1         0             0     ...                0
# 150         1         0             0     ...                0
# 151         0         0             0     ...                0
# 152         0         0             0     ...                0
# 153         1         0             0     ...                0
# 154         1         0             0     ...                1
# 155         1         0             0     ...                0
# 156         0         0             0     ...                0
# 157         0         0             0     ...                0
# 158         0         0             0     ...                0
# 159         0         0             0     ...                0
# 160         0         0             0     ...                1
# 161         0         0             0     ...                0
# 162         0         0             0     ...                0
# 163         1         0             0     ...                0
# 164         0         0             0     ...                1
# 165         0         0             0     ...                0
#
#      Programmed before?                                  Python Background  \
# 0                   Yes  Significant -- I am a wizard when it comes to ...
# 1                   Yes  Some Python -- I have had one class or written...
# 2                    No  No programming background -- is Python Taylor ...
# 3                   Yes  No Python, but I've done some programming in o...
# 4                   Yes  Some Python -- I have had one class or written...
# 5                   Yes  Some Python -- I have had one class or written...
# 6                   Yes  Some Python -- I have had one class or written...
# 7                    No  No programming background -- is Python Taylor ...
# 8                    No  No programming background -- is Python Taylor ...
# 9                   Yes  Some Python -- I have had one class or written...
# 10                  Yes  Some Python -- I have had one class or written...
# 11                  Yes  Some Python -- I have had one class or written...
# 12                   No  No programming background -- is Python Taylor ...
# 13                  Yes  Some Python -- I have had one class or written...
# 14                  Yes  No Python, but I've done some programming in o...
# 15                  Yes  Some Python -- I have had one class or written...
# 16                  Yes  No Python, but I've done some programming in o...
# 17                  Yes  Some Python -- I have had one class or written...
# 18                  Yes  No Python, but I've done some programming in o...
# 19                  Yes  Some Python -- I have had one class or written...
# 20                  Yes  Significant -- I am a wizard when it comes to ...
# 21                  Yes  No Python, but I've done some programming in o...
# 22                  Yes  No Python, but I've done some programming in o...
# 23                  Yes  No Python, but I've done some programming in o...
# 24                  Yes  No Python, but I've done some programming in o...
# 25                   No  No programming background -- is Python Taylor ...
# 26                   No  No programming background -- is Python Taylor ...
# 27                  Yes  Significant -- I am a wizard when it comes to ...
# 28                  Yes  Some Python -- I have had one class or written...
# 29                  Yes  Some Python -- I have had one class or written...
# ..                  ...                                                ...
# 136                 Yes  Some Python -- I have had one class or written...
# 137                 Yes  Some Python -- I have had one class or written...
# 138                 Yes  Significant -- I am a wizard when it comes to ...
# 139                 Yes  Some Python -- I have had one class or written...
# 140                  No  No programming background -- is Python Taylor ...
# 141                 Yes  Some Python -- I have had one class or written...
# 142                 Yes  Some Python -- I have had one class or written...
# 143                 Yes  Significant -- I am a wizard when it comes to ...
# 144                 Yes  Some Python -- I have had one class or written...
# 145                  No  No programming background -- is Python Taylor ...
# 146                 Yes  Some Python -- I have had one class or written...
# 147                 Yes  No Python, but I've done some programming in o...
# 148                 Yes  Some Python -- I have had one class or written...
# 149                  No  No programming background -- is Python Taylor ...
# 150                  No  Some Python -- I have had one class or written...
# 151                  No  No programming background -- is Python Taylor ...
# 152                  No  No programming background -- is Python Taylor ...
# 153                  No  No programming background -- is Python Taylor ...
# 154                 Yes  No Python, but I've done some programming in o...
# 155                 Yes  Some Python -- I have had one class or written...
# 156                  No  No programming background -- is Python Taylor ...
# 157                  No  No Python, but I've done some programming in o...
# 158                 Yes  Some Python -- I have had one class or written...
# 159                 Yes  Some Python -- I have had one class or written...
# 160                 Yes  No Python, but I've done some programming in o...
# 161                  No  No programming background -- is Python Taylor ...
# 162                  No  No Python, but I've done some programming in o...
# 163                 Yes  No Python, but I've done some programming in o...
# 164                  No  No programming background -- is Python Taylor ...
# 165                 Yes  Some Python -- I have had one class or written...
#
#      Statistics Courses Hours Studying  Siblings  Hours of Sleep  Shoes Owned  \
# 0                     2            3.0       2.0             8.0          4.0
# 1                    20            1.0       2.0             7.0         20.0
# 2                     3            3.0       1.0             7.0         20.0
# 3                     2            4.0       1.0             6.0         10.0
# 4                     1            4.0       0.0             8.0         20.0
# 5                     0            3.0       2.0             6.0          4.0
# 6                     1            0.0       2.0             6.0          2.0
# 7                     0            5.0       1.0             8.0          8.0
# 8                     1            4.0       1.0             7.0          5.0
# 9                     1            3.0       2.0             8.0          5.0
# 10                    4            3.0       0.0             6.0          6.0
# 11                    1            2.0       2.0             7.0         20.0
# 12                    1            2.0       1.0             7.0          3.0
# 13                    3           10.0       2.0             7.0          3.0
# 14                    2            3.0       2.0             7.0          8.0
# 15                    2           12.0       0.0             7.0          4.0
# 16                    1            6.0       2.0             7.0         12.0
# 17                    0            4.0       0.0             7.0         10.0
# 18                    1            7.0       0.0             7.0          7.0
# 19                    2            2.0       2.0             6.0          7.0
# 20                    0            3.0       2.0             8.0          2.0
# 21                    1            2.0       2.0             7.0          NaN
# 22                    1            2.0       1.0             8.0         25.0
# 23                    0            4.0       1.0             6.0          4.0
# 24                    2            1.0       1.0             6.0          5.0
# 25                    1           10.0       0.0             7.0         10.0
# 26                    0            2.0       2.0             7.0          4.0
# 27                    2            3.0       2.0             7.5          3.0
# 28                    1            7.0       0.0             8.0          6.0
# 29                    0            2.5       NaN             7.5          5.0
# ..                  ...            ...       ...             ...          ...
# 136                   3            4.0       0.0             8.0          4.0
# 137                   3            2.0       1.0             7.0         10.0
# 138                   4            4.0       1.0             7.0         15.0
# 139                   1            6.0       0.0             7.0         10.0
# 140                   0            2.0       2.0             8.0          9.0
# 141                   2            1.0       1.0             6.0          3.0
# 142                   1            1.0       1.0             7.0          2.0
# 143                   2            3.0       1.0             7.0          2.0
# 144                   5            2.0       2.0             8.0         12.0
# 145                   1            2.0       2.0             6.0         10.0
# 146                   4            4.0       3.0             7.0         30.0
# 147                   1            2.5       2.0             5.5          8.0
# 148                   1            4.0       2.0            10.0          6.0
# 149                   0            3.0       2.0             7.0         14.0
# 150                   2            5.0       2.0             6.0          4.0
# 151                   0            2.0       1.0             7.0          5.0
# 152                   1            3.0       1.0             7.0         20.0
# 153                   0            6.0       0.0             7.0          3.0
# 154                   0            2.5       2.0             6.0          1.0
# 155                   4            4.0       0.0             7.0         15.0
# 156                   1            8.0       2.0             7.0          3.0
# 157                   1            2.0       2.0             7.0          3.0
# 158                   4            3.0       1.0             6.0         20.0
# 159                   0            3.0       3.0             5.0         10.0
# 160                   1            8.0       4.0             8.0         12.0
# 161                   1            2.0       9.0             7.0         30.0
# 162                   1            2.0       1.0             8.0          3.0
# 163                   0            3.0       2.0             8.0         12.0
# 164                   1            1.0       1.0             7.0         12.0
# 165                   1            4.0       1.0             7.0          6.0
#
#      People Texted Yesterday  Personality
# 0                        2.0    Introvert
# 1                       24.0    Extrovert
# 2                       10.0    Introvert
# 3                        8.0    Introvert
# 4                       30.0     Ambivert
# 5                       11.0    Introvert
# 6                       74.0    Introvert
# 7                       20.0     Ambivert
# 8                        4.0     Ambivert
# 9                       10.0     Ambivert
# 10                      15.0    Introvert
# 11                      15.0    Extrovert
# 12                       0.0    Extrovert
# 13                      70.0     Ambivert
# 14                       2.0    Introvert
# 15                     100.0     Ambivert
# 16                      50.0    Extrovert
# 17                      10.0     Ambivert
# 18                      19.0     Ambivert
# 19                      15.0     Ambivert
# 20                      10.0     Ambivert
# 21                      27.0     Ambivert
# 22                      10.0    Introvert
# 23                       6.0     Ambivert
# 24                      12.0     Ambivert
# 25                     535.0     Ambivert
# 26                       5.0    Introvert
# 27                       3.0    Introvert
# 28                       5.0    Introvert
# 29                       2.0    Introvert
# ..                       ...          ...
# 136                     30.0     Ambivert
# 137                     10.0     Ambivert
# 138                      7.0    Introvert
# 139                     10.0     Ambivert
# 140                      4.0     Ambivert
# 141                     10.0    Introvert
# 142                      1.0    Introvert
# 143                      3.0    Introvert
# 144                     42.0    Introvert
# 145                     25.0    Introvert
# 146                     32.0    Extrovert
# 147                      4.0     Ambivert
# 148                     15.0     Ambivert
# 149                      5.0     Ambivert
# 150                      8.0    Introvert
# 151                      4.0     Ambivert
# 152                      6.0     Ambivert
# 153                      8.0    Extrovert
# 154                      3.0     Ambivert
# 155                      5.0     Ambivert
# 156                      5.0     Ambivert
# 157                     20.0     Ambivert
# 158                     10.0     Ambivert
# 159                     15.0    Extrovert
# 160                    100.0     Ambivert
# 161                     12.0    Extrovert
# 162                      8.0     Ambivert
# 163                     25.0     Ambivert
# 164                     60.0    Introvert
# 165                     15.0    Introvert
#
# [166 rows x 31 columns]

# %%
## == TEST CASES for Puzzle 2.1 ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any error our output, you PASSED all test cases!
# - If this cell results in any errors, check you previous cell, make changes, and RE-RUN your code and then this cell.

assert(len(df_hello) == 166), "The dataframe does not appear to have correct dataset loaded"

# %% [markdown]
# ## 2.2: Observation Subsets
#
# Create two DataFrames that contain subsets of our data: one DataFrame that includes everyone who has watches Twitch at least once a week and one DataFrame that includes everyone who does not watch twitch at least once a week:

# %%
df_twitch = df_hello[df_hello["Has Twitch"]==1]
df_twitch
# Out:
#            Name                                              Major  \
# 5         Dhruv                                   Computer science
# 9    Edward/Edd                        CS, business data analysis?
# 10        Taige                                          Math + CS
# 13         Andy                                         Statistics
# 44       Andrew                                          CS + STAT
# 45          Leo                                                CS?
# 51     Zhoutian                               Computer Engineering
# 61        Tyler                                  actuarial science
# 67        Vivek                                   Computer science
# 77      Michael                                  Actuarial Science
# 90      Stephen                      Psychology & Computer Science
# 103        Cole                                  Political Science
# 126     Jaesung                                          Economics
# 129       Miles                                                GIS
# 141        Andi  Computer Science + Statistics or Statistics ma...
# 142       Jason                                            History
# 143      Austin                   Computer Science and Linguistics
# 148        Matt                               Information Sciences
# 154       David                               Information Sciences
# 160        Nate                                         Statistics
# 164        John                             Statistics or Business
#
#     School Year     Type                 Computer  Straw Holes  Has Dogs  \
# 5     Sophomore  Android   Windows-based computer          1.0         0
# 9        Senior  Android     Linux-based computer          1.0         0
# 10     Freshman   iPhone   Windows-based computer          1.0         0
# 13       Senior   iPhone   Windows-based computer          1.0         0
# 44       Junior   iPhone   Windows-based computer          1.0         1
# 45     Freshman   iPhone   Windows-based computer          1.0         0
# 51     Freshman   iPhone   Windows-based computer          1.0         0
# 61     Freshman  Android   Windows-based computer          1.0         1
# 67    Sophomore   iPhone   Windows-based computer          2.0         0
# 77       Senior  Android   Windows-based computer          1.0         0
# 90     Freshman  Android  Mac OS X-based computer          2.0         1
# 103      Junior   iPhone  Mac OS X-based computer          1.0         1
# 126      Senior   iPhone  Mac OS X-based computer          1.0         0
# 129      Senior   iPhone   Windows-based computer          0.0         1
# 141   Sophomore   iPhone   Windows-based computer          1.0         1
# 142      Senior  Android   Windows-based computer          1.0         1
# 143      Junior  Android   Windows-based computer          1.0         0
# 148   Sophomore  Android     Linux-based computer          1.0         0
# 154   Sophomore  Android   Windows-based computer          1.0         1
# 160   Sophomore   iPhone   Windows-based computer          1.0         1
# 164    Freshman   iPhone   Windows-based computer          1.0         1
#
#      Has Cats  Has Fish  Has Chickens     ...       Has Twitch  \
# 5           0         0             0     ...                1
# 9           0         0             0     ...                1
# 10          1         0             0     ...                1
# 13          0         0             0     ...                1
# 44          1         0             0     ...                1
# 45          0         1             0     ...                1
# 51          0         1             0     ...                1
# 61          1         0             0     ...                1
# 67          0         1             0     ...                1
# 77          0         0             0     ...                1
# 90          1         0             0     ...                1
# 103         0         0             0     ...                1
# 126         0         0             0     ...                1
# 129         1         0             1     ...                1
# 141         0         0             0     ...                1
# 142         0         0             0     ...                1
# 143         0         1             0     ...                1
# 148         0         0             0     ...                1
# 154         1         0             0     ...                1
# 160         0         0             0     ...                1
# 164         0         0             0     ...                1
#
#      Programmed before?                                  Python Background  \
# 5                   Yes  Some Python -- I have had one class or written...
# 9                   Yes  Some Python -- I have had one class or written...
# 10                  Yes  Some Python -- I have had one class or written...
# 13                  Yes  Some Python -- I have had one class or written...
# 44                  Yes  No Python, but I've done some programming in o...
# 45                  Yes  Some Python -- I have had one class or written...
# 51                  Yes  No Python, but I've done some programming in o...
# 61                  Yes  Some Python -- I have had one class or written...
# 67                  Yes  Some Python -- I have had one class or written...
# 77                  Yes  Some Python -- I have had one class or written...
# 90                  Yes  Some Python -- I have had one class or written...
# 103                 Yes  No Python, but I've done some programming in o...
# 126                 Yes  No Python, but I've done some programming in o...
# 129                 Yes  Some Python -- I have had one class or written...
# 141                 Yes  Some Python -- I have had one class or written...
# 142                 Yes  Some Python -- I have had one class or written...
# 143                 Yes  Significant -- I am a wizard when it comes to ...
# 148                 Yes  Some Python -- I have had one class or written...
# 154                 Yes  No Python, but I've done some programming in o...
# 160                 Yes  No Python, but I've done some programming in o...
# 164                  No  No programming background -- is Python Taylor ...
#
#      Statistics Courses Hours Studying  Siblings  Hours of Sleep  Shoes Owned  \
# 5                     0            3.0       2.0             6.0          4.0
# 9                     1            3.0       2.0             8.0          5.0
# 10                    4            3.0       0.0             6.0          6.0
# 13                    3           10.0       2.0             7.0          3.0
# 44                    4            4.0       1.0             5.0          2.0
# 45                    0            3.0       1.0             8.5          3.0
# 51                    1            9.0       0.0             7.0          6.0
# 61                    2            3.0       3.0             8.0          5.0
# 67                    0            3.0       1.0             6.0          4.0
# 77                    2            1.0       2.0             8.0          6.0
# 90                    0           10.0       0.0             7.5          2.0
# 103                   2            4.0       1.0             6.0         11.0
# 126                   3           12.0       2.0             7.0          5.0
# 129                   1            1.0       0.0             7.0          3.0
# 141                   2            1.0       1.0             6.0          3.0
# 142                   1            1.0       1.0             7.0          2.0
# 143                   2            3.0       1.0             7.0          2.0
# 148                   1            4.0       2.0            10.0          6.0
# 154                   0            2.5       2.0             6.0          1.0
# 160                   1            8.0       4.0             8.0         12.0
# 164                   1            1.0       1.0             7.0         12.0
#
#      People Texted Yesterday  Personality
# 5                       11.0    Introvert
# 9                       10.0     Ambivert
# 10                      15.0    Introvert
# 13                      70.0     Ambivert
# 44                       2.0     Ambivert
# 45                      20.0     Ambivert
# 51                       6.0     Ambivert
# 61                      10.0    Introvert
# 67                      30.0    Extrovert
# 77                       9.0     Ambivert
# 90                       8.0    Introvert
# 103                      3.0    Introvert
# 126                      3.0    Introvert
# 129                     10.0     Ambivert
# 141                     10.0    Introvert
# 142                      1.0    Introvert
# 143                      3.0    Introvert
# 148                     15.0     Ambivert
# 154                      3.0     Ambivert
# 160                    100.0     Ambivert
# 164                     60.0    Introvert
#
# [21 rows x 31 columns]

# %%
## == TEST CASES for Puzzle 2.2 ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any error our output, you PASSED all test cases!
# - If this cell results in any errors, check you previous cell, make changes, and RE-RUN your code and then this cell.

assert(len(df_twitch) == 21), "The dataframe does not appear to have been correct subset"

# %%
df_no_twitch = df_hello[df_hello["Has Twitch"]==0]
df_no_twitch
# Out:
#           Name                                    Major School Year     Type  \
# 0         Wade                         Computer Science       Other  Android
# 1        Karle                               Statistics       Other   iPhone
# 2         noor                global studies/statistics   Sophomore   iPhone
# 3     Jonathan                        Political Science      Senior   iPhone
# 4        Clare                               Statistics   Sophomore   iPhone
# 6         Alex                                  Physics      Junior  Android
# 7        Margo                                Chemistry      Senior   iPhone
# 8      Natalia                               Psychology    Freshman   iPhone
# 11        Sara                              Advertising      Junior   iPhone
# 12        Zayd                            Communication      Senior  Android
# 14        Gail                              Art History      Senior  Android
# 15       Jinda                         Computer Science       Other   iPhone
# 16     Natasha          Computer Science and Philosophy    Freshman   iPhone
# 17       Yijie             Computer Science+Mathematics    Freshman  Android
# 18      steven                             data science    Freshman  Android
# 19     Safwaan                                Economics      Senior   iPhone
# 20        Matt                                     Math      Junior   iPhone
# 21       Colin                        Actuarial Science    Freshman   iPhone
# 22        Katy                               Statistics   Sophomore   iPhone
# 23       Yosup           Computer Science + Mathematics    Freshman  Android
# 24      Andrew           Computer Science and Economics      Junior   iPhone
# 25    Caroline                                  Finance    Freshman   iPhone
# 26        Eric                             Not sure yet    Freshman   iPhone
# 27        Mike                               Statistics      Junior  Android
# 28       Chloe                   Structural Engineering      Junior   iPhone
# 29      Eugene            Statistics + Computer Science    Freshman   iPhone
# 30   Folashade                        Political Science   Sophomore   iPhone
# 31        Lisa               Human Resource Development       Other   iPhone
# 32         Uma           Molecular and Cellular Biology    Freshman   iPhone
# 33        Nick                        Political Science    Freshman  Android
# ..         ...                                      ...         ...      ...
# 128      Eddie                                  Finance      Junior   iPhone
# 130     Alison                     Computer Engineering      Senior   iPhone
# 131      Medha                Math and Computer Science   Sophomore  Android
# 132     Haosen                        Civil Engineering      Senior   iPhone
# 133       Mike                              Mathematics      Junior  Android
# 134      Roman                         Computer Science    Freshman   iPhone
# 135     Gargee                              mathematics   Sophomore   iPhone
# 136      Vivek                         CS + Linguistics      Senior   iPhone
# 137      Irene                               Statistics      Junior   iPhone
# 138  Sanskruti                              CS and Math      Senior   iPhone
# 139    Jiaming                                  Math+CS   Sophomore   iPhone
# 140    Makayla                 Media and Cinema Studies    Freshman   iPhone
# 144      Colin  Econometrics and Quantitative Economics      Senior   iPhone
# 145     Connor                              Advertising      Junior   iPhone
# 146       Kate                         Computer Science      Junior   iPhone
# 147       Nick                             Econometrics      Junior   iPhone
# 149      Dylan                             Anthropology      Senior   iPhone
# 150      Brian                        Political Science      Senior   iPhone
# 151        Jun                                    maths    Freshman   iPhone
# 152    Jessica                               Statistics   Sophomore   iPhone
# 153         LJ                                      NaN    Freshman  Android
# 155     Serena                                     Math      Senior   iPhone
# 156      Sofia                        Political Science      Junior   iPhone
# 157      Donny                     Information Sciences      Junior   iPhone
# 158        Ash           Consumer Economics and Finance      Junior   iPhone
# 159     Julisa                              Mathematics   Sophomore   iPhone
# 161  Stephanie                        Political Science      Junior   iPhone
# 162      Cindy                   biomedical engineering      Senior  Android
# 163      Talal                     Information sciences   Sophomore   iPhone
# 165     Anisha                                      Mcb      Junior   iPhone
#
#                     Computer  Straw Holes  Has Dogs  Has Cats  Has Fish  \
# 0     Windows-based computer          2.0         0         1         0
# 1    Mac OS X-based computer          1.0         0         0         0
# 2    Mac OS X-based computer          1.0         0         0         0
# 3    Mac OS X-based computer          1.0         1         1         0
# 4    Mac OS X-based computer          1.0         1         0         0
# 6     Windows-based computer          1.0         0         0         0
# 7    Mac OS X-based computer          0.5         1         0         0
# 8                      Other          1.0         0         0         0
# 11   Mac OS X-based computer          1.0         1         0         0
# 12   Mac OS X-based computer          2.0         0         1         0
# 14    Windows-based computer          1.0         1         0         0
# 15   Mac OS X-based computer          1.0         0         0         0
# 16   Mac OS X-based computer          1.0         0         0         0
# 17   Mac OS X-based computer          2.0         0         0         0
# 18    Windows-based computer          2.0         0         0         1
# 19   Mac OS X-based computer          1.0         0         0         0
# 20   Mac OS X-based computer          1.0         0         1         0
# 21    Windows-based computer          1.0         1         0         0
# 22   Mac OS X-based computer          1.0         1         0         0
# 23   Mac OS X-based computer          2.0         0         0         0
# 24   Mac OS X-based computer          1.0         0         0         0
# 25   Mac OS X-based computer          1.0         1         0         0
# 26   Mac OS X-based computer          1.0         0         0         0
# 27    Windows-based computer          1.0         1         0         0
# 28   Mac OS X-based computer          1.0         0         0         1
# 29   Mac OS X-based computer          2.0         0         0         0
# 30   Mac OS X-based computer          1.0         0         0         0
# 31   Mac OS X-based computer          2.0         0         0         0
# 32   Mac OS X-based computer          1.0         0         0         0
# 33    Windows-based computer          1.0         1         1         0
# ..                       ...          ...       ...       ...       ...
# 128  Mac OS X-based computer          1.0         1         0         0
# 130  Mac OS X-based computer          0.0         0         0         0
# 131  Mac OS X-based computer          1.0         0         0         0
# 132   Windows-based computer          2.0         0         0         0
# 133   Windows-based computer          1.0         1         0         0
# 134  Mac OS X-based computer          1.0         0         0         0
# 135  Mac OS X-based computer          2.0         0         0         0
# 136  Mac OS X-based computer          1.0         0         0         0
# 137  Mac OS X-based computer          1.0         1         0         0
# 138  Mac OS X-based computer          1.0         1         0         0
# 139  Mac OS X-based computer          2.0         0         0         0
# 140                    Other          2.0         1         0         0
# 144  Mac OS X-based computer          1.0         0         0         0
# 145  Mac OS X-based computer          1.0         1         1         0
# 146  Mac OS X-based computer          1.0         1         0         0
# 147  Mac OS X-based computer          2.0         1         0         0
# 149   Windows-based computer          1.0         1         1         0
# 150  Mac OS X-based computer          2.0         1         1         0
# 151  Mac OS X-based computer          1.0         0         0         0
# 152  Mac OS X-based computer          1.0         0         0         0
# 153   Windows-based computer          1.0         0         1         0
# 155  Mac OS X-based computer          2.0         0         1         0
# 156  Mac OS X-based computer          1.0         0         0         0
# 157   Windows-based computer          1.0         0         0         0
# 158  Mac OS X-based computer          1.0         0         0         0
# 159   Windows-based computer          2.0         0         0         0
# 161  Mac OS X-based computer          NaN         1         0         0
# 162   Windows-based computer          1.0         1         0         0
# 163   Windows-based computer          1.0         0         1         0
# 165  Mac OS X-based computer          1.0         0         0         0
#
#      Has Chickens     ...       Has Twitch  Programmed before?  \
# 0               0     ...                0                 Yes
# 1               0     ...                0                 Yes
# 2               0     ...                0                  No
# 3               0     ...                0                 Yes
# 4               0     ...                0                 Yes
# 6               0     ...                0                 Yes
# 7               0     ...                0                  No
# 8               0     ...                0                  No
# 11              0     ...                0                 Yes
# 12              0     ...                0                  No
# 14              0     ...                0                 Yes
# 15              0     ...                0                 Yes
# 16              0     ...                0                 Yes
# 17              0     ...                0                 Yes
# 18              0     ...                0                 Yes
# 19              0     ...                0                 Yes
# 20              0     ...                0                 Yes
# 21              0     ...                0                 Yes
# 22              0     ...                0                 Yes
# 23              0     ...                0                 Yes
# 24              0     ...                0                 Yes
# 25              0     ...                0                  No
# 26              0     ...                0                  No
# 27              0     ...                0                 Yes
# 28              0     ...                0                 Yes
# 29              0     ...                0                 Yes
# 30              0     ...                0                  No
# 31              0     ...                0                  No
# 32              0     ...                0                 Yes
# 33              0     ...                0                  No
# ..            ...     ...              ...                 ...
# 128             0     ...                0                 Yes
# 130             0     ...                0                 Yes
# 131             0     ...                0                 Yes
# 132             0     ...                0                 Yes
# 133             0     ...                0                 Yes
# 134             0     ...                0                 Yes
# 135             0     ...                0                 Yes
# 136             0     ...                0                 Yes
# 137             0     ...                0                 Yes
# 138             0     ...                0                 Yes
# 139             0     ...                0                 Yes
# 140             0     ...                0                  No
# 144             0     ...                0                 Yes
# 145             0     ...                0                  No
# 146             0     ...                0                 Yes
# 147             0     ...                0                 Yes
# 149             0     ...                0                  No
# 150             0     ...                0                  No
# 151             0     ...                0                  No
# 152             0     ...                0                  No
# 153             0     ...                0                  No
# 155             0     ...                0                 Yes
# 156             0     ...                0                  No
# 157             0     ...                0                  No
# 158             0     ...                0                 Yes
# 159             0     ...                0                 Yes
# 161             0     ...                0                  No
# 162             0     ...                0                  No
# 163             0     ...                0                 Yes
# 165             0     ...                0                 Yes
#
#                                      Python Background  Statistics Courses  \
# 0    Significant -- I am a wizard when it comes to ...                   2
# 1    Some Python -- I have had one class or written...                  20
# 2    No programming background -- is Python Taylor ...                   3
# 3    No Python, but I've done some programming in o...                   2
# 4    Some Python -- I have had one class or written...                   1
# 6    Some Python -- I have had one class or written...                   1
# 7    No programming background -- is Python Taylor ...                   0
# 8    No programming background -- is Python Taylor ...                   1
# 11   Some Python -- I have had one class or written...                   1
# 12   No programming background -- is Python Taylor ...                   1
# 14   No Python, but I've done some programming in o...                   2
# 15   Some Python -- I have had one class or written...                   2
# 16   No Python, but I've done some programming in o...                   1
# 17   Some Python -- I have had one class or written...                   0
# 18   No Python, but I've done some programming in o...                   1
# 19   Some Python -- I have had one class or written...                   2
# 20   Significant -- I am a wizard when it comes to ...                   0
# 21   No Python, but I've done some programming in o...                   1
# 22   No Python, but I've done some programming in o...                   1
# 23   No Python, but I've done some programming in o...                   0
# 24   No Python, but I've done some programming in o...                   2
# 25   No programming background -- is Python Taylor ...                   1
# 26   No programming background -- is Python Taylor ...                   0
# 27   Significant -- I am a wizard when it comes to ...                   2
# 28   Some Python -- I have had one class or written...                   1
# 29   Some Python -- I have had one class or written...                   0
# 30   No programming background -- is Python Taylor ...                   0
# 31   No programming background -- is Python Taylor ...                   2
# 32   Some Python -- I have had one class or written...                   1
# 33   No programming background -- is Python Taylor ...                   0
# ..                                                 ...                 ...
# 128  Some Python -- I have had one class or written...                   1
# 130  Some Python -- I have had one class or written...                   0
# 131  Some Python -- I have had one class or written...                   1
# 132  No programming background -- is Python Taylor ...                   6
# 133  Some Python -- I have had one class or written...                   2
# 134  Some Python -- I have had one class or written...                   0
# 135  Some Python -- I have had one class or written...                   2
# 136  Some Python -- I have had one class or written...                   3
# 137  Some Python -- I have had one class or written...                   3
# 138  Significant -- I am a wizard when it comes to ...                   4
# 139  Some Python -- I have had one class or written...                   1
# 140  No programming background -- is Python Taylor ...                   0
# 144  Some Python -- I have had one class or written...                   5
# 145  No programming background -- is Python Taylor ...                   1
# 146  Some Python -- I have had one class or written...                   4
# 147  No Python, but I've done some programming in o...                   1
# 149  No programming background -- is Python Taylor ...                   0
# 150  Some Python -- I have had one class or written...                   2
# 151  No programming background -- is Python Taylor ...                   0
# 152  No programming background -- is Python Taylor ...                   1
# 153  No programming background -- is Python Taylor ...                   0
# 155  Some Python -- I have had one class or written...                   4
# 156  No programming background -- is Python Taylor ...                   1
# 157  No Python, but I've done some programming in o...                   1
# 158  Some Python -- I have had one class or written...                   4
# 159  Some Python -- I have had one class or written...                   0
# 161  No programming background -- is Python Taylor ...                   1
# 162  No Python, but I've done some programming in o...                   1
# 163  No Python, but I've done some programming in o...                   0
# 165  Some Python -- I have had one class or written...                   1
#
#     Hours Studying  Siblings  Hours of Sleep  Shoes Owned  \
# 0              3.0       2.0             8.0          4.0
# 1              1.0       2.0             7.0         20.0
# 2              3.0       1.0             7.0         20.0
# 3              4.0       1.0             6.0         10.0
# 4              4.0       0.0             8.0         20.0
# 6              0.0       2.0             6.0          2.0
# 7              5.0       1.0             8.0          8.0
# 8              4.0       1.0             7.0          5.0
# 11             2.0       2.0             7.0         20.0
# 12             2.0       1.0             7.0          3.0
# 14             3.0       2.0             7.0          8.0
# 15            12.0       0.0             7.0          4.0
# 16             6.0       2.0             7.0         12.0
# 17             4.0       0.0             7.0         10.0
# 18             7.0       0.0             7.0          7.0
# 19             2.0       2.0             6.0          7.0
# 20             3.0       2.0             8.0          2.0
# 21             2.0       2.0             7.0          NaN
# 22             2.0       1.0             8.0         25.0
# 23             4.0       1.0             6.0          4.0
# 24             1.0       1.0             6.0          5.0
# 25            10.0       0.0             7.0         10.0
# 26             2.0       2.0             7.0          4.0
# 27             3.0       2.0             7.5          3.0
# 28             7.0       0.0             8.0          6.0
# 29             2.5       NaN             7.5          5.0
# 30            10.0       2.0             6.0          4.0
# 31            30.0       0.0             8.0         20.0
# 32             4.0       0.0             7.0          3.0
# 33             1.0       3.0             7.0          3.0
# ..             ...       ...             ...          ...
# 128            4.0       1.0             7.0         14.0
# 130            6.0       1.0             6.0         10.0
# 131            2.0       1.0             7.0          6.0
# 132            7.5       0.0             8.0          4.0
# 133            2.0       2.0             7.0          5.0
# 134            3.0       1.0             7.0          2.0
# 135            4.0       1.0             7.0         11.0
# 136            4.0       0.0             8.0          4.0
# 137            2.0       1.0             7.0         10.0
# 138            4.0       1.0             7.0         15.0
# 139            6.0       0.0             7.0         10.0
# 140            2.0       2.0             8.0          9.0
# 144            2.0       2.0             8.0         12.0
# 145            2.0       2.0             6.0         10.0
# 146            4.0       3.0             7.0         30.0
# 147            2.5       2.0             5.5          8.0
# 149            3.0       2.0             7.0         14.0
# 150            5.0       2.0             6.0          4.0
# 151            2.0       1.0             7.0          5.0
# 152            3.0       1.0             7.0         20.0
# 153            6.0       0.0             7.0          3.0
# 155            4.0       0.0             7.0         15.0
# 156            8.0       2.0             7.0          3.0
# 157            2.0       2.0             7.0          3.0
# 158            3.0       1.0             6.0         20.0
# 159            3.0       3.0             5.0         10.0
# 161            2.0       9.0             7.0         30.0
# 162            2.0       1.0             8.0          3.0
# 163            3.0       2.0             8.0         12.0
# 165            4.0       1.0             7.0          6.0
#
#      People Texted Yesterday  Personality
# 0                        2.0    Introvert
# 1                       24.0    Extrovert
# 2                       10.0    Introvert
# 3                        8.0    Introvert
# 4                       30.0     Ambivert
# 6                       74.0    Introvert
# 7                       20.0     Ambivert
# 8                        4.0     Ambivert
# 11                      15.0    Extrovert
# 12                       0.0    Extrovert
# 14                       2.0    Introvert
# 15                     100.0     Ambivert
# 16                      50.0    Extrovert
# 17                      10.0     Ambivert
# 18                      19.0     Ambivert
# 19                      15.0     Ambivert
# 20                      10.0     Ambivert
# 21                      27.0     Ambivert
# 22                      10.0    Introvert
# 23                       6.0     Ambivert
# 24                      12.0     Ambivert
# 25                     535.0     Ambivert
# 26                       5.0    Introvert
# 27                       3.0    Introvert
# 28                       5.0    Introvert
# 29                       2.0    Introvert
# 30                       7.0    Introvert
# 31                       6.0     Ambivert
# 32                       6.0     Ambivert
# 33                      19.0     Ambivert
# ..                       ...          ...
# 128                     20.0    Extrovert
# 130                     12.0     Ambivert
# 131                     15.0     Ambivert
# 132                      6.0     Ambivert
# 133                      0.0    Extrovert
# 134                      6.0    Introvert
# 135                     20.0    Extrovert
# 136                     30.0     Ambivert
# 137                     10.0     Ambivert
# 138                      7.0    Introvert
# 139                     10.0     Ambivert
# 140                      4.0     Ambivert
# 144                     42.0    Introvert
# 145                     25.0    Introvert
# 146                     32.0    Extrovert
# 147                      4.0     Ambivert
# 149                      5.0     Ambivert
# 150                      8.0    Introvert
# 151                      4.0     Ambivert
# 152                      6.0     Ambivert
# 153                      8.0    Extrovert
# 155                      5.0     Ambivert
# 156                      5.0     Ambivert
# 157                     20.0     Ambivert
# 158                     10.0     Ambivert
# 159                     15.0    Extrovert
# 161                     12.0    Extrovert
# 162                      8.0     Ambivert
# 163                     25.0     Ambivert
# 165                     15.0    Introvert
#
# [145 rows x 31 columns]

# %%
## == TEST CASES for Puzzle 2.2 ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any error our output, you PASSED all test cases!
# - If this cell results in any errors, check you previous cell, make changes, and RE-RUN your code and then this cell.

assert(len(df_no_twitch) == 145), "The dataframe does not appear to have been correct subset"

# %% [markdown]
# ## 2.3: Average Number of Pairs of Shoes
#
# Find the average number of pairs of shoes of each group:

# %%
twitch_avg_shoes = df_twitch["Shoes Owned"].mean()
twitch_avg_shoes
# Out:
# 4.904761904761905

# %%
## == TEST CASES for Puzzle 2.3 ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any error our output, you PASSED all test cases!
# - If this cell results in any errors, check you previous cell, make changes, and RE-RUN your code and then this cell.

assert(twitch_avg_shoes == 103/21),  "The average number of pairs of shoes in twitch dataset does not appear to seem correct. Make sure you are taking mean of the correct variable."

# %%
no_twitch_avg_shoes = df_no_twitch["Shoes Owned"].mean()
no_twitch_avg_shoes
# Out:
# 9.38888888888889

# %%
## == TEST CASES for Puzzle 2.3 ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any error our output, you PASSED all test cases!
# - If this cell results in any errors, check you previous cell, make changes, and RE-RUN your code and then this cell.

assert(no_twitch_avg_shoes == 1352 / 144),  "The average number of pairs of shoes in no twitch dataset does not appear to seem correct. Make sure you are taking mean of the correct variable."

# %% [markdown]
# ## 2.4. Observations
#
# Answer the next two questions with 1-2 sentences each.  The cells after the question text are editable -- you should double-click and replace the text with your answer:

# %% [markdown]
# ### Q1: Is there a difference in the number of shoes owned between the two groups?

# %% [markdown]
# Yes; on average, the group that does not watch Twitch at least once a week owns almost double the amount of pairs of shoes as the group that does watch Twitch once a week.

# %% [markdown]
# ### Q2: What might be some possible confounding variable in this result?

# %% [markdown]
# I hypothesize that males watch Twitch more often than females, and females own more shoes than males on average.  Not watching Twitch once a week does not cause someone to buy more shoes.  Therefore, gender is a confounding variable in this situation.

# %% [markdown]
# # Finale!
#
# You're almost done -- congratulations!
#
# You need to do two more things:
#
# 1. Save your work.  To do this, create a **notebook checkpoint** by using the menu within the notebook to go **File -> Save and Checkpoint**
#
# 2. After you have saved and checkpointed, exit this notebook and return to the Data Science Discovery page on how to use git to turn this notebook into the course!
