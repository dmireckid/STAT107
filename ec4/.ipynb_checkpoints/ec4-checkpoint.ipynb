# %% [markdown]
# # EC Notebook for Lecture 4: Blocking and Conditionals
#
# This extra credit Python notebook will let you practice the material you saw in lecture!  Completing all parts of this notebook will earn +1 extra credit point to your grade in STAT 107!
#
# This notebook is worth +1 if turned in before 11:30am on **Friday, Sept. 6** *(30 minutes before the next STAT 107 lecture)*.  You can feel free to complete it anytime for extra practice.

# %% [markdown]
# ## 1. Loading pandas and importing data
#
# For this notebook, we will continue to use the "Hello" dataset introduced last lecture!
#
# Using your @illinois.edu address, download the dataset as a CSV and **make sure to save or move it to the same directory as this notebook**: https://docs.google.com/spreadsheets/d/1LB4E89GoVi5yezEfHhopbI5BMxodSG7VvoznkaAkMAQ/edit#gid=0
#
# Use the following cell to load the pandas library and read the DataSet as a DataFrame:

# %%
import pandas as pd
df = pd.read_csv('hello dataset.csv')

# %% [markdown]
# ## 2. Finising the Lecture Problem
#
# In lecture, we left you with a final puzzle.  From the lecture handout:
#
# > Use Python to create a control group of 20 students, using blocking to control for the influence we suspect having more than 1 siblings might have.  Make sure you have an equal number of students with 0 or 1 sibling and an equal number of students with 2 or more siblings.
#
# We will complete this in four separate steps to get practice on each part.
#
# #### 2.1: Sibling Block #1
#
# Creating a DataFrame that contains all students with 0 or 1 siblings and call it `block1`:

# %%
block1 = df[df["Siblings"] <= 1]
block1
# Out:
#           Name                                              Major School Year  \
# 2         noor                          global studies/statistics   Sophomore
# 3     Jonathan                                  Political Science      Senior
# 4        Clare                                         Statistics   Sophomore
# 7        Margo                                          Chemistry      Senior
# 8      Natalia                                         Psychology    Freshman
# 10       Taige                                          Math + CS    Freshman
# 12        Zayd                                      Communication      Senior
# 15       Jinda                                   Computer Science       Other
# 17       Yijie                       Computer Science+Mathematics    Freshman
# 18      steven                                       data science    Freshman
# 22        Katy                                         Statistics   Sophomore
# 23       Yosup                     Computer Science + Mathematics    Freshman
# 24      Andrew                     Computer Science and Economics      Junior
# 25    Caroline                                            Finance    Freshman
# 28       Chloe                             Structural Engineering      Junior
# 31        Lisa                         Human Resource Development       Other
# 32         Uma                     Molecular and Cellular Biology    Freshman
# 35        Niks                   Mathematics and Computer Science    Freshman
# 36     Raagini                                   Computer Science      Senior
# 39      Munwon                                         Statistics      Senior
# 42      Wenxin                                         Statistics      Senior
# 44      Andrew                                          CS + STAT      Junior
# 45         Leo                                                CS?    Freshman
# 47       Erica                                          Sociology      Junior
# 49        Noah                                       Econometrics      Senior
# 50      Ilisha                                         Psychology      Junior
# 51    Zhoutian                               Computer Engineering    Freshman
# 53       Jiwon                                            CS+Stat      Junior
# 55       Shubh                    Computer Science and Statistics   Sophomore
# 56     Kamayah                     Mathematics & Computer Science      Junior
# ..         ...                                                ...         ...
# 117     Ashley                                  Actuarial Science   Sophomore
# 118      Mendy                                  Political Science    Freshman
# 119        You                                   Computer science    Freshman
# 120     Sumedh                    Statistics and Computer Science    Freshman
# 121    Gerardo                                           Business    Freshman
# 122      Marni                         Speech and hearing science   Sophomore
# 123    Gautham                                        Mathematics      Junior
# 124     Sheila                            Linguistics and English      Junior
# 128      Eddie                                            Finance      Junior
# 129      Miles                                                GIS      Senior
# 130     Alison                               Computer Engineering      Senior
# 131      Medha                          Math and Computer Science   Sophomore
# 132     Haosen                                  Civil Engineering      Senior
# 134      Roman                                   Computer Science    Freshman
# 135     Gargee                                        mathematics   Sophomore
# 136      Vivek                                   CS + Linguistics      Senior
# 137      Irene                                         Statistics      Junior
# 138  Sanskruti                                        CS and Math      Senior
# 139    Jiaming                                            Math+CS   Sophomore
# 141       Andi  Computer Science + Statistics or Statistics ma...   Sophomore
# 142      Jason                                            History      Senior
# 143     Austin                   Computer Science and Linguistics      Junior
# 151        Jun                                              maths    Freshman
# 152    Jessica                                         Statistics   Sophomore
# 153         LJ                                                NaN    Freshman
# 155     Serena                                               Math      Senior
# 158        Ash                     Consumer Economics and Finance      Junior
# 162      Cindy                             biomedical engineering      Senior
# 164       John                             Statistics or Business    Freshman
# 165     Anisha                                                Mcb      Junior
#
#         Type                 Computer  Straw Holes  Has Dogs  Has Cats  \
# 2     iPhone  Mac OS X-based computer          1.0         0         0
# 3     iPhone  Mac OS X-based computer          1.0         1         1
# 4     iPhone  Mac OS X-based computer          1.0         1         0
# 7     iPhone  Mac OS X-based computer          0.5         1         0
# 8     iPhone                    Other          1.0         0         0
# 10    iPhone   Windows-based computer          1.0         0         1
# 12   Android  Mac OS X-based computer          2.0         0         1
# 15    iPhone  Mac OS X-based computer          1.0         0         0
# 17   Android  Mac OS X-based computer          2.0         0         0
# 18   Android   Windows-based computer          2.0         0         0
# 22    iPhone  Mac OS X-based computer          1.0         1         0
# 23   Android  Mac OS X-based computer          2.0         0         0
# 24    iPhone  Mac OS X-based computer          1.0         0         0
# 25    iPhone  Mac OS X-based computer          1.0         1         0
# 28    iPhone  Mac OS X-based computer          1.0         0         0
# 31    iPhone  Mac OS X-based computer          2.0         0         0
# 32    iPhone  Mac OS X-based computer          1.0         0         0
# 35   Android   Windows-based computer          2.0         0         0
# 36    iPhone  Mac OS X-based computer          1.0         0         0
# 39    iPhone   Windows-based computer          2.0         0         0
# 42    iPhone  Mac OS X-based computer          1.0         0         0
# 44    iPhone   Windows-based computer          1.0         1         1
# 45    iPhone   Windows-based computer          1.0         0         0
# 47    iPhone  Mac OS X-based computer          2.0         0         0
# 49    iPhone  Mac OS X-based computer          1.0         0         1
# 50    iPhone  Mac OS X-based computer          2.0         0         0
# 51    iPhone   Windows-based computer          1.0         0         0
# 53    iPhone   Windows-based computer          1.0         0         0
# 55   Android  Mac OS X-based computer          2.0         0         0
# 56    iPhone   Windows-based computer          2.0         0         1
# ..       ...                      ...          ...       ...       ...
# 117   iPhone  Mac OS X-based computer          1.0         1         0
# 118   iPhone  Mac OS X-based computer          1.0         0         0
# 119   iPhone  Mac OS X-based computer          2.0         1         0
# 120  Android   Windows-based computer          2.0         0         0
# 121   iPhone   Windows-based computer          1.0         0         0
# 122   iPhone  Mac OS X-based computer          1.0         1         0
# 123  Android   Windows-based computer          0.0         1         0
# 124   iPhone   Windows-based computer          2.0         0         1
# 128   iPhone  Mac OS X-based computer          1.0         1         0
# 129   iPhone   Windows-based computer          0.0         1         1
# 130   iPhone  Mac OS X-based computer          0.0         0         0
# 131  Android  Mac OS X-based computer          1.0         0         0
# 132   iPhone   Windows-based computer          2.0         0         0
# 134   iPhone  Mac OS X-based computer          1.0         0         0
# 135   iPhone  Mac OS X-based computer          2.0         0         0
# 136   iPhone  Mac OS X-based computer          1.0         0         0
# 137   iPhone  Mac OS X-based computer          1.0         1         0
# 138   iPhone  Mac OS X-based computer          1.0         1         0
# 139   iPhone  Mac OS X-based computer          2.0         0         0
# 141   iPhone   Windows-based computer          1.0         1         0
# 142  Android   Windows-based computer          1.0         1         0
# 143  Android   Windows-based computer          1.0         0         0
# 151   iPhone  Mac OS X-based computer          1.0         0         0
# 152   iPhone  Mac OS X-based computer          1.0         0         0
# 153  Android   Windows-based computer          1.0         0         1
# 155   iPhone  Mac OS X-based computer          2.0         0         1
# 158   iPhone  Mac OS X-based computer          1.0         0         0
# 162  Android   Windows-based computer          1.0         1         0
# 164   iPhone   Windows-based computer          1.0         1         0
# 165   iPhone  Mac OS X-based computer          1.0         0         0
#
#      Has Fish  Has Chickens     ...       Has Twitch  Programmed before?  \
# 2           0             0     ...                0                  No
# 3           0             0     ...                0                 Yes
# 4           0             0     ...                0                 Yes
# 7           0             0     ...                0                  No
# 8           0             0     ...                0                  No
# 10          0             0     ...                1                 Yes
# 12          0             0     ...                0                  No
# 15          0             0     ...                0                 Yes
# 17          0             0     ...                0                 Yes
# 18          1             0     ...                0                 Yes
# 22          0             0     ...                0                 Yes
# 23          0             0     ...                0                 Yes
# 24          0             0     ...                0                 Yes
# 25          0             0     ...                0                  No
# 28          1             0     ...                0                 Yes
# 31          0             0     ...                0                  No
# 32          0             0     ...                0                 Yes
# 35          0             0     ...                0                 Yes
# 36          0             0     ...                0                 Yes
# 39          0             0     ...                0                 Yes
# 42          0             0     ...                0                 Yes
# 44          0             0     ...                1                 Yes
# 45          1             0     ...                1                 Yes
# 47          0             0     ...                0                 Yes
# 49          0             0     ...                0                 Yes
# 50          0             0     ...                0                 Yes
# 51          1             0     ...                1                 Yes
# 53          0             0     ...                0                 Yes
# 55          0             0     ...                0                 Yes
# 56          0             0     ...                0                 Yes
# ..        ...           ...     ...              ...                 ...
# 117         0             0     ...                0                 Yes
# 118         1             0     ...                0                 Yes
# 119         0             0     ...                0                 Yes
# 120         0             0     ...                0                 Yes
# 121         0             0     ...                0                 Yes
# 122         0             0     ...                0                  No
# 123         0             0     ...                0                 Yes
# 124         0             0     ...                0                 Yes
# 128         0             0     ...                0                 Yes
# 129         0             1     ...                1                 Yes
# 130         0             0     ...                0                 Yes
# 131         0             0     ...                0                 Yes
# 132         0             0     ...                0                 Yes
# 134         0             0     ...                0                 Yes
# 135         0             0     ...                0                 Yes
# 136         0             0     ...                0                 Yes
# 137         0             0     ...                0                 Yes
# 138         0             0     ...                0                 Yes
# 139         0             0     ...                0                 Yes
# 141         0             0     ...                1                 Yes
# 142         0             0     ...                1                 Yes
# 143         1             0     ...                1                 Yes
# 151         0             0     ...                0                  No
# 152         0             0     ...                0                  No
# 153         0             0     ...                0                  No
# 155         0             0     ...                0                 Yes
# 158         0             0     ...                0                 Yes
# 162         0             0     ...                0                  No
# 164         0             0     ...                1                  No
# 165         0             0     ...                0                 Yes
#
#                                      Python Background  Statistics Courses  \
# 2    No programming background -- is Python Taylor ...                   3
# 3    No Python, but I've done some programming in o...                   2
# 4    Some Python -- I have had one class or written...                   1
# 7    No programming background -- is Python Taylor ...                   0
# 8    No programming background -- is Python Taylor ...                   1
# 10   Some Python -- I have had one class or written...                   4
# 12   No programming background -- is Python Taylor ...                   1
# 15   Some Python -- I have had one class or written...                   2
# 17   Some Python -- I have had one class or written...                   0
# 18   No Python, but I've done some programming in o...                   1
# 22   No Python, but I've done some programming in o...                   1
# 23   No Python, but I've done some programming in o...                   0
# 24   No Python, but I've done some programming in o...                   2
# 25   No programming background -- is Python Taylor ...                   1
# 28   Some Python -- I have had one class or written...                   1
# 31   No programming background -- is Python Taylor ...                   2
# 32   Some Python -- I have had one class or written...                   1
# 35   Some Python -- I have had one class or written...                   1
# 36   Some Python -- I have had one class or written...                   3
# 39   No Python, but I've done some programming in o...                   4
# 42   Some Python -- I have had one class or written...                   5
# 44   No Python, but I've done some programming in o...                   4
# 45   Some Python -- I have had one class or written...                   0
# 47   No Python, but I've done some programming in o...                   3
# 49   Some Python -- I have had one class or written...                   4
# 50   Some Python -- I have had one class or written...                   2
# 51   No Python, but I've done some programming in o...                   1
# 53   Some Python -- I have had one class or written...                   4
# 55   No Python, but I've done some programming in o...                   1
# 56   No Python, but I've done some programming in o...                   1
# ..                                                 ...                 ...
# 117  No Python, but I've done some programming in o...                   0
# 118  No Python, but I've done some programming in o...                   1
# 119  Some Python -- I have had one class or written...                   0
# 120  Significant -- I am a wizard when it comes to ...                   1
# 121  No Python, but I've done some programming in o...                   0
# 122  No programming background -- is Python Taylor ...                   1
# 123  Some Python -- I have had one class or written...                   3
# 124  Some Python -- I have had one class or written...                   1
# 128  Some Python -- I have had one class or written...                   1
# 129  Some Python -- I have had one class or written...                   1
# 130  Some Python -- I have had one class or written...                   0
# 131  Some Python -- I have had one class or written...                   1
# 132  No programming background -- is Python Taylor ...                   6
# 134  Some Python -- I have had one class or written...                   0
# 135  Some Python -- I have had one class or written...                   2
# 136  Some Python -- I have had one class or written...                   3
# 137  Some Python -- I have had one class or written...                   3
# 138  Significant -- I am a wizard when it comes to ...                   4
# 139  Some Python -- I have had one class or written...                   1
# 141  Some Python -- I have had one class or written...                   2
# 142  Some Python -- I have had one class or written...                   1
# 143  Significant -- I am a wizard when it comes to ...                   2
# 151  No programming background -- is Python Taylor ...                   0
# 152  No programming background -- is Python Taylor ...                   1
# 153  No programming background -- is Python Taylor ...                   0
# 155  Some Python -- I have had one class or written...                   4
# 158  Some Python -- I have had one class or written...                   4
# 162  No Python, but I've done some programming in o...                   1
# 164  No programming background -- is Python Taylor ...                   1
# 165  Some Python -- I have had one class or written...                   1
#
#     Hours Studying  Siblings  Hours of Sleep  Shoes Owned  \
# 2              3.0       1.0             7.0         20.0
# 3              4.0       1.0             6.0         10.0
# 4              4.0       0.0             8.0         20.0
# 7              5.0       1.0             8.0          8.0
# 8              4.0       1.0             7.0          5.0
# 10             3.0       0.0             6.0          6.0
# 12             2.0       1.0             7.0          3.0
# 15            12.0       0.0             7.0          4.0
# 17             4.0       0.0             7.0         10.0
# 18             7.0       0.0             7.0          7.0
# 22             2.0       1.0             8.0         25.0
# 23             4.0       1.0             6.0          4.0
# 24             1.0       1.0             6.0          5.0
# 25            10.0       0.0             7.0         10.0
# 28             7.0       0.0             8.0          6.0
# 31            30.0       0.0             8.0         20.0
# 32             4.0       0.0             7.0          3.0
# 35             3.0       0.0             7.0          4.0
# 36             4.0       1.0             6.0         10.0
# 39             6.0       1.0             7.0          8.0
# 42             3.0       0.0             8.0         10.0
# 44             4.0       1.0             5.0          2.0
# 45             3.0       1.0             8.5          3.0
# 47             3.0       1.0             8.0          8.0
# 49             3.0       1.0             7.0          7.0
# 50             3.0       1.0             7.0         10.0
# 51             9.0       0.0             7.0          6.0
# 53             5.0       1.0             7.0          1.0
# 55             2.0       1.0             7.0          7.0
# 56             4.0       0.0             7.0         25.0
# ..             ...       ...             ...          ...
# 117            4.0       0.0             6.0          8.0
# 118            0.5       1.0             7.0          7.0
# 119            3.0       0.0             9.0          3.0
# 120            5.0       1.0             7.0          5.0
# 121            0.0       0.0             9.0          5.0
# 122            4.0       1.0             7.0         13.0
# 123            5.0       1.0             7.0          4.0
# 124            5.0       1.0             8.0         20.0
# 128            4.0       1.0             7.0         14.0
# 129            1.0       0.0             7.0          3.0
# 130            6.0       1.0             6.0         10.0
# 131            2.0       1.0             7.0          6.0
# 132            7.5       0.0             8.0          4.0
# 134            3.0       1.0             7.0          2.0
# 135            4.0       1.0             7.0         11.0
# 136            4.0       0.0             8.0          4.0
# 137            2.0       1.0             7.0         10.0
# 138            4.0       1.0             7.0         15.0
# 139            6.0       0.0             7.0         10.0
# 141            1.0       1.0             6.0          3.0
# 142            1.0       1.0             7.0          2.0
# 143            3.0       1.0             7.0          2.0
# 151            2.0       1.0             7.0          5.0
# 152            3.0       1.0             7.0         20.0
# 153            6.0       0.0             7.0          3.0
# 155            4.0       0.0             7.0         15.0
# 158            3.0       1.0             6.0         20.0
# 162            2.0       1.0             8.0          3.0
# 164            1.0       1.0             7.0         12.0
# 165            4.0       1.0             7.0          6.0
#
#      People Texted Yesterday  Personality
# 2                       10.0    Introvert
# 3                        8.0    Introvert
# 4                       30.0     Ambivert
# 7                       20.0     Ambivert
# 8                        4.0     Ambivert
# 10                      15.0    Introvert
# 12                       0.0    Extrovert
# 15                     100.0     Ambivert
# 17                      10.0     Ambivert
# 18                      19.0     Ambivert
# 22                      10.0    Introvert
# 23                       6.0     Ambivert
# 24                      12.0     Ambivert
# 25                     535.0     Ambivert
# 28                       5.0    Introvert
# 31                       6.0     Ambivert
# 32                       6.0     Ambivert
# 35                      30.0    Introvert
# 36                       9.0     Ambivert
# 39                       7.0    Introvert
# 42                       5.0    Introvert
# 44                       2.0     Ambivert
# 45                      20.0     Ambivert
# 47                      12.0     Ambivert
# 49                       6.0    Introvert
# 50                      31.0     Ambivert
# 51                       6.0     Ambivert
# 53                       3.0    Introvert
# 55                      12.0     Ambivert
# 56                       6.0    Introvert
# ..                       ...          ...
# 117                     15.0    Introvert
# 118                      7.0     Ambivert
# 119                     63.0     Ambivert
# 120                      7.0     Ambivert
# 121                     20.0    Extrovert
# 122                     24.0    Extrovert
# 123                      4.0    Introvert
# 124                     13.0     Ambivert
# 128                     20.0    Extrovert
# 129                     10.0     Ambivert
# 130                     12.0     Ambivert
# 131                     15.0     Ambivert
# 132                      6.0     Ambivert
# 134                      6.0    Introvert
# 135                     20.0    Extrovert
# 136                     30.0     Ambivert
# 137                     10.0     Ambivert
# 138                      7.0    Introvert
# 139                     10.0     Ambivert
# 141                     10.0    Introvert
# 142                      1.0    Introvert
# 143                      3.0    Introvert
# 151                      4.0     Ambivert
# 152                      6.0     Ambivert
# 153                      8.0    Extrovert
# 155                      5.0     Ambivert
# 158                     10.0     Ambivert
# 162                      8.0     Ambivert
# 164                     60.0    Introvert
# 165                     15.0    Introvert
#
# [100 rows x 31 columns]

# %% [markdown]
# #### 2.2: Sibling Block #2
#
# Create a DataFrame that contains all students with 2 or more siblings and call it `block2`:

# %%
block2 = df[df["Siblings"] >= 2]
block2
# Out:
#                Name                                              Major  \
# 0              Wade                                   Computer Science
# 1             Karle                                         Statistics
# 5             Dhruv                                   Computer science
# 6              Alex                                            Physics
# 9        Edward/Edd                        CS, business data analysis?
# 11             Sara                                        Advertising
# 13             Andy                                         Statistics
# 14             Gail                                        Art History
# 16          Natasha                    Computer Science and Philosophy
# 19          Safwaan                                          Economics
# 20             Matt                                               Math
# 21            Colin                                  Actuarial Science
# 26             Eric                                       Not sure yet
# 27             Mike                                         Statistics
# 30        Folashade                                  Political Science
# 33             Nick                                  Political Science
# 34           Jackie                                               math
# 37             Jose                                  Political Science
# 38          Trishul                                   Computer Science
# 40           Joshua                                         undeclared
# 41          Michael                                   Computer Science
# 43            Louie                                     CS + Astronomy
# 46              Zac                agribusiness markets and management
# 48          Vincent                                         Statistics
# 52   Joshua Fischer                                  Actuarial Science
# 54         Saharish                                  Political Science
# 57              Ian                Actuarial Science, Computer Science
# 58            Diego                                        CS + Anthro
# 61            Tyler                                  actuarial science
# 63            Emily                                         Statistics
# ..              ...                                                ...
# 77          Michael                                  Actuarial Science
# 80           Esther                                         Statistics
# 81             Rami                                         Psychology
# 85            Olive                                    Theatre Studies
# 87           Gloria                                      Communication
# 88            Hadil  linguistics, and then law school (immigration ...
# 95           Nicole                                  Political Science
# 99           Daniel                                         Statistics
# 104          Eunice                                         Journalism
# 108          Satori                                  Industrial Design
# 112         Enrique                                   Computer Science
# 125          Carlos                                         Statistics
# 126         Jaesung                                          Economics
# 127        Veronica                                     Communications
# 133            Mike                                        Mathematics
# 140         Makayla                           Media and Cinema Studies
# 144           Colin            Econometrics and Quantitative Economics
# 145          Connor                                        Advertising
# 146            Kate                                   Computer Science
# 147            Nick                                       Econometrics
# 148            Matt                               Information Sciences
# 149           Dylan                                       Anthropology
# 150           Brian                                  Political Science
# 154           David                               Information Sciences
# 156           Sofia                                  Political Science
# 157           Donny                               Information Sciences
# 159          Julisa                                        Mathematics
# 160            Nate                                         Statistics
# 161       Stephanie                                  Political Science
# 163           Talal                               Information sciences
#
#     School Year     Type                 Computer  Straw Holes  Has Dogs  \
# 0         Other  Android   Windows-based computer          2.0         0
# 1         Other   iPhone  Mac OS X-based computer          1.0         0
# 5     Sophomore  Android   Windows-based computer          1.0         0
# 6        Junior  Android   Windows-based computer          1.0         0
# 9        Senior  Android     Linux-based computer          1.0         0
# 11       Junior   iPhone  Mac OS X-based computer          1.0         1
# 13       Senior   iPhone   Windows-based computer          1.0         0
# 14       Senior  Android   Windows-based computer          1.0         1
# 16     Freshman   iPhone  Mac OS X-based computer          1.0         0
# 19       Senior   iPhone  Mac OS X-based computer          1.0         0
# 20       Junior   iPhone  Mac OS X-based computer          1.0         0
# 21     Freshman   iPhone   Windows-based computer          1.0         1
# 26     Freshman   iPhone  Mac OS X-based computer          1.0         0
# 27       Junior  Android   Windows-based computer          1.0         1
# 30    Sophomore   iPhone  Mac OS X-based computer          1.0         0
# 33     Freshman  Android   Windows-based computer          1.0         1
# 34    Sophomore   iPhone   Windows-based computer          2.0         1
# 37     Freshman  Android                    Other          1.0         1
# 38    Sophomore   iPhone  Mac OS X-based computer          1.0         0
# 40    Sophomore   iPhone  Mac OS X-based computer          1.0         0
# 41     Freshman   iPhone  Mac OS X-based computer          4.0         1
# 43     Freshman   iPhone  Mac OS X-based computer          2.0         1
# 46       Junior   iPhone                    Other          1.0         1
# 48       Senior   iPhone  Mac OS X-based computer          1.0         1
# 52       Junior   iPhone  Mac OS X-based computer          2.0         0
# 54       Senior   iPhone  Mac OS X-based computer          1.0         1
# 57    Sophomore   iPhone  Mac OS X-based computer          1.0         1
# 58       Junior   iPhone   Windows-based computer          1.0         0
# 61     Freshman  Android   Windows-based computer          1.0         1
# 63    Sophomore   iPhone  Mac OS X-based computer          1.0         1
# ..          ...      ...                      ...          ...       ...
# 77       Senior  Android   Windows-based computer          1.0         0
# 80       Senior  Android   Windows-based computer          1.0         0
# 81     Freshman  Android  Mac OS X-based computer          2.0         0
# 85     Freshman   iPhone                    Other          1.0         1
# 87       Senior   iPhone  Mac OS X-based computer          1.0         1
# 88       Senior   iPhone  Mac OS X-based computer          1.0         0
# 95     Freshman   iPhone  Mac OS X-based computer          1.0         0
# 99    Sophomore   iPhone  Mac OS X-based computer          1.0         0
# 104   Sophomore   iPhone  Mac OS X-based computer          2.0         0
# 108      Junior   iPhone  Mac OS X-based computer          0.0         0
# 112      Senior   iPhone  Mac OS X-based computer          1.0         1
# 125      Junior   iPhone  Mac OS X-based computer          1.0         1
# 126      Senior   iPhone  Mac OS X-based computer          1.0         0
# 127   Sophomore   iPhone  Mac OS X-based computer          2.0         0
# 133      Junior  Android   Windows-based computer          1.0         1
# 140    Freshman   iPhone                    Other          2.0         1
# 144      Senior   iPhone  Mac OS X-based computer          1.0         0
# 145      Junior   iPhone  Mac OS X-based computer          1.0         1
# 146      Junior   iPhone  Mac OS X-based computer          1.0         1
# 147      Junior   iPhone  Mac OS X-based computer          2.0         1
# 148   Sophomore  Android     Linux-based computer          1.0         0
# 149      Senior   iPhone   Windows-based computer          1.0         1
# 150      Senior   iPhone  Mac OS X-based computer          2.0         1
# 154   Sophomore  Android   Windows-based computer          1.0         1
# 156      Junior   iPhone  Mac OS X-based computer          1.0         0
# 157      Junior   iPhone   Windows-based computer          1.0         0
# 159   Sophomore   iPhone   Windows-based computer          2.0         0
# 160   Sophomore   iPhone   Windows-based computer          1.0         1
# 161      Junior   iPhone  Mac OS X-based computer          NaN         1
# 163   Sophomore   iPhone   Windows-based computer          1.0         0
#
#      Has Cats  Has Fish  Has Chickens     ...       Has Twitch  \
# 0           1         0             0     ...                0
# 1           0         0             0     ...                0
# 5           0         0             0     ...                1
# 6           0         0             0     ...                0
# 9           0         0             0     ...                1
# 11          0         0             0     ...                0
# 13          0         0             0     ...                1
# 14          0         0             0     ...                0
# 16          0         0             0     ...                0
# 19          0         0             0     ...                0
# 20          1         0             0     ...                0
# 21          0         0             0     ...                0
# 26          0         0             0     ...                0
# 27          0         0             0     ...                0
# 30          0         0             0     ...                0
# 33          1         0             0     ...                0
# 34          0         0             0     ...                0
# 37          1         0             0     ...                0
# 38          0         0             0     ...                0
# 40          0         0             0     ...                0
# 41          0         0             0     ...                0
# 43          1         0             0     ...                0
# 46          0         0             0     ...                0
# 48          0         0             0     ...                0
# 52          0         0             0     ...                0
# 54          0         0             0     ...                0
# 57          1         1             1     ...                0
# 58          0         0             0     ...                0
# 61          1         0             0     ...                1
# 63          0         0             0     ...                0
# ..        ...       ...           ...     ...              ...
# 77          0         0             0     ...                1
# 80          0         0             0     ...                0
# 81          0         0             0     ...                0
# 85          1         0             0     ...                0
# 87          0         0             0     ...                0
# 88          0         0             0     ...                0
# 95          1         0             0     ...                0
# 99          1         0             0     ...                0
# 104         0         0             0     ...                0
# 108         0         0             0     ...                0
# 112         0         0             0     ...                0
# 125         0         0             0     ...                0
# 126         0         0             0     ...                1
# 127         0         0             0     ...                0
# 133         0         0             0     ...                0
# 140         0         0             0     ...                0
# 144         0         0             0     ...                0
# 145         1         0             0     ...                0
# 146         0         0             0     ...                0
# 147         0         0             0     ...                0
# 148         0         0             0     ...                1
# 149         1         0             0     ...                0
# 150         1         0             0     ...                0
# 154         1         0             0     ...                1
# 156         0         0             0     ...                0
# 157         0         0             0     ...                0
# 159         0         0             0     ...                0
# 160         0         0             0     ...                1
# 161         0         0             0     ...                0
# 163         1         0             0     ...                0
#
#      Programmed before?                                  Python Background  \
# 0                   Yes  Significant -- I am a wizard when it comes to ...
# 1                   Yes  Some Python -- I have had one class or written...
# 5                   Yes  Some Python -- I have had one class or written...
# 6                   Yes  Some Python -- I have had one class or written...
# 9                   Yes  Some Python -- I have had one class or written...
# 11                  Yes  Some Python -- I have had one class or written...
# 13                  Yes  Some Python -- I have had one class or written...
# 14                  Yes  No Python, but I've done some programming in o...
# 16                  Yes  No Python, but I've done some programming in o...
# 19                  Yes  Some Python -- I have had one class or written...
# 20                  Yes  Significant -- I am a wizard when it comes to ...
# 21                  Yes  No Python, but I've done some programming in o...
# 26                   No  No programming background -- is Python Taylor ...
# 27                  Yes  Significant -- I am a wizard when it comes to ...
# 30                   No  No programming background -- is Python Taylor ...
# 33                   No  No programming background -- is Python Taylor ...
# 34                  Yes  Some Python -- I have had one class or written...
# 37                   No  No programming background -- is Python Taylor ...
# 38                  Yes  Some Python -- I have had one class or written...
# 40                  Yes  Some Python -- I have had one class or written...
# 41                   No  No programming background -- is Python Taylor ...
# 43                  Yes  Some Python -- I have had one class or written...
# 46                   No  No programming background -- is Python Taylor ...
# 48                   No  No programming background -- is Python Taylor ...
# 52                  Yes  Some Python -- I have had one class or written...
# 54                   No  No programming background -- is Python Taylor ...
# 57                  Yes  No Python, but I've done some programming in o...
# 58                  Yes  Some Python -- I have had one class or written...
# 61                  Yes  Some Python -- I have had one class or written...
# 63                  Yes  No Python, but I've done some programming in o...
# ..                  ...                                                ...
# 77                  Yes  Some Python -- I have had one class or written...
# 80                  Yes  Some Python -- I have had one class or written...
# 81                   No  No programming background -- is Python Taylor ...
# 85                   No  No programming background -- is Python Taylor ...
# 87                   No  No programming background -- is Python Taylor ...
# 88                   No  No programming background -- is Python Taylor ...
# 95                   No  No programming background -- is Python Taylor ...
# 99                  Yes  Some Python -- I have had one class or written...
# 104                 Yes  Some Python -- I have had one class or written...
# 108                 Yes  Some Python -- I have had one class or written...
# 112                 Yes  Some Python -- I have had one class or written...
# 125                 Yes  Some Python -- I have had one class or written...
# 126                 Yes  No Python, but I've done some programming in o...
# 127                 Yes  No Python, but I've done some programming in o...
# 133                 Yes  Some Python -- I have had one class or written...
# 140                  No  No programming background -- is Python Taylor ...
# 144                 Yes  Some Python -- I have had one class or written...
# 145                  No  No programming background -- is Python Taylor ...
# 146                 Yes  Some Python -- I have had one class or written...
# 147                 Yes  No Python, but I've done some programming in o...
# 148                 Yes  Some Python -- I have had one class or written...
# 149                  No  No programming background -- is Python Taylor ...
# 150                  No  Some Python -- I have had one class or written...
# 154                 Yes  No Python, but I've done some programming in o...
# 156                  No  No programming background -- is Python Taylor ...
# 157                  No  No Python, but I've done some programming in o...
# 159                 Yes  Some Python -- I have had one class or written...
# 160                 Yes  No Python, but I've done some programming in o...
# 161                  No  No programming background -- is Python Taylor ...
# 163                 Yes  No Python, but I've done some programming in o...
#
#      Statistics Courses Hours Studying  Siblings  Hours of Sleep  Shoes Owned  \
# 0                     2            3.0       2.0             8.0          4.0
# 1                    20            1.0       2.0             7.0         20.0
# 5                     0            3.0       2.0             6.0          4.0
# 6                     1            0.0       2.0             6.0          2.0
# 9                     1            3.0       2.0             8.0          5.0
# 11                    1            2.0       2.0             7.0         20.0
# 13                    3           10.0       2.0             7.0          3.0
# 14                    2            3.0       2.0             7.0          8.0
# 16                    1            6.0       2.0             7.0         12.0
# 19                    2            2.0       2.0             6.0          7.0
# 20                    0            3.0       2.0             8.0          2.0
# 21                    1            2.0       2.0             7.0          NaN
# 26                    0            2.0       2.0             7.0          4.0
# 27                    2            3.0       2.0             7.5          3.0
# 30                    0           10.0       2.0             6.0          4.0
# 33                    0            1.0       3.0             7.0          3.0
# 34                    1            2.0       5.0             8.0         14.0
# 37                    1            2.0       3.0             7.0          5.0
# 38                    1            5.0       2.0             8.0          2.0
# 40                    1           20.0       3.0             8.0         15.0
# 41                    0            2.0       2.0             6.0          3.0
# 43                    1            2.0       2.0             8.0          2.0
# 46                    1            2.0       2.0             8.0          3.0
# 48                    5            4.0       2.0             8.0          5.0
# 52                    2            1.0       2.0             5.0          2.0
# 54                    1            5.0       2.0             6.5         10.0
# 57                    2            3.0       3.0             5.0          3.0
# 58                    2            2.0       2.0             7.0         10.0
# 61                    2            3.0       3.0             8.0          5.0
# 63                    0            3.0       2.0             7.5         35.0
# ..                  ...            ...       ...             ...          ...
# 77                    2            1.0       2.0             8.0          6.0
# 80                    2            4.0       3.0             6.0         10.0
# 81                    1            4.0       2.0             6.0          5.0
# 85                    1            2.0       3.0             7.0          8.0
# 87                    1            2.0       5.0             5.0         20.0
# 88                    0            4.0       4.0             6.0         20.0
# 95                    1            4.0       2.0             7.0         12.0
# 99                    1            4.0       2.0             8.0          6.0
# 104                   1            3.0       2.0             6.0          6.0
# 108                   2            2.0       2.0             7.0          3.0
# 112                   2            3.0       3.0             7.0         12.0
# 125                   1            2.0       2.0             7.0         12.0
# 126                   3           12.0       2.0             7.0          5.0
# 127                   0            3.0       2.0             7.0         20.0
# 133                   2            2.0       2.0             7.0          5.0
# 140                   0            2.0       2.0             8.0          9.0
# 144                   5            2.0       2.0             8.0         12.0
# 145                   1            2.0       2.0             6.0         10.0
# 146                   4            4.0       3.0             7.0         30.0
# 147                   1            2.5       2.0             5.5          8.0
# 148                   1            4.0       2.0            10.0          6.0
# 149                   0            3.0       2.0             7.0         14.0
# 150                   2            5.0       2.0             6.0          4.0
# 154                   0            2.5       2.0             6.0          1.0
# 156                   1            8.0       2.0             7.0          3.0
# 157                   1            2.0       2.0             7.0          3.0
# 159                   0            3.0       3.0             5.0         10.0
# 160                   1            8.0       4.0             8.0         12.0
# 161                   1            2.0       9.0             7.0         30.0
# 163                   0            3.0       2.0             8.0         12.0
#
#      People Texted Yesterday  Personality
# 0                        2.0    Introvert
# 1                       24.0    Extrovert
# 5                       11.0    Introvert
# 6                       74.0    Introvert
# 9                       10.0     Ambivert
# 11                      15.0    Extrovert
# 13                      70.0     Ambivert
# 14                       2.0    Introvert
# 16                      50.0    Extrovert
# 19                      15.0     Ambivert
# 20                      10.0     Ambivert
# 21                      27.0     Ambivert
# 26                       5.0    Introvert
# 27                       3.0    Introvert
# 30                       7.0    Introvert
# 33                      19.0     Ambivert
# 34                      13.0    Introvert
# 37                       9.0     Ambivert
# 38                       4.0     Ambivert
# 40                      20.0    Introvert
# 41                       5.0     Ambivert
# 43                       2.0    Introvert
# 46                       3.0     Ambivert
# 48                       2.0    Introvert
# 52                      25.0    Introvert
# 54                      17.0     Ambivert
# 57                     104.0     Ambivert
# 58                       8.0     Ambivert
# 61                      10.0    Introvert
# 63                      18.0     Ambivert
# ..                       ...          ...
# 77                       9.0     Ambivert
# 80                       8.0    Introvert
# 81                       6.0     Ambivert
# 85                       5.0     Ambivert
# 87                       3.0    Introvert
# 88                       2.0     Ambivert
# 95                      10.0    Introvert
# 99                      26.0     Ambivert
# 104                      7.0    Introvert
# 108                     18.0     Ambivert
# 112                      6.0     Ambivert
# 125                     24.0     Ambivert
# 126                      3.0    Introvert
# 127                     11.0    Extrovert
# 133                      0.0    Extrovert
# 140                      4.0     Ambivert
# 144                     42.0    Introvert
# 145                     25.0    Introvert
# 146                     32.0    Extrovert
# 147                      4.0     Ambivert
# 148                     15.0     Ambivert
# 149                      5.0     Ambivert
# 150                      8.0    Introvert
# 154                      3.0     Ambivert
# 156                      5.0     Ambivert
# 157                     20.0     Ambivert
# 159                     15.0    Extrovert
# 160                    100.0     Ambivert
# 161                     12.0    Extrovert
# 163                     25.0     Ambivert
#
# [65 rows x 31 columns]

# %% [markdown]
# #### 2.3: Selecting equal groups from block1 and block2
#
# **Randomly** select an equal number of students from each of `block1` and `block2` and store them in `control1` and `control2`.  We will combine both groups to make the full control group:

# %%
control1 = block1.sample(n=10)
control1
# Out:
#        Name                             Major School Year     Type  \
# 12     Zayd                     Communication      Senior  Android
# 164    John            Statistics or Business    Freshman   iPhone
# 155  Serena                              Math      Senior   iPhone
# 122   Marni        Speech and hearing science   Sophomore   iPhone
# 113    Alex          Media and Cinema Studies    Freshman   iPhone
# 143  Austin  Computer Science and Linguistics      Junior  Android
# 32      Uma    Molecular and Cellular Biology    Freshman   iPhone
# 128   Eddie                           Finance      Junior   iPhone
# 103    Cole                 Political Science      Junior   iPhone
# 72     Isha                        Psychology    Freshman   iPhone
#
#                     Computer  Straw Holes  Has Dogs  Has Cats  Has Fish  \
# 12   Mac OS X-based computer          2.0         0         1         0
# 164   Windows-based computer          1.0         1         0         0
# 155  Mac OS X-based computer          2.0         0         1         0
# 122  Mac OS X-based computer          1.0         1         0         0
# 113   Windows-based computer          2.0         1         0         0
# 143   Windows-based computer          1.0         0         0         1
# 32   Mac OS X-based computer          1.0         0         0         0
# 128  Mac OS X-based computer          1.0         1         0         0
# 103  Mac OS X-based computer          1.0         1         0         0
# 72    Windows-based computer          2.0         1         0         0
#
#      Has Chickens     ...       Has Twitch  Programmed before?  \
# 12              0     ...                0                  No
# 164             0     ...                1                  No
# 155             0     ...                0                 Yes
# 122             0     ...                0                  No
# 113             0     ...                0                 Yes
# 143             0     ...                1                 Yes
# 32              0     ...                0                 Yes
# 128             0     ...                0                 Yes
# 103             0     ...                1                 Yes
# 72              0     ...                0                 Yes
#
#                                      Python Background  Statistics Courses  \
# 12   No programming background -- is Python Taylor ...                   1
# 164  No programming background -- is Python Taylor ...                   1
# 155  Some Python -- I have had one class or written...                   4
# 122  No programming background -- is Python Taylor ...                   1
# 113  No Python, but I've done some programming in o...                   0
# 143  Significant -- I am a wizard when it comes to ...                   2
# 32   Some Python -- I have had one class or written...                   1
# 128  Some Python -- I have had one class or written...                   1
# 103  No Python, but I've done some programming in o...                   2
# 72   Some Python -- I have had one class or written...                   1
#
#     Hours Studying  Siblings  Hours of Sleep  Shoes Owned  \
# 12             2.0       1.0             7.0          3.0
# 164            1.0       1.0             7.0         12.0
# 155            4.0       0.0             7.0         15.0
# 122            4.0       1.0             7.0         13.0
# 113            0.5       1.0             6.0          3.0
# 143            3.0       1.0             7.0          2.0
# 32             4.0       0.0             7.0          3.0
# 128            4.0       1.0             7.0         14.0
# 103            4.0       1.0             6.0         11.0
# 72             3.0       1.0             8.0         15.0
#
#      People Texted Yesterday  Personality
# 12                       0.0    Extrovert
# 164                     60.0    Introvert
# 155                      5.0     Ambivert
# 122                     24.0    Extrovert
# 113                      3.0    Introvert
# 143                      3.0    Introvert
# 32                       6.0     Ambivert
# 128                     20.0    Extrovert
# 103                      3.0    Introvert
# 72                      10.0    Introvert
#
# [10 rows x 31 columns]

# %%
control2 = block2.sample(n=10)
control2
# Out:
#         Name                              Major School Year     Type  \
# 0       Wade                   Computer Science       Other  Android
# 159   Julisa                        Mathematics   Sophomore   iPhone
# 69       NaN                       Data Science       Other  Android
# 76     Elena  Economics and Information Science   Sophomore   iPhone
# 5      Dhruv                   Computer science   Sophomore  Android
# 133     Mike                        Mathematics      Junior  Android
# 77   Michael                  Actuarial Science      Senior  Android
# 156    Sofia                  Political Science      Junior   iPhone
# 19   Safwaan                          Economics      Senior   iPhone
# 112  Enrique                   Computer Science      Senior   iPhone
#
#                     Computer  Straw Holes  Has Dogs  Has Cats  Has Fish  \
# 0     Windows-based computer          2.0         0         1         0
# 159   Windows-based computer          2.0         0         0         0
# 69    Windows-based computer          2.0         0         0         1
# 76   Mac OS X-based computer          1.0         1         0         0
# 5     Windows-based computer          1.0         0         0         0
# 133   Windows-based computer          1.0         1         0         0
# 77    Windows-based computer          1.0         0         0         0
# 156  Mac OS X-based computer          1.0         0         0         0
# 19   Mac OS X-based computer          1.0         0         0         0
# 112  Mac OS X-based computer          1.0         1         0         0
#
#      Has Chickens     ...       Has Twitch  Programmed before?  \
# 0               0     ...                0                 Yes
# 159             0     ...                0                 Yes
# 69              0     ...                0                 Yes
# 76              0     ...                0                  No
# 5               0     ...                1                 Yes
# 133             0     ...                0                 Yes
# 77              0     ...                1                 Yes
# 156             0     ...                0                  No
# 19              0     ...                0                 Yes
# 112             0     ...                0                 Yes
#
#                                      Python Background  Statistics Courses  \
# 0    Significant -- I am a wizard when it comes to ...                   2
# 159  Some Python -- I have had one class or written...                   0
# 69   Some Python -- I have had one class or written...                   1
# 76   No programming background -- is Python Taylor ...                   1
# 5    Some Python -- I have had one class or written...                   0
# 133  Some Python -- I have had one class or written...                   2
# 77   Some Python -- I have had one class or written...                   2
# 156  No programming background -- is Python Taylor ...                   1
# 19   Some Python -- I have had one class or written...                   2
# 112  Some Python -- I have had one class or written...                   2
#
#     Hours Studying  Siblings  Hours of Sleep  Shoes Owned  \
# 0              3.0       2.0             8.0          4.0
# 159            3.0       3.0             5.0         10.0
# 69             2.0       2.0             8.0          2.0
# 76             2.0       3.0             7.0         10.0
# 5              3.0       2.0             6.0          4.0
# 133            2.0       2.0             7.0          5.0
# 77             1.0       2.0             8.0          6.0
# 156            8.0       2.0             7.0          3.0
# 19             2.0       2.0             6.0          7.0
# 112            3.0       3.0             7.0         12.0
#
#      People Texted Yesterday  Personality
# 0                        2.0    Introvert
# 159                     15.0    Extrovert
# 69                       5.0    Introvert
# 76                       7.0     Ambivert
# 5                       11.0    Introvert
# 133                      0.0    Extrovert
# 77                       9.0     Ambivert
# 156                      5.0     Ambivert
# 19                      15.0     Ambivert
# 112                      6.0     Ambivert
#
# [10 rows x 31 columns]

# %% [markdown]
# #### 2.4. Combine the two sub-groups into a single control group
#
# Use the following code to merge the contents of `control1` and `control2` together into one large group called `control`:

# %%
control = pd.merge(control1, control2, how='outer', on='Siblings')

# %%
## == TEST CASES for Puzzle 2 ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any error our output, you PASSED all test cases!
# - If this cell results in any errors, check you previous cell, make changes, and RE-RUN your code and then this cell.

assert( len(control) == 20 ), "Your control group must only have 20 courses in it."
assert( len(control[control.Siblings < 2] ) == 10 ), "Your control group must only have 10 people with 0-1 siblings in it."
assert( len(control[control.Siblings >= 2] ) == 10 ), "Your control group must only have 10 people with 2+ siblings in it."

# %% [markdown]
# ## 3. Create a treatment group
#
# Let's extend what you did onto a new topic.  Using this week's dataset, the course catalog at Illinois, use Python to create a treatment group of 10 courses, using blocking to control for the influence we suspect being an upper-level course might have.
#
# An upper-level course is a course that has a number course number of 300 or higher.  Make sure you have an equal number of lower-level and upper-level courses in your final treatment group.
#
# You can find the course catalog dataset here: https://docs.google.com/spreadsheets/d/1ZnpZpipyui_zIIBblmalRYiyEG1glUKinqJtQxVL04o/edit#gid=0
#
# You have several cells to work in if you need them.  The only requirement is that your final treatment group must be randomly selected and be stored in the variable `treatment`.

# %%
df2 = pd.read_csv('Illinois Course Catalog.csv')

# %%
low = df2[df2["Number"] < 300]
high = df2[df2["Number"] >= 300]
lowr = low.sample(n=5)
highr = high.sample(n=5)

# %%
# Make sure your final answer is in `treatment`:
treatment = pd.merge(lowr, highr, how='outer', on='Number')
treatment
# Out:
#    Year_x Term_x YearTerm_x Subject_x  Number                        Name_x  \
# 0  2019.0   Fall    2019-fa      YDSH     103        Intermediate Yiddish I
# 1  2019.0   Fall    2019-fa      ENGL     265  Intro to American Indian Lit
# 2  2019.0   Fall    2019-fa      GLBL     228   Terrorism, Past and Present
# 3  2019.0   Fall    2019-fa      GEOG     105             The Digital Earth
# 4  2019.0   Fall    2019-fa      HNDI     199    Undergraduate Open Seminar
# 5     NaN    NaN        NaN       NaN     593                           NaN
# 6     NaN    NaN        NaN       NaN     433                           NaN
# 7     NaN    NaN        NaN       NaN     421                           NaN
# 8     NaN    NaN        NaN       NaN     587                           NaN
# 9     NaN    NaN        NaN       NaN     598                           NaN
#
#                                        Description_x Credit Hours_x  \
# 0  Continuation of YDSH 102. Develops more advanc...       4 hours.
# 1                      Same as AIS 265. See AIS 265.       3 hours.
# 2                    Same as HIST 257. See HIST 257.       3 hours.
# 3  Geospatial technologies such as global positio...       3 hours.
# 4                                   May be repeated.  1 TO 5 hours.
# 5                                                NaN            NaN
# 6                                                NaN            NaN
# 7                                                NaN            NaN
# 8                                                NaN            NaN
# 9                                                NaN            NaN
#
#                                       Section Info_x  \
# 0  Prerequisite: YDSH 102 or equivalent placement...
# 1                                                NaN
# 2                    Same as HIST 257. See HIST 257.
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
#
#                                  Degree Attributes_x  Year_y Term_y  \
# 0                                                NaN     NaN    NaN
# 1  Humanities - Lit & Arts, and Cultural Studies ...     NaN    NaN
# 2                   Humanities - Hist & Phil course.     NaN    NaN
# 3                 Social & Beh Sci - Soc Sci course.     NaN    NaN
# 4                                                NaN     NaN    NaN
# 5                                                NaN  2019.0   Fall
# 6                                                NaN  2019.0   Fall
# 7                                                NaN  2019.0   Fall
# 8                                                NaN  2019.0   Fall
# 9                                                NaN  2019.0   Fall
#
#   YearTerm_y Subject_y                        Name_y  \
# 0        NaN       NaN                           NaN
# 1        NaN       NaN                           NaN
# 2        NaN       NaN                           NaN
# 3        NaN       NaN                           NaN
# 4        NaN       NaN                           NaN
# 5    2019-fa       CWL               Special Studies
# 6    2019-fa      NEUR     Evolutionary Neuroscience
# 7    2019-fa      AFST  Sacred African Diaspora Arts
# 8    2019-fa      LING    Topics in Sociolinguistics
# 9    2019-fa      HDFS      Special Problems in HDFS
#
#                                        Description_y Credit Hours_y  \
# 0                                                NaN            NaN
# 1                                                NaN            NaN
# 2                                                NaN            NaN
# 3                                                NaN            NaN
# 4                                                NaN            NaN
# 5                                                NaN  1 TO 4 hours.
# 6  Same as IB 436, PHIL 433 and PSYC 433. See PSY...  3 OR 4 hours.
# 7                    Same as ARTH 413. See ARTH 413.  3 OR 4 hours.
# 8  Discussion of current topics in sociolinguisti...       4 hours.
# 9  Research or independent study on a special pro...  1 TO 4 hours.
#
#                                       Section Info_y Degree Attributes_y
# 0                                                NaN                 NaN
# 1                                                NaN                 NaN
# 2                                                NaN                 NaN
# 3                                                NaN                 NaN
# 4                                                NaN                 NaN
# 5                                                NaN                 NaN
# 6  Same as IB 436, PHIL 433 and PSYC 433. See PSY...                 NaN
# 7                                                NaN                 NaN
# 8                                                NaN                 NaN
# 9  1 to 4 graduate hours. No professional credit....                 NaN

# %%
## == TEST CASES for Puzzle 3 ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any error our output, you PASSED all test cases!
# - If this cell results in any errors, check you previous cell, make changes, and RE-RUN your code and then this cell.

assert( len(treatment) == 10 ), "Your treatment group must only have 10 courses in it."
assert( len(treatment[treatment.Number < 300] ) == 5 ), "Your treatment group must only have 5 lower-level courses in it."
assert( len(treatment[treatment.Number >= 300] ) == 5 ), "Your treatment group must only have 5 upper-level courses in it."

# %% [markdown]
# ## Submit Your Work!
#
# Make sure to **Save and Checkpoint** your notebook, exit Jupyter, and submit your work! :)
