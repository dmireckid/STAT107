# %% [markdown]
# # EC Notebook for Lecture 3: Ideal Experimental Design + Row Selection
#
# This extra credit Python notebook will let you practice the material you saw in lecture!  Completing all parts of this notebook will earn +1 extra credit point to your grade in STAT 107!
#
# This notebook is due at 11:30am on **Wednesday, Sept. 4** *(30 minutes before the next STAT 107 lecture)*.

# %% [markdown]
# ## 1. Import the `pandas` library as `pd`
#
# Using the code you learned in class, import the pandas library:

# %%
import pandas as pd

# %%
## == TEST CASES ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any error our output, you PASSED all test cases!
# - If this cell results in any errors, check you previous cell, make changes, and RE-RUN your code and then this cell.

# Test #1:
# - This uses the `pd` (pandas) library to create a DataFrame.  This line will fail if `pd` has not been imported:
result = pd.DataFrame()

# %% [markdown]
# ## 2. Load the "Hello Dataset"
#
# As part of the first lecture, we created a dataset for this course!
#
# 1. The dataset can be found here: https://docs.google.com/spreadsheets/d/1LB4E89GoVi5yezEfHhopbI5BMxodSG7VvoznkaAkMAQ/edit#gid=0
#
#
# 2. Download the dataset as a CSV:
#
#   * In lecture you learned that Comma-Separated Values (CSV) files are an easy format for Data Science tools like Python to read.
#   * Use the **File -> Download** menu to choose the format you want to download your data in from Google Sheets.
#   * Once downloaded, move the file from your "Downloads" to the same directory as this Python Notebook.  If you use the recommended file location, the location will be: **Your Desktop -> stat107 -> netid -> ec3**.
#
#
# 3. Run the next cell to load the dataset into Python into the variable name `df`.
#
#   * The file name you are loading must **EXACTLY MATCH** the file name on your computer, including capitalization.  You will need to edit the code (or the downloaded file name) so the file name matches.

# %%
df = pd.read_csv('hello dataset.csv')

# %%
## == TEST CASES ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any error our output, you PASSED all test cases!
# - If this cell results in any errors, check you previous cell, make changes, and RE-RUN your code and then this cell.

# Ensure `Wade` exists somewhere in the data:
assert(df[ df.Name == 'Wade' ].Name.values[0] == 'Wade'), "No row is found that contains `Wade`.  Did you import the right dataset?"

# Ensure `Karle` exists somewhere in the data:
assert(df[ df.Name == 'Karle' ].Name.values[0] == 'Karle'), "No row is found that contains `Karle`.  Did you import the right dataset?"

# %% [markdown]
# ## 3. Extra Credit Problems
#
# ### Puzzle 3.1: A Data Science pill
#
# In lecture, you learned that Karle and Wade created a new pill that they think will help make students EXPERT Python programmers.  Before distributing this pill, they need to do an experiment to see if it actually works.  Assume everyone in the class has given permission to be involved in the experiment, but we can only accommodate **80** people.  Use Python to take a random sample of 80 students from the class and store it in the variable named `df_80`.

# %%
df_80 = df.sample(n=80)
df_80
# Out:
#            Name                                Major School Year     Type  \
# 17        Yijie         Computer Science+Mathematics    Freshman  Android
# 90      Stephen        Psychology & Computer Science    Freshman  Android
# 1         Karle                           Statistics       Other   iPhone
# 29       Eugene        Statistics + Computer Science    Freshman   iPhone
# 20         Matt                                 Math      Junior   iPhone
# 10        Taige                            Math + CS    Freshman   iPhone
# 28        Chloe               Structural Engineering      Junior   iPhone
# 45          Leo                                  CS?    Freshman   iPhone
# 142       Jason                              History      Senior  Android
# 95       Nicole                    Political Science    Freshman   iPhone
# 33         Nick                    Political Science    Freshman  Android
# 3      Jonathan                    Political Science      Senior   iPhone
# 135      Gargee                          mathematics   Sophomore   iPhone
# 50       Ilisha                           Psychology      Junior   iPhone
# 57          Ian  Actuarial Science, Computer Science   Sophomore   iPhone
# 108      Satori                    Industrial Design      Junior   iPhone
# 83         Maya                       Communications   Sophomore   iPhone
# 4         Clare                           Statistics   Sophomore   iPhone
# 60        Yijia                           statistics   Sophomore   iPhone
# 100       Carol                            Fine Arts      Junior   iPhone
# 118       Mendy                    Political Science    Freshman   iPhone
# 30    Folashade                    Political Science   Sophomore   iPhone
# 86    Catherine      Statistics and Computer Science   Sophomore   iPhone
# 9    Edward/Edd          CS, business data analysis?      Senior  Android
# 129       Miles                                  GIS      Senior   iPhone
# 89         Iris                      Agri-accounting      Senior   iPhone
# 68      Amartya                         Astrophysics    Freshman  Android
# 107         Ran                          Mathematics      Junior   iPhone
# 154       David                 Information Sciences   Sophomore  Android
# 70          Jie                              Biology    Freshman   iPhone
# ..          ...                                  ...         ...      ...
# 59       Qichao                 Computer engineering      Senior   iPhone
# 97        Oscar            Engineering CS or Math&CS    Freshman   iPhone
# 85        Olive                      Theatre Studies    Freshman   iPhone
# 137       Irene                           Statistics      Junior   iPhone
# 139     Jiaming                              Math+CS   Sophomore   iPhone
# 67        Vivek                     Computer science   Sophomore   iPhone
# 41      Michael                     Computer Science    Freshman   iPhone
# 115       Dhruv                           Statistics      Junior   iPhone
# 81         Rami                           Psychology    Freshman  Android
# 117      Ashley                    Actuarial Science   Sophomore   iPhone
# 162       Cindy               biomedical engineering      Senior  Android
# 76        Elena    Economics and Information Science   Sophomore   iPhone
# 114        Seth                              Finance      Senior   iPhone
# 120      Sumedh      Statistics and Computer Science    Freshman  Android
# 44       Andrew                            CS + STAT      Junior   iPhone
# 51     Zhoutian                 Computer Engineering    Freshman   iPhone
# 69          NaN                         Data Science       Other  Android
# 122       Marni           Speech and hearing science   Sophomore   iPhone
# 16      Natasha      Computer Science and Philosophy    Freshman   iPhone
# 157       Donny                 Information Sciences      Junior   iPhone
# 165      Anisha                                  Mcb      Junior   iPhone
# 98      Yiqiang                    Political Science       Other   iPhone
# 82         Tian                        data analysis    Freshman   iPhone
# 126     Jaesung                            Economics      Senior   iPhone
# 8       Natalia                           Psychology    Freshman   iPhone
# 77      Michael                    Actuarial Science      Senior  Android
# 61        Tyler                    actuarial science    Freshman  Android
# 128       Eddie                              Finance      Junior   iPhone
# 55        Shubh      Computer Science and Statistics   Sophomore  Android
# 145      Connor                          Advertising      Junior   iPhone
#
#                     Computer  Straw Holes  Has Dogs  Has Cats  Has Fish  \
# 17   Mac OS X-based computer          2.0         0         0         0
# 90   Mac OS X-based computer          2.0         1         1         0
# 1    Mac OS X-based computer          1.0         0         0         0
# 29   Mac OS X-based computer          2.0         0         0         0
# 20   Mac OS X-based computer          1.0         0         1         0
# 10    Windows-based computer          1.0         0         1         0
# 28   Mac OS X-based computer          1.0         0         0         1
# 45    Windows-based computer          1.0         0         0         1
# 142   Windows-based computer          1.0         1         0         0
# 95   Mac OS X-based computer          1.0         0         1         0
# 33    Windows-based computer          1.0         1         1         0
# 3    Mac OS X-based computer          1.0         1         1         0
# 135  Mac OS X-based computer          2.0         0         0         0
# 50   Mac OS X-based computer          2.0         0         0         0
# 57   Mac OS X-based computer          1.0         1         1         1
# 108  Mac OS X-based computer          0.0         0         0         0
# 83   Mac OS X-based computer          1.0         1         0         0
# 4    Mac OS X-based computer          1.0         1         0         0
# 60    Windows-based computer         20.0         1         0         0
# 100   Windows-based computer          1.0         0         0         1
# 118  Mac OS X-based computer          1.0         0         0         1
# 30   Mac OS X-based computer          1.0         0         0         0
# 86    Windows-based computer          1.0         0         0         0
# 9       Linux-based computer          1.0         0         0         0
# 129   Windows-based computer          0.0         1         1         0
# 89   Mac OS X-based computer          1.0         1         1         0
# 68    Windows-based computer          1.0         0         0         0
# 107  Mac OS X-based computer          1.0         0         0         0
# 154   Windows-based computer          1.0         1         1         0
# 70   Mac OS X-based computer          1.0         1         0         0
# ..                       ...          ...       ...       ...       ...
# 59   Mac OS X-based computer          1.0         0         0         0
# 97    Windows-based computer          1.0         0         0         0
# 85                     Other          1.0         1         1         0
# 137  Mac OS X-based computer          1.0         1         0         0
# 139  Mac OS X-based computer          2.0         0         0         0
# 67    Windows-based computer          2.0         0         0         1
# 41   Mac OS X-based computer          4.0         1         0         0
# 115   Windows-based computer          1.0         0         0         0
# 81   Mac OS X-based computer          2.0         0         0         0
# 117  Mac OS X-based computer          1.0         1         0         0
# 162   Windows-based computer          1.0         1         0         0
# 76   Mac OS X-based computer          1.0         1         0         0
# 114   Windows-based computer          1.0         1         0         0
# 120   Windows-based computer          2.0         0         0         0
# 44    Windows-based computer          1.0         1         1         0
# 51    Windows-based computer          1.0         0         0         1
# 69    Windows-based computer          2.0         0         0         1
# 122  Mac OS X-based computer          1.0         1         0         0
# 16   Mac OS X-based computer          1.0         0         0         0
# 157   Windows-based computer          1.0         0         0         0
# 165  Mac OS X-based computer          1.0         0         0         0
# 98   Mac OS X-based computer          1.0         1         0         0
# 82   Mac OS X-based computer          1.0         1         0         0
# 126  Mac OS X-based computer          1.0         0         0         0
# 8                      Other          1.0         0         0         0
# 77    Windows-based computer          1.0         0         0         0
# 61    Windows-based computer          1.0         1         1         0
# 128  Mac OS X-based computer          1.0         1         0         0
# 55   Mac OS X-based computer          2.0         0         0         0
# 145  Mac OS X-based computer          1.0         1         1         0
#
#      Has Chickens     ...       Has Twitch  Programmed before?  \
# 17              0     ...                0                 Yes
# 90              0     ...                1                 Yes
# 1               0     ...                0                 Yes
# 29              0     ...                0                 Yes
# 20              0     ...                0                 Yes
# 10              0     ...                1                 Yes
# 28              0     ...                0                 Yes
# 45              0     ...                1                 Yes
# 142             0     ...                1                 Yes
# 95              0     ...                0                  No
# 33              0     ...                0                  No
# 3               0     ...                0                 Yes
# 135             0     ...                0                 Yes
# 50              0     ...                0                 Yes
# 57              1     ...                0                 Yes
# 108             0     ...                0                 Yes
# 83              0     ...                0                  No
# 4               0     ...                0                 Yes
# 60              0     ...                0                  No
# 100             0     ...                0                 Yes
# 118             0     ...                0                 Yes
# 30              0     ...                0                  No
# 86              0     ...                0                 Yes
# 9               0     ...                1                 Yes
# 129             1     ...                1                 Yes
# 89              0     ...                0                 Yes
# 68              0     ...                0                 Yes
# 107             0     ...                0                  No
# 154             0     ...                1                 Yes
# 70              0     ...                0                  No
# ..            ...     ...              ...                 ...
# 59              0     ...                0                 Yes
# 97              0     ...                0                 Yes
# 85              0     ...                0                  No
# 137             0     ...                0                 Yes
# 139             0     ...                0                 Yes
# 67              0     ...                1                 Yes
# 41              0     ...                0                  No
# 115             0     ...                0                 Yes
# 81              0     ...                0                  No
# 117             0     ...                0                 Yes
# 162             0     ...                0                  No
# 76              0     ...                0                  No
# 114             0     ...                0                 Yes
# 120             0     ...                0                 Yes
# 44              0     ...                1                 Yes
# 51              0     ...                1                 Yes
# 69              0     ...                0                 Yes
# 122             0     ...                0                  No
# 16              0     ...                0                 Yes
# 157             0     ...                0                  No
# 165             0     ...                0                 Yes
# 98              0     ...                0                 Yes
# 82              0     ...                0                  No
# 126             0     ...                1                 Yes
# 8               0     ...                0                  No
# 77              0     ...                1                 Yes
# 61              0     ...                1                 Yes
# 128             0     ...                0                 Yes
# 55              0     ...                0                 Yes
# 145             0     ...                0                  No
#
#                                      Python Background  Statistics Courses  \
# 17   Some Python -- I have had one class or written...                   0
# 90   Some Python -- I have had one class or written...                   0
# 1    Some Python -- I have had one class or written...                  20
# 29   Some Python -- I have had one class or written...                   0
# 20   Significant -- I am a wizard when it comes to ...                   0
# 10   Some Python -- I have had one class or written...                   4
# 28   Some Python -- I have had one class or written...                   1
# 45   Some Python -- I have had one class or written...                   0
# 142  Some Python -- I have had one class or written...                   1
# 95   No programming background -- is Python Taylor ...                   1
# 33   No programming background -- is Python Taylor ...                   0
# 3    No Python, but I've done some programming in o...                   2
# 135  Some Python -- I have had one class or written...                   2
# 50   Some Python -- I have had one class or written...                   2
# 57   No Python, but I've done some programming in o...                   2
# 108  Some Python -- I have had one class or written...                   2
# 83   No programming background -- is Python Taylor ...                   1
# 4    Some Python -- I have had one class or written...                   1
# 60   No programming background -- is Python Taylor ...                   1
# 100  Some Python -- I have had one class or written...                   2
# 118  No Python, but I've done some programming in o...                   1
# 30   No programming background -- is Python Taylor ...                   0
# 86   No Python, but I've done some programming in o...                   3
# 9    Some Python -- I have had one class or written...                   1
# 129  Some Python -- I have had one class or written...                   1
# 89   Some Python -- I have had one class or written...                   2
# 68   Some Python -- I have had one class or written...                   1
# 107  No Python, but I've done some programming in o...                   1
# 154  No Python, but I've done some programming in o...                   0
# 70   No programming background -- is Python Taylor ...                   1
# ..                                                 ...                 ...
# 59   Some Python -- I have had one class or written...                   3
# 97   No Python, but I've done some programming in o...                   1
# 85   No programming background -- is Python Taylor ...                   1
# 137  Some Python -- I have had one class or written...                   3
# 139  Some Python -- I have had one class or written...                   1
# 67   Some Python -- I have had one class or written...                   0
# 41   No programming background -- is Python Taylor ...                   0
# 115  No Python, but I've done some programming in o...                   3
# 81   No programming background -- is Python Taylor ...                   1
# 117  No Python, but I've done some programming in o...                   0
# 162  No Python, but I've done some programming in o...                   1
# 76   No programming background -- is Python Taylor ...                   1
# 114  Some Python -- I have had one class or written...                   2
# 120  Significant -- I am a wizard when it comes to ...                   1
# 44   No Python, but I've done some programming in o...                   4
# 51   No Python, but I've done some programming in o...                   1
# 69   Some Python -- I have had one class or written...                   1
# 122  No programming background -- is Python Taylor ...                   1
# 16   No Python, but I've done some programming in o...                   1
# 157  No Python, but I've done some programming in o...                   1
# 165  Some Python -- I have had one class or written...                   1
# 98   No Python, but I've done some programming in o...                   2
# 82   No programming background -- is Python Taylor ...                   1
# 126  No Python, but I've done some programming in o...                   3
# 8    No programming background -- is Python Taylor ...                   1
# 77   Some Python -- I have had one class or written...                   2
# 61   Some Python -- I have had one class or written...                   2
# 128  Some Python -- I have had one class or written...                   1
# 55   No Python, but I've done some programming in o...                   1
# 145  No programming background -- is Python Taylor ...                   1
#
#     Hours Studying  Siblings  Hours of Sleep  Shoes Owned  \
# 17             4.0       0.0             7.0         10.0
# 90            10.0       0.0             7.5          2.0
# 1              1.0       2.0             7.0         20.0
# 29             2.5       NaN             7.5          5.0
# 20             3.0       2.0             8.0          2.0
# 10             3.0       0.0             6.0          6.0
# 28             7.0       0.0             8.0          6.0
# 45             3.0       1.0             8.5          3.0
# 142            1.0       1.0             7.0          2.0
# 95             4.0       2.0             7.0         12.0
# 33             1.0       3.0             7.0          3.0
# 3              4.0       1.0             6.0         10.0
# 135            4.0       1.0             7.0         11.0
# 50             3.0       1.0             7.0         10.0
# 57             3.0       3.0             5.0          3.0
# 108            2.0       2.0             7.0          3.0
# 83             1.0       1.0             8.0         15.0
# 4              4.0       0.0             8.0         20.0
# 60            10.0       1.0             6.0          2.0
# 100            3.0       0.0             8.0         10.0
# 118            0.5       1.0             7.0          7.0
# 30            10.0       2.0             6.0          4.0
# 86             5.0       1.0             7.0         10.0
# 9              3.0       2.0             8.0          5.0
# 129            1.0       0.0             7.0          3.0
# 89             2.0       0.0             8.0         20.0
# 68             3.0       1.0             7.0          4.0
# 107            8.0       0.0             7.0          7.0
# 154            2.5       2.0             6.0          1.0
# 70             3.0       1.0             7.0          5.0
# ..             ...       ...             ...          ...
# 59             6.0       0.0             7.0          7.0
# 97             5.0       1.0             7.0          5.0
# 85             2.0       3.0             7.0          8.0
# 137            2.0       1.0             7.0         10.0
# 139            6.0       0.0             7.0         10.0
# 67             3.0       1.0             6.0          4.0
# 41             2.0       2.0             6.0          3.0
# 115            4.0       1.0             6.0          4.0
# 81             4.0       2.0             6.0          5.0
# 117            4.0       0.0             6.0          8.0
# 162            2.0       1.0             8.0          3.0
# 76             2.0       3.0             7.0         10.0
# 114            3.0       1.0             7.0          8.0
# 120            5.0       1.0             7.0          5.0
# 44             4.0       1.0             5.0          2.0
# 51             9.0       0.0             7.0          6.0
# 69             2.0       2.0             8.0          2.0
# 122            4.0       1.0             7.0         13.0
# 16             6.0       2.0             7.0         12.0
# 157            2.0       2.0             7.0          3.0
# 165            4.0       1.0             7.0          6.0
# 98             8.0       0.0             7.0          4.0
# 82             3.0       0.0             8.0         17.0
# 126           12.0       2.0             7.0          5.0
# 8              4.0       1.0             7.0          5.0
# 77             1.0       2.0             8.0          6.0
# 61             3.0       3.0             8.0          5.0
# 128            4.0       1.0             7.0         14.0
# 55             2.0       1.0             7.0          7.0
# 145            2.0       2.0             6.0         10.0
#
#      People Texted Yesterday  Personality
# 17                      10.0     Ambivert
# 90                       8.0    Introvert
# 1                       24.0    Extrovert
# 29                       2.0    Introvert
# 20                      10.0     Ambivert
# 10                      15.0    Introvert
# 28                       5.0    Introvert
# 45                      20.0     Ambivert
# 142                      1.0    Introvert
# 95                      10.0    Introvert
# 33                      19.0     Ambivert
# 3                        8.0    Introvert
# 135                     20.0    Extrovert
# 50                      31.0     Ambivert
# 57                     104.0     Ambivert
# 108                     18.0     Ambivert
# 83                      18.0    Extrovert
# 4                       30.0     Ambivert
# 60                       5.0    Introvert
# 100                      6.0     Ambivert
# 118                      7.0     Ambivert
# 30                       7.0    Introvert
# 86                       9.0     Ambivert
# 9                       10.0     Ambivert
# 129                     10.0     Ambivert
# 89                      10.0     Ambivert
# 68                       4.0    Introvert
# 107                      4.0     Ambivert
# 154                      3.0     Ambivert
# 70                       NaN     Ambivert
# ..                       ...          ...
# 59                       9.0     Ambivert
# 97                      15.0     Ambivert
# 85                       5.0     Ambivert
# 137                     10.0     Ambivert
# 139                     10.0     Ambivert
# 67                      30.0    Extrovert
# 41                       5.0     Ambivert
# 115                     14.0     Ambivert
# 81                       6.0     Ambivert
# 117                     15.0    Introvert
# 162                      8.0     Ambivert
# 76                       7.0     Ambivert
# 114                     12.0     Ambivert
# 120                      7.0     Ambivert
# 44                       2.0     Ambivert
# 51                       6.0     Ambivert
# 69                       5.0    Introvert
# 122                     24.0    Extrovert
# 16                      50.0    Extrovert
# 157                     20.0     Ambivert
# 165                     15.0    Introvert
# 98                       3.0     Ambivert
# 82                       9.0     Ambivert
# 126                      3.0    Introvert
# 8                        4.0     Ambivert
# 77                       9.0     Ambivert
# 61                      10.0    Introvert
# 128                     20.0    Extrovert
# 55                      12.0     Ambivert
# 145                     25.0    Introvert
#
# [80 rows x 31 columns]

# %%
## == TEST CASES ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any error our output, you PASSED all test cases!
# - If this cell results in any errors, check you previous cell, make changes, and RE-RUN your code and then this cell.


# Ensure df_80 has exactly 80 observations (rows)
assert(len(df_80) == 80), 'The variable `df_80` does not have exactly 80 observations/rows (it has ' + str(len(df_80)) + ' rows).'

# Ensure df_80 does not contain only the first 80 rows
full_match = True
for i in range(0, 80):
    if df_80.index[i] != i:
        full_match = False
        break
        
assert(full_match == False), 'The variable `df_80` contains the FIRST 80 observations/rows.  Make sure to make a RANDOM selection of the 80 rows.'

# %% [markdown]
# ### Puzzle 3.2: Finding Ten Winners
#
# Suppose a contest is held in Data Science Discovery and we need to pick **ten (10) winners at random**.  Use Python to find 10 winners at random and store those winners in the variable `winners`.

# %%
winners = df.sample(n=10)
winners
# Out:
#           Name                            Major School Year     Type  \
# 130     Alison             Computer Engineering      Senior   iPhone
# 29      Eugene    Statistics + Computer Science    Freshman   iPhone
# 5        Dhruv                 Computer science   Sophomore  Android
# 15       Jinda                 Computer Science       Other   iPhone
# 86   Catherine  Statistics and Computer Science   Sophomore   iPhone
# 123    Gautham                      Mathematics      Junior  Android
# 154      David             Information Sciences   Sophomore  Android
# 110       Amey                 Computer Science    Freshman   iPhone
# 92        Yena                      Mathematics    Freshman   iPhone
# 93        Teju  computer science and statistics      Junior   iPhone
#
#                     Computer  Straw Holes  Has Dogs  Has Cats  Has Fish  \
# 130  Mac OS X-based computer          0.0         0         0         0
# 29   Mac OS X-based computer          2.0         0         0         0
# 5     Windows-based computer          1.0         0         0         0
# 15   Mac OS X-based computer          1.0         0         0         0
# 86    Windows-based computer          1.0         0         0         0
# 123   Windows-based computer          0.0         1         0         0
# 154   Windows-based computer          1.0         1         1         0
# 110  Mac OS X-based computer          1.0         0         0         1
# 92   Mac OS X-based computer          1.0         1         0         0
# 93   Mac OS X-based computer          1.0         1         0         0
#
#      Has Chickens     ...       Has Twitch  Programmed before?  \
# 130             0     ...                0                 Yes
# 29              0     ...                0                 Yes
# 5               0     ...                1                 Yes
# 15              0     ...                0                 Yes
# 86              0     ...                0                 Yes
# 123             0     ...                0                 Yes
# 154             0     ...                1                 Yes
# 110             0     ...                0                 Yes
# 92              0     ...                0                  No
# 93              0     ...                0                 Yes
#
#                                      Python Background  Statistics Courses  \
# 130  Some Python -- I have had one class or written...                   0
# 29   Some Python -- I have had one class or written...                   0
# 5    Some Python -- I have had one class or written...                   0
# 15   Some Python -- I have had one class or written...                   2
# 86   No Python, but I've done some programming in o...                   3
# 123  Some Python -- I have had one class or written...                   3
# 154  No Python, but I've done some programming in o...                   0
# 110  No Python, but I've done some programming in o...                   1
# 92   Some Python -- I have had one class or written...                   1
# 93   No Python, but I've done some programming in o...                   4
#
#     Hours Studying  Siblings  Hours of Sleep  Shoes Owned  \
# 130            6.0       1.0             6.0         10.0
# 29             2.5       NaN             7.5          5.0
# 5              3.0       2.0             6.0          4.0
# 15            12.0       0.0             7.0          4.0
# 86             5.0       1.0             7.0         10.0
# 123            5.0       1.0             7.0          4.0
# 154            2.5       2.0             6.0          1.0
# 110            3.0       1.0             8.0          6.0
# 92             3.0       1.0             6.0          5.0
# 93             3.0       1.0             8.0          8.0
#
#      People Texted Yesterday  Personality
# 130                     12.0     Ambivert
# 29                       2.0    Introvert
# 5                       11.0    Introvert
# 15                     100.0     Ambivert
# 86                       9.0     Ambivert
# 123                      4.0    Introvert
# 154                      3.0     Ambivert
# 110                     20.0     Ambivert
# 92                      13.0    Introvert
# 93                       5.0    Introvert
#
# [10 rows x 31 columns]

# %%
## == TEST CASES ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any error our output, you PASSED all test cases!
# - If this cell results in any errors, check you previous cell, make changes, and RE-RUN your code and then this cell.

# Ensure `winners` has exactly 10 observations (rows)
assert(len(winners) == 10), 'The variable `winners` does not have exactly 10 observations/rows (it has ' + str(len(winners)) + ' rows).'

# Ensure `winners` does not contain only the first 10 rows
full_match = True
for i in range(0, 10):
    if winners.index[i] != i:
        full_match = False
        break
        
assert(full_match == False), 'The variable `winners` contains the FIRST 10 observations/rows.  Make sure to make a RANDOM selection of the 10 rows.'

# %% [markdown]
# ### Puzzle 3.3:
#
# Take a look at the list of winners from the previous puzzle and **re-run** the cell (Shift+Enter).  Double click this cell
# to answer the next question:
#
# - Do the winners change each time you run it?
#
#     Yes, they change each time I re-run the cell.

# %% [markdown]
# ## 4. Submit Your Work
#
# In this notebook:
#
# 1. Click **File** -> **Save and Checkpoint** (to save your work)
# 2. Click **File** -> **Close and Halt** (to exit this notebook)
#
# Follow the instructions on the STAT 107 website to submit your work.
