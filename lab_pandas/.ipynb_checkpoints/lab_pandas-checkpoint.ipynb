# %% [markdown]
# # lab_pandas
#
# Hi Data Scientists,
#
# Welcome to the second lab!  In this lab, you will explore **data types** in Python and learn the first tool of Data Science -- `pandas`.  As you go through the lab:
#
# - Make sure to run every cell with Python code and observe the output
# - Complete all puzzles and submit this lab before Monday evening at 11:59pm
#
#
# ### Labs are Collabrative
#
# In your lab section (right now!), find a person or two around you and form a group.  Work on this together, making sure all of you understand each component of the lab.
#
#
# ### Getting Help
#
# Remember, there are a lot of ways to get help if you find yourself stuck:
#
# 1. In lab section, your TA, CAs, and your peers are here for you!
#
#
# 2. On the course Piazza page: https://piazza.com/illinois/fall2019/stat107
#
#
# 3. Office Hours:
#
#   - Open office hours **every Monday, Wednesday, Thursday, and Friday** from 4:00pm - 6:30pm in 23 Illini Hall
#
#   - Prof. Wade + Prof. Karle are available every Wednesday from 8:30am - 10:00am in 2215 Siebel Center

# %% [markdown]
# ## Part 1: Data Types
#
# In Python, data must be stored as a **number** (without quotes), as a **string** (text with quotes), or as some **other type**.  Every piece of data in Python will have three **features**:
#
# 1. A **name** *(this is what we refer to it by)*
# 2. A **value** *(this is the value is stores)*
# 3. A **data type** *(this is the format that the data is stored)*

# %% [markdown]
# ### Example: Data Types
#
# Run the following line that creates the name `seconds_in_a_minute`:

# %%
seconds_in_a_minute = 60 * 60
seconds_in_a_minute
# Out:
# 3600

# %% [markdown]
# The features of `seconds_in_a_minute` are the following:
#
# - The **name** is `seconds_in_a_minute`
# - The **value** of `seconds_in_a_minute` is `3600`
# - The **data type** of `seconds_in_a_minute` is a **number**

# %% [markdown]
# ### Puzzle 1.1: Your Name
# #### Puzzle 1.1a: Creating Your Name
#
# Modify the following cell of Python to replace `...` with your name:
#
# - Remember, because your name is a **string**, you will need to use quotes (`'`...`'`)

# %%
my_name = "Damian"
my_name
# Out:
# 'Damian'

# %%
## == TEST CASES for Puzzle 1.1 ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any error our output, you PASSED all test cases!
# - If this cell results in any errors, check you previous cell, make changes, and RE-RUN your code and then this cell.

assert(type(my_name) == type('string')), 'It looks like your name is not a string.  Make sure to assign your name.'

# %% [markdown]
# #### Puzzle 1.1b: Features of `my_name`
#
# Modify the following cell of to replace ... with the correct features about `my_name`.  (This is a text cell, so we won't see the results until we grade it later.)

# %% [markdown]
# - The **name** is my_name
# - The **value** of `my_name` is "Damian"
# - The **data type** of `my_name` is a string

# %% [markdown]
# ### Puzzle 1.2: The Current Year
#
# #### Puzzle 1.2a: Creating `current_year`
#
# Modify the following cell of Python to replace `...` with the current year (as a **number**):

# %%
current_year = 2019
current_year
# Out:
# 2019

# %%
## == TEST CASES for Puzzle 1.2 ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any error our output, you PASSED all test cases!
# - If this cell results in any errors, check you previous cell, make changes, and RE-RUN your code and then this cell.

assert(type(current_year) == type(2019)), 'It looks like your name is not a number.  Make sure to assign the year as a number.'

# %% [markdown]
# #### Puzzle 1.2b: Features of `current_year`
#
# Modify the following cell of to replace ... with the correct features about `current_year`:

# %% [markdown]
# - The **name** is current_year
# - The **value** of `current_year` is 2019
# - The **data type** of `current_year` is a number

# %% [markdown]
# ### Review: Operations on Numbers
#
# Last week, you used the **add** (`+`) operation to add two **numbers** together.  For example:

# %%
eleven = 4 + 7
eleven
# Out:
# 11

# %% [markdown]
# You also can use **subtraction** (`-`), **multiplication** (`*`), **division** (`/`), and you can **raise a number to a power** (`**`):

# %%
fiftyfive = 100 - 45
print(fiftyfive)

sixteen = 8 * 2
print(sixteen)

two = 6 / 3
print(two)

eight = 2 ** 3
print(eight)
# Out:
# 55
# 16
# 2.0
# 8

# %% [markdown]
# A few things you may have noticed:
# - We used `print()` again this week, allowing us to output values that are not the last line of code!
# - The result of `two` is `2.0`, a non-whole number!  There are two different types of numbers: **integers** (whole numbers) and **floating point numbers** (numbers with a decimal).  We will explore these in the next part of this lab!

# %% [markdown]
# ### Concatenating Strings
#
# In Python, you join two **strings** together with the same `+` operation you used with **numbers**.  For example, we can join `'Hello'` and `'World'` together:

# %%
print('Hello' + 'World')
# Out:
# HelloWorld

# %% [markdown]
# ...that's a little awkward.  Let's add a space together to join three strings together:

# %%
print('Hello' + ' ' + 'World')
# Out:
# Hello World

# %% [markdown]
# When we join strings together, we do **NOT** say that we are **adding** strings together.  We **add** numbers together.  Instead, this operation of joining two or more strings is called **concatenation** *(concatenation literally means "the action of linking things together in a series")*.
#
# ### Puzzle 1.3:
#
# Instead of `'Hello World'`, modify the value in `hello` to say hello **to you** by using `my_name` you created earlier in this lab:

# %%
# Modify this Python to say 'Hello ___', where ___ is your name.
# - Use `my_name` you created earlier.

hello = 'Hello' + ' ' + my_name
print(hello)
# Out:
# Hello Damian

# %%
## == TEST CASES for Puzzle 1.3 ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any error our output, you PASSED all test cases!
# - If this cell results in any errors, check you previous cell, make changes, and RE-RUN your code and then this cell.

assert(hello == 'Hello ' + my_name), "Your string `hello` is not saying hi to yourself. :("

# %% [markdown]
# ### Puzzle 1.4:
#
# Let's wish the current year (2019) hello as well!  Modify the following code to print hello **to the current year** using `current_year` you created earlier in this lab:
#
# - If you do this corretly, **you will see an error** -- an error is the expected result!!

# %%
# Modify this Python to say "Hello 2019", where 2019 is the current year.
# - Use `current_year` you created earlier.
print('Hello' + ' ' + current_year)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-c6234e68da70> in <module>()
#       1 # Modify this Python to say "Hello 2019", where 2019 is the current year.
#       2 # - Use `current_year` you created earlier.
# ----> 3 print('Hello' + ' ' + current_year)
#
# TypeError: must be str, not int

# %% [markdown]
# If you used `current_year`, Python will be confused and give you the following error:
#
# ![TypeError: can only concatenate str to str](img/error-cannot-concat.png)
#
# The text of the error tells us something about Python:
#
# - Python can only concatenate a **string** to another **string**
# - Therefore, Python can **NOT** concatenate a **string** to a **number**
#
# In the next section, we will learn how to convert between data types!

# %% [markdown]
# ## Part 2: Functions: Programs that work for us!
#
# In programming, we do not want to do everything ourselves.  Instead, **functions** provide us **functionality** that does work for us!  We already have learned one **function**:
#
# - `print( value )`, prints out `value` to the screen
#
# All **functions** always are made up of three parts:
#
# 1. Every function always has a **name** (ex: `print`)
# 2. Every function's name is always following with **paired parentheses** (ex: `print()`)
# 3. Functions may take **values between the paired parentheses** (ex: `print('Hello')` or `print(43)`).  We call the values that a function has between it's paired parentheses the **function parameters**.
#
# Here's a visual breakdown of this same information:
#
# ![Visual print function](img/print-function.png)
#
# The values that a function can receive vary by function and must be known.  `print` is very special in that it can take in almost any type of data.

# %% [markdown]
# ### The `str` Function
#
# The second function we will use is the `str` function.  This function has a different name than `print` and will do something different.  However, we use `str` is the same way.
#
# The `str` function will take in a value as it's parameter and **return** a string version of that value.  For example, the **number** `42` can be represented as the string `"42"`.  The **return value** of the function is what is left after the function is run.
#
# A few examples to run, notice the output of each of them:

# %%
str(42)
# Out:
# '42'

# %%
str('Hello')
# Out:
# 'Hello'

# %%
nine = str(4 + 5)
nine
# Out:
# '9'

# %% [markdown]
# ### Puzzle 2.1:
#
# Now we can wish the current year (2019) hello by using the `str` function!
#
# Modify the following code to say hello **to the current year** using `current_year` you created back in Part 1 of this lab:

# %%
# Modify this Python to say "Hello 2019", where 2019 is the current year.
# - Use `current_year` you created earlier.
print('Hello' + ' ' + str(current_year))
# Out:
# Hello 2019

# %% [markdown]
# ### The `float` and `int` functions
#
# The next two functions do the reverse of `str`.  Instead of taking a value and returning a string, `float` and `int` are functions that take a value and return a number.  Both `float` and `int` are similar, but have an important difference:
#
# - `int` (short for **integer**) returns whole numbers only (ex: 1, 2, 3, 4, etc)
# - `float` (short for **floating point**) returns decimal numbers (ex: 5.2, 3.141592654, 4.25, 11.0, etc)
#
# If you use `int` on a non-whole number, `int` will return only the whole number component of the number.  For example, the whole number part of **3.9** is **3** (note that it does **NOT** do any rounding).  A few examples:

# %%
print( int(4.9) )
print( int(-8.7) )
print( float("4.8") )
print( int("9") )
# Out:
# 4
# -8
# 4.8
# 9

# %% [markdown]
# If Python is unable to convert the value to a number, your code will have an error:

# %%
float('Hello')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-62e6d411d8e4> in <module>()
# ----> 1 float('Hello')
#
# ValueError: could not convert string to float: 'Hello'

# %% [markdown]
# ### Puzzle 2.2:
#
# In the next cell, several names are defined with various values.  Run this cell:

# %%
a = "17"
b = "44.2"
c = "19"

# %% [markdown]
# **Without editing the previous cell**, compute the value of $a + b + c$ in the next cell:

# %%
# Compute the value of a + b + c
total = float(a)+float(b)+float(c)
total
# Out:
# 80.2

# %% [markdown]
# Note: Your result should **NOT** be `1744.219`.  Make sure your answer makes sense before running the test cases.

# %%
## == TEST CASES for Puzzle 2.2 ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any error our output, you PASSED all test cases!
# - If this cell results in any errors, check you previous cell, make changes, and RE-RUN your code and then this cell.

assert(a == "17"), "You must not modify the value of `a`."
assert(type(a) == type("17")), "You must not modify the value of `a`."

assert(b == "44.2"), "You must not modify the value of `b`."
assert(type(b) == type("44.2")), "You must not modify the value of `b`."

assert(c == "19"), "You must not modify the value of `c`."
assert(type(c) == type("19")), "You must not modify the value of `c`."

assert(total == 80.2), "The value in `total` is not the sum of `a`, `b`, and `c`."

# %% [markdown]
# ## Part 3: Importing Datasets
#
# Data Science is focused on using tools to access, analyze, and find meaningful results in data.  Now that we know some basic Python programming, we are ready to do begin to use our first dataset!
#
# ### CSV File Format
#
# One widely used file format to store datasets is as **CSV** or **Comma-Separated Values**.  The CSV file maps extremely well between a spreadsheet program (ex: Microsoft Excel, Google Sheets) and programming languages.  Specifically:
#
# - Every row on a spreadsheet is a line in a CSV file
# - Every column on a spreadsheet is separated by a comma in a CSV file

# %% [markdown]
# ### Download the UIUC Course Catalog as a CSV
#
# Let's grab the first dataset we will use!  For this dataset, we have already collected and put the data into a Google Sheet for you.  You will need to download the file as a CSV and place it in the same directory as this Python notebook.
#
# 1. Open the Google Sheet for the "UIUC Course Catalog Dataset": https://docs.google.com/spreadsheets/d/1ZnpZpipyui_zIIBblmalRYiyEG1glUKinqJtQxVL04o/edit#gid=0
#
# 2. Choose **File** -> **Download As** -> **Comma-separated Values (.csv, current sheet)**
#
# 3. Find the downloaded file on your computer and move it into the same directory as this notebook.
#   * The file is likely in your Downloads as `Illinois Course Catalog - Sheet1.csv`
#   * You notebook is likely on your Desktop under `stat107 -> [netid] -> lab_pandas`
#   * You need to ensure the downloaded file is in the `lab_pandas` folder before running the next cell.

# %% [markdown]
# ### Using Pandas to Read CSV Files
#
# In Data Science DISCOVERY, we will use the `pandas` **library** for working with data.  Libraries are collections of functions and other objects that extend what Python can do by itself.  The `pandas` library is the most widely used library for data science.
#
# To use the `pandas` library, we must **import** it into your notebook.  In future labs, you will find this will be one of the first lines we will run in every notebook:

# %%
import pandas as pd

# %% [markdown]
# To use a function inside of the pandas library, the function name will always start with `pandas.` to denote that Python can find it within the `pandas` library.  The first function we will use from the `pandas` library is `read_csv`.
# - Because `read_csv` is in the pandas library, the full function name is `pandas.read_csv()`.

# %% [markdown]
# ### Puzzle 3.1:
#
# The `pd.read_csv` function's first parameter is the name of the file that it is reading.  Using this, we know the format of the function follows the expected format.  Set the name `df` to be the result of the `pd.read_csv` function:

# %%
df = pd.read_csv('Illinois Course Catalog.csv')
df
# Out:
#       Year  Term YearTerm Subject  Number  \
# 0     2019  Fall  2019-fa     AAS     100
# 1     2019  Fall  2019-fa     AAS     105
# 2     2019  Fall  2019-fa     AAS     120
# 3     2019  Fall  2019-fa     AAS     199
# 4     2019  Fall  2019-fa     AAS     200
# 5     2019  Fall  2019-fa     AAS     201
# 6     2019  Fall  2019-fa     AAS     211
# 7     2019  Fall  2019-fa     AAS     215
# 8     2019  Fall  2019-fa     AAS     224
# 9     2019  Fall  2019-fa     AAS     246
# 10    2019  Fall  2019-fa     AAS     258
# 11    2019  Fall  2019-fa     AAS     260
# 12    2019  Fall  2019-fa     AAS     265
# 13    2019  Fall  2019-fa     AAS     275
# 14    2019  Fall  2019-fa     AAS     281
# 15    2019  Fall  2019-fa     AAS     282
# 16    2019  Fall  2019-fa     AAS     283
# 17    2019  Fall  2019-fa     AAS     286
# 18    2019  Fall  2019-fa     AAS     287
# 19    2019  Fall  2019-fa     AAS     288
# 20    2019  Fall  2019-fa     AAS     290
# 21    2019  Fall  2019-fa     AAS     291
# 22    2019  Fall  2019-fa     AAS     297
# 23    2019  Fall  2019-fa     AAS     299
# 24    2019  Fall  2019-fa     AAS     300
# 25    2019  Fall  2019-fa     AAS     310
# 26    2019  Fall  2019-fa     AAS     315
# 27    2019  Fall  2019-fa     AAS     317
# 28    2019  Fall  2019-fa     AAS     328
# 29    2019  Fall  2019-fa     AAS     343
# ...    ...   ...      ...     ...     ...
# 8559  2019  Fall  2019-fa      VM     626
# 8560  2019  Fall  2019-fa      VM     627
# 8561  2019  Fall  2019-fa      VM     635
# 8562  2019  Fall  2019-fa      VM     642
# 8563  2019  Fall  2019-fa      VM     643
# 8564  2019  Fall  2019-fa      VM     645
# 8565  2019  Fall  2019-fa      VM     694
# 8566  2019  Fall  2019-fa    WLOF     201
# 8567  2019  Fall  2019-fa    WLOF     202
# 8568  2019  Fall  2019-fa    WLOF     403
# 8569  2019  Fall  2019-fa    WLOF     404
# 8570  2019  Fall  2019-fa    WLOF     405
# 8571  2019  Fall  2019-fa    WLOF     406
# 8572  2019  Fall  2019-fa    WLOF     407
# 8573  2019  Fall  2019-fa    WRIT     199
# 8574  2019  Fall  2019-fa    WRIT     300
# 8575  2019  Fall  2019-fa    WRIT     303
# 8576  2019  Fall  2019-fa    YDSH     101
# 8577  2019  Fall  2019-fa    YDSH     102
# 8578  2019  Fall  2019-fa    YDSH     103
# 8579  2019  Fall  2019-fa    YDSH     104
# 8580  2019  Fall  2019-fa    YDSH     220
# 8581  2019  Fall  2019-fa    YDSH     320
# 8582  2019  Fall  2019-fa    YDSH     420
# 8583  2019  Fall  2019-fa    ZULU     201
# 8584  2019  Fall  2019-fa    ZULU     202
# 8585  2019  Fall  2019-fa    ZULU     403
# 8586  2019  Fall  2019-fa    ZULU     404
# 8587  2019  Fall  2019-fa    ZULU     405
# 8588  2019  Fall  2019-fa    ZULU     406
#
#                                          Name  \
# 0                Intro Asian American Studies
# 1       Introduction to Arab American Studies
# 2               Intro to Asian Am Pop Culture
# 3                  Undergraduate Open Seminar
# 4                        U.S. Race and Empire
# 5             US Racial &amp; Ethnic Politics
# 6                Asian Americans and the Arts
# 7                US Citizenship Comparatively
# 8               Asian Am Historical Sociology
# 9                Asian American Youth in Film
# 10                         Muslims in America
# 11               Intro Asian American Theatre
# 12                        Politics of Hip Hop
# 13                    The Politics of Fashion
# 14               Constructing Race in America
# 15               Feminist and Queer Activisms
# 16                     Asian American History
# 17                  Asian American Literature
# 18                   Food and Asian Americans
# 19                 Global Islam and Feminisms
# 20                           Individual Study
# 21              Hinduism in the United States
# 22                  Asian Families in America
# 23              Begin Topics Asian Am Studies
# 24    Theories of Race, Gender, and Sexuality
# 25                Race and Cultural Diversity
# 26                    War, Memory, and Cinema
# 27                    Asian American Politics
# 28         Asian Americans &amp; Inequalities
# 29             Criminalization and Punishment
# ...                                       ...
# 8559                   The Basics of Business
# 8560                  Fundamentals of Finance
# 8561               Veterinary Medical Spanish
# 8562           Contemporary Issues in Vet Med
# 8563               Fundamentals of Management
# 8564               Communications in Practice
# 8565                      Veterinary Medicine
# 8566                       Elementary Wolof I
# 8567                      Elementary Wolof II
# 8568                     Intermediate Wolof I
# 8569                    Intermediate Wolof II
# 8570                         Advanced Wolof I
# 8571                        Advanced Wolof II
# 8572            Topics Wolof Lang &amp; Lit I
# 8573               Undergraduate Open Seminar
# 8574               Issues in Tutoring Writing
# 8575                     Writing Across Media
# 8576                      Beginning Yiddish I
# 8577                     Beginning Yiddish II
# 8578                   Intermediate Yiddish I
# 8579                  Intermediate Yiddish II
# 8580                      Jewish Storytelling
# 8581           Lit Responses to the Holocaust
# 8582                      Jewish Life-Writing
# 8583                        Elementary Zulu I
# 8584                       Elementary Zulu II
# 8585                      Intermediate Zulu I
# 8586                     Intermediate Zulu II
# 8587                          Advanced Zulu I
# 8588                         Advanced Zulu II
#
#                                             Description   Credit Hours  \
# 0     Interdisciplinary introduction to the basic co...       3 hours.
# 1     Interdisciplinary introduction to the basic co...       3 hours.
# 2     Introductory understanding of the way U.S. pop...       3 hours.
# 3              May be repeated to a maximum of 6 hours.  1 TO 5 hours.
# 4     Invites students to examine histories and narr...       3 hours.
# 5     Same as AFRO 201, LLS 201, and PS 201. See PS ...       3 hours.
# 6     Examination of Asian American artistic express...       3 hours.
# 7     Examines the racial, gendered, and sexualized ...       3 hours.
# 8     Explores concepts of colonization, internation...       3 hours.
# 9     Examines both mainstream and independent films...       3 hours.
# 10    Introduction to the study of Muslims in the Un...       3 hours.
# 11                      Same as THEA 260. See THEA 260.       3 hours.
# 12                        Same as LLS 265. See LLS 265.       3 hours.
# 13                        Same as GWS 275. See GWS 275.       3 hours.
# 14    Same as AFRO 281, HIST 281, and LLS 281. See H...       3 hours.
# 15            Same as GWS 282 and LLS 282. See GWS 282.       3 hours.
# 16                      Same as HIST 283. See HIST 283.       3 hours.
# 17                      Same as ENGL 286. See ENGL 286.       3 hours.
# 18    Introduction to the interdisciplinary study of...       3 hours.
# 19                        Same as GWS 288. See GWS 288.       3 hours.
# 20    Supervised reading and research in Asian Ameri...  2 TO 3 hours.
# 21                        Same as REL 291. See REL 291.       3 hours.
# 22         Same as HDFS 221 and SOCW 297. See SOCW 297.       3 hours.
# 23    May be repeated in the same or subsequent term...       3 hours.
# 24    Explores theories for performing interdiscipli...       3 hours.
# 25    Same as AFRO 310, EPS 310, and LLS 310. See EP...       4 hours.
# 26    Interdisciplinary examination of the ways that...       3 hours.
# 27                          Same as PS 317. See PS 317.       3 hours.
# 28                        Same as SOC 328. See SOC 328.       3 hours.
# 29    Same as AFRO 343, AIS 343, GWS 343, and LLS 34...       3 hours.
# ...                                                 ...            ...
# 8559  Business principles related to managing a vete...       1 hours.
# 8560  Provides students with a strong introductory b...       1 hours.
# 8561  In this course second year veterinary students...       2 hours.
# 8562  An introductory course for first year veterina...       1 hours.
# 8563  An introductory course for second year veterin...       1 hours.
# 8564  An introductory course for third year veterina...       1 hours.
# 8565  To be used to designate a trial or experimenta...  1 TO 4 hours.
# 8566  Introduction to Wolof; emphasizes grammar, pro...       5 hours.
# 8567  Continuation of elementary Wolof, with introdu...       5 hours.
# 8568  Survey of more advanced grammar, with emphasis...       4 hours.
# 8569  Continuation of WLOF 403. Emphasizes ability t...       4 hours.
# 8570  Third year Wolof with emphasis on conversation...       3 hours.
# 8571  Continuation of WLOF 405 with increased emphas...       3 hours.
# 8572  Selected readings from modern Wolof authors, w...       3 hours.
# 8573  See course schedule for topics. Approved for L...  1 TO 5 hours.
# 8574  Introduction to the work of writing centers, t...       3 hours.
# 8575                    Same as INFO 303. See INFO 303.       3 hours.
# 8576  Course develops basic conversational and readi...       4 hours.
# 8577  Continuation of YDSH 101 focusing on comprehen...       4 hours.
# 8578  Continuation of YDSH 102. Develops more advanc...       4 hours.
# 8579  Continuation of YDSH 103. Prerequisite: YDSH 1...       4 hours.
# 8580  Course will introduce the great Jewish storyte...       3 hours.
# 8581  Course introduces a variety of Jewish literary...       3 hours.
# 8582  Jewish life-writing from the late 18th century...  3 OR 4 hours.
# 8583  Introduction to Zulu; emphasis on grammar, pro...       5 hours.
# 8584  Continuation of ZULU 201 with introduction of ...       5 hours.
# 8585  Survey of more advanced grammar; emphasis on i...       4 hours.
# 8586  Continuation of ZULU 403; emphasis on increasi...       4 hours.
# 8587  Third year Zulu with emphasis on conversationa...       3 hours.
# 8588  Continuation of Zulu 405 with increased emphas...       3 hours.
#
#                                            Section Info  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                      Same as LLS 200.
# 5     Same as AFRO 201, LLS 201, and PS 201. See PS ...
# 6                                                   NaN
# 7                                                   NaN
# 8                                                   NaN
# 9                                                   NaN
# 10                                                  NaN
# 11                                                  NaN
# 12                                                  NaN
# 13                        Same as GWS 275. See GWS 275.
# 14    Same as AFRO 281, HIST 281, and LLS 281. See H...
# 15                                                  NaN
# 16                      Same as HIST 283. See HIST 283.
# 17                                                  NaN
# 18    Prerequisite: AAS 100 or AAS 120, or consent o...
# 19                                                  NaN
# 20                                                  NaN
# 21                                                  NaN
# 22         Same as HDFS 221 and SOCW 297. See SOCW 297.
# 23                                                  NaN
# 24                                                  NaN
# 25    Same as AFRO 310, EPS 310, and LLS 310. See EP...
# 26                                                  NaN
# 27                                                  NaN
# 28                                                  NaN
# 29                                                  NaN
# ...                                                 ...
# 8559  1 graduate hour. 1 professional hour. Prerequi...
# 8560                                                NaN
# 8561  No graduate credit. 2 professional hours. Appr...
# 8562                                                NaN
# 8563  No graduate credit. 1 professional hour. Appro...
# 8564                                                NaN
# 8565                                                NaN
# 8566  Same as AFST 241. Participation in language la...
# 8567                                                NaN
# 8568  Same as AFST 443. 4 undergraduate hours. 4 gra...
# 8569                                                NaN
# 8570  Same as AFST 445. 3 undergraduate hours. 3 gra...
# 8571                                                NaN
# 8572                                                NaN
# 8573                                                NaN
# 8574  Credit is not given for WRIT 203 and WRIT 300....
# 8575                    Same as INFO 303. See INFO 303.
# 8576                                                NaN
# 8577                                                NaN
# 8578  Prerequisite: YDSH 102 or equivalent placement...
# 8579                                                NaN
# 8580    Same as CWL 221, ENGL 223, JS 220, and REL 220.
# 8581                                                NaN
# 8582                                                NaN
# 8583  Same as AFST 251. Participation in the languag...
# 8584  Same as AFST 252. Participation in the languag...
# 8585                                                NaN
# 8586                                                NaN
# 8587                                                NaN
# 8588                                                NaN
#
#                                       Degree Attributes
# 0     Social & Beh Sci - Soc Sci, and Cultural Studi...
# 1                Cultural Studies - US Minority course.
# 2                Cultural Studies - US Minority course.
# 3                                                   NaN
# 4     Humanities - Hist & Phil, and Cultural Studies...
# 5     Social & Beh Sci - Soc Sci, and Cultural Studi...
# 6     Humanities - Lit & Arts, and Cultural Studies ...
# 7     Humanities - Hist & Phil, and Cultural Studies...
# 8                Cultural Studies - US Minority course.
# 9     Social & Beh Sci - Soc Sci, and Cultural Studi...
# 10    Social & Beh Sci - Soc Sci, and Cultural Studi...
# 11               Cultural Studies - US Minority course.
# 12               Cultural Studies - US Minority course.
# 13               Cultural Studies - US Minority course.
# 14    Humanities - Hist & Phil, and Cultural Studies...
# 15                                                  NaN
# 16    Humanities - Hist & Phil, and Cultural Studies...
# 17    Humanities - Lit & Arts, and Cultural Studies ...
# 18    Social & Beh Sci - Soc Sci, and Cultural Studi...
# 19                  Cultural Studies - Non-West course.
# 20                                                  NaN
# 21                                                  NaN
# 22    Social & Beh Sci - Soc Sci, and Cultural Studi...
# 23                                                  NaN
# 24                         Advanced Composition course.
# 25    Advanced Composition, and Cultural Studies - U...
# 26                                                  NaN
# 27                                                  NaN
# 28                                                  NaN
# 29                                                  NaN
# ...                                                 ...
# 8559                                                NaN
# 8560                                                NaN
# 8561                                                NaN
# 8562                                                NaN
# 8563                                                NaN
# 8564                                                NaN
# 8565                                                NaN
# 8566                                                NaN
# 8567                                                NaN
# 8568                                                NaN
# 8569                                                NaN
# 8570                                                NaN
# 8571                                                NaN
# 8572                                                NaN
# 8573                                                NaN
# 8574                                                NaN
# 8575                       Advanced Composition course.
# 8576                                                NaN
# 8577                                                NaN
# 8578                                                NaN
# 8579                                                NaN
# 8580  Humanities - Lit & Arts, and Cultural Studies ...
# 8581  Humanities - Lit & Arts, and Cultural Studies ...
# 8582                                                NaN
# 8583                                                NaN
# 8584                                                NaN
# 8585                                                NaN
# 8586                                                NaN
# 8587                                                NaN
# 8588                                                NaN
#
# [8589 rows x 10 columns]

# %%
## == TEST CASES for Puzzle 3.1 ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any error our output, you PASSED all test cases!
# - If this cell results in any errors, check you previous cell, make changes, and RE-RUN your code and then this cell.

assert( len(df) == 8589 ), "It looks like you did not import the correct dataset?"

# %% [markdown]
# ### The DataFrame Type
#
# In Python so far, we have had **string** and **number** data types.  With the successful `pd.read_csv` function, we now have a third type: a **DataFrame**.  We can always ask Python to tell us the type with the `type` function:

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# The `pandas.core.frame.DataFrame` (which we will just call `DataFrame`) type has hundreds of useful functions that can be called on it:
#
# - We can choose data that matches a specific requirement,
# - We can group our data by a certain column,
# - ...and hundreds of other things...
#
# The key idea here is that **`df` is the name of the DataFrame** that contains the data in the CSV file you downloaded.

# %% [markdown]
# ### Accessing a Column
#
# The dataset you downloaded has six columns: `Year`, `Term`, `YearTerm`, `Subject`, `Number`, and `Title`.  We can access a column by **indexing into the DataFrame**.  Whenever we **index into** something, we will use matchingsquare brackets: `[` and `]`.  For example, to **index into the column `Subject`**:

# %%
df["Subject"]
# Out:
# 0        AAS
# 1        AAS
# 2        AAS
# 3        AAS
# 4        AAS
# 5        AAS
# 6        AAS
# 7        AAS
# 8        AAS
# 9        AAS
# 10       AAS
# 11       AAS
# 12       AAS
# 13       AAS
# 14       AAS
# 15       AAS
# 16       AAS
# 17       AAS
# 18       AAS
# 19       AAS
# 20       AAS
# 21       AAS
# 22       AAS
# 23       AAS
# 24       AAS
# 25       AAS
# 26       AAS
# 27       AAS
# 28       AAS
# 29       AAS
#         ...
# 8559      VM
# 8560      VM
# 8561      VM
# 8562      VM
# 8563      VM
# 8564      VM
# 8565      VM
# 8566    WLOF
# 8567    WLOF
# 8568    WLOF
# 8569    WLOF
# 8570    WLOF
# 8571    WLOF
# 8572    WLOF
# 8573    WRIT
# 8574    WRIT
# 8575    WRIT
# 8576    YDSH
# 8577    YDSH
# 8578    YDSH
# 8579    YDSH
# 8580    YDSH
# 8581    YDSH
# 8582    YDSH
# 8583    ZULU
# 8584    ZULU
# 8585    ZULU
# 8586    ZULU
# 8587    ZULU
# 8588    ZULU
# Name: Subject, Length: 8589, dtype: object

# %% [markdown]
# Notice that we now only have the **Subject** data in our output, no longer the whole DataFrame.  We can do this with any of the six columns using the same format:
#
# ![image.png](img/DataFrame-index-into-column.png)

# %% [markdown]
# ### Puzzle 3.2:
#
# List the **name of every course** (ex: 'Data Science Discovery') at Illinois:
#
# - You may need to refer back to the data sheet (or the DataFrame output above) to get the correct column name.

# %%
df["Name"]
# Out:
# 0                  Intro Asian American Studies
# 1         Introduction to Arab American Studies
# 2                 Intro to Asian Am Pop Culture
# 3                    Undergraduate Open Seminar
# 4                          U.S. Race and Empire
# 5               US Racial &amp; Ethnic Politics
# 6                  Asian Americans and the Arts
# 7                  US Citizenship Comparatively
# 8                 Asian Am Historical Sociology
# 9                  Asian American Youth in Film
# 10                           Muslims in America
# 11                 Intro Asian American Theatre
# 12                          Politics of Hip Hop
# 13                      The Politics of Fashion
# 14                 Constructing Race in America
# 15                 Feminist and Queer Activisms
# 16                       Asian American History
# 17                    Asian American Literature
# 18                     Food and Asian Americans
# 19                   Global Islam and Feminisms
# 20                             Individual Study
# 21                Hinduism in the United States
# 22                    Asian Families in America
# 23                Begin Topics Asian Am Studies
# 24      Theories of Race, Gender, and Sexuality
# 25                  Race and Cultural Diversity
# 26                      War, Memory, and Cinema
# 27                      Asian American Politics
# 28           Asian Americans &amp; Inequalities
# 29               Criminalization and Punishment
#                          ...
# 8559                     The Basics of Business
# 8560                    Fundamentals of Finance
# 8561                 Veterinary Medical Spanish
# 8562             Contemporary Issues in Vet Med
# 8563                 Fundamentals of Management
# 8564                 Communications in Practice
# 8565                        Veterinary Medicine
# 8566                         Elementary Wolof I
# 8567                        Elementary Wolof II
# 8568                       Intermediate Wolof I
# 8569                      Intermediate Wolof II
# 8570                           Advanced Wolof I
# 8571                          Advanced Wolof II
# 8572              Topics Wolof Lang &amp; Lit I
# 8573                 Undergraduate Open Seminar
# 8574                 Issues in Tutoring Writing
# 8575                       Writing Across Media
# 8576                        Beginning Yiddish I
# 8577                       Beginning Yiddish II
# 8578                     Intermediate Yiddish I
# 8579                    Intermediate Yiddish II
# 8580                        Jewish Storytelling
# 8581             Lit Responses to the Holocaust
# 8582                        Jewish Life-Writing
# 8583                          Elementary Zulu I
# 8584                         Elementary Zulu II
# 8585                        Intermediate Zulu I
# 8586                       Intermediate Zulu II
# 8587                            Advanced Zulu I
# 8588                           Advanced Zulu II
# Name: Name, Length: 8589, dtype: object

# %% [markdown]
# ### Finding a Subset of the Data
#
# Let's find a subset of the data.  To do this, we will **index into the DataFrame** with a **conditional statement**.  A **conditional** is anything that Python can check if it's **True/Yes or False/No**.  For example:
#
# - Is this course's subject STAT?  *...YES, that's True*
# - Is this course offered in 2012?  *...NO, that's False*
#
# #### Writing a Equality Conditional in Python
#
# The most basic conditional is a test for equality -- if something is **exactly equal to** something else.  To test for equality, Python uses `==`.
#
# - Remember, we already used `=` to set a name equal to something -- so Python needs to use something different.
#
# In general, we will test if **each row in a column contains some value**.  For example, we may want to test if the subject for a given course is exactly equal to `'STAT'`.  To do this, the conditional will be:
#
# ![image.png](img/DataFrame-conditional.png)
#
#
# ### Puzzle 3.3: A standalone conditional
#
# Write the conditional to check if each row in our DataFrame's **Subject** is `'STAT'`.
#
# - You will expect to see a whole bunch of `False`.

# %%
df["Subject"] == "STAT"
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
# 5       False
# 6       False
# 7       False
# 8       False
# 9       False
# 10      False
# 11      False
# 12      False
# 13      False
# 14      False
# 15      False
# 16      False
# 17      False
# 18      False
# 19      False
# 20      False
# 21      False
# 22      False
# 23      False
# 24      False
# 25      False
# 26      False
# 27      False
# 28      False
# 29      False
#         ...
# 8559    False
# 8560    False
# 8561    False
# 8562    False
# 8563    False
# 8564    False
# 8565    False
# 8566    False
# 8567    False
# 8568    False
# 8569    False
# 8570    False
# 8571    False
# 8572    False
# 8573    False
# 8574    False
# 8575    False
# 8576    False
# 8577    False
# 8578    False
# 8579    False
# 8580    False
# 8581    False
# 8582    False
# 8583    False
# 8584    False
# 8585    False
# 8586    False
# 8587    False
# 8588    False
# Name: Subject, Length: 8589, dtype: bool

# %% [markdown]
# The expected result will list a large number or row numbers (0, 1, ..., 8741) that tells us if each row is STAT.  This is almost useful, but we want to **index the whole conditional into the DataFrame** to get **ONLY the rows where the conditional is True**.
#
# We will index into the DataFrame with the full condiitional:
#
# ![image.png](img/DataFarme-row-conditional.png)

# %% [markdown]
# ### Puzzle 3.4: Selecting a Subset of Rows
#
# In the next cell, select only the rows that have a **Subject** of `'STAT'`:

# %%
df[df["Subject"] == "STAT"]
# Out:
#       Year  Term YearTerm Subject  Number  \
# 8002  2019  Fall  2019-fa    STAT     100
# 8003  2019  Fall  2019-fa    STAT     107
# 8004  2019  Fall  2019-fa    STAT     199
# 8005  2019  Fall  2019-fa    STAT     200
# 8006  2019  Fall  2019-fa    STAT     212
# 8007  2019  Fall  2019-fa    STAT     361
# 8008  2019  Fall  2019-fa    STAT     385
# 8009  2019  Fall  2019-fa    STAT     390
# 8010  2019  Fall  2019-fa    STAT     391
# 8011  2019  Fall  2019-fa    STAT     400
# 8012  2019  Fall  2019-fa    STAT     408
# 8013  2019  Fall  2019-fa    STAT     409
# 8014  2019  Fall  2019-fa    STAT     410
# 8015  2019  Fall  2019-fa    STAT     420
# 8016  2019  Fall  2019-fa    STAT     424
# 8017  2019  Fall  2019-fa    STAT     425
# 8018  2019  Fall  2019-fa    STAT     426
# 8019  2019  Fall  2019-fa    STAT     427
# 8020  2019  Fall  2019-fa    STAT     428
# 8021  2019  Fall  2019-fa    STAT     429
# 8022  2019  Fall  2019-fa    STAT     430
# 8023  2019  Fall  2019-fa    STAT     431
# 8024  2019  Fall  2019-fa    STAT     432
# 8025  2019  Fall  2019-fa    STAT     433
# 8026  2019  Fall  2019-fa    STAT     434
# 8027  2019  Fall  2019-fa    STAT     440
# 8028  2019  Fall  2019-fa    STAT     443
# 8029  2019  Fall  2019-fa    STAT     448
# 8030  2019  Fall  2019-fa    STAT     458
# 8031  2019  Fall  2019-fa    STAT     480
# 8032  2019  Fall  2019-fa    STAT     510
# 8033  2019  Fall  2019-fa    STAT     511
# 8034  2019  Fall  2019-fa    STAT     525
# 8035  2019  Fall  2019-fa    STAT     527
# 8036  2019  Fall  2019-fa    STAT     530
# 8037  2019  Fall  2019-fa    STAT     534
# 8038  2019  Fall  2019-fa    STAT     538
# 8039  2019  Fall  2019-fa    STAT     541
# 8040  2019  Fall  2019-fa    STAT     542
# 8041  2019  Fall  2019-fa    STAT     543
# 8042  2019  Fall  2019-fa    STAT     545
# 8043  2019  Fall  2019-fa    STAT     546
# 8044  2019  Fall  2019-fa    STAT     551
# 8045  2019  Fall  2019-fa    STAT     552
# 8046  2019  Fall  2019-fa    STAT     553
# 8047  2019  Fall  2019-fa    STAT     554
# 8048  2019  Fall  2019-fa    STAT     555
# 8049  2019  Fall  2019-fa    STAT     558
# 8050  2019  Fall  2019-fa    STAT     571
# 8051  2019  Fall  2019-fa    STAT     575
# 8052  2019  Fall  2019-fa    STAT     578
# 8053  2019  Fall  2019-fa    STAT     587
# 8054  2019  Fall  2019-fa    STAT     588
# 8055  2019  Fall  2019-fa    STAT     590
# 8056  2019  Fall  2019-fa    STAT     593
# 8057  2019  Fall  2019-fa    STAT     595
# 8058  2019  Fall  2019-fa    STAT     599
#
#                                                    Name  \
# 8002                                         Statistics
# 8003                             Data Science Discovery
# 8004                         Undergraduate Open Seminar
# 8005                               Statistical Analysis
# 8006                                      Biostatistics
# 8007  Probability &amp; Statistics for Computer Science
# 8008                     Statistics Programming Methods
# 8009                                   Individual Study
# 8010                            Honors Individual Study
# 8011                       Statistics and Probability I
# 8012                             Actuarial Statistics I
# 8013                            Actuarial Statistics II
# 8014                      Statistics and Probability II
# 8015                      Methods of Applied Statistics
# 8016                               Analysis of Variance
# 8017                      Applied Regression and Design
# 8018                      Sampling and Categorical Data
# 8019                             Statistical Consulting
# 8020                              Statistical Computing
# 8021                               Time Series Analysis
# 8022                       Topics in Applied Statistics
# 8023                          Applied Bayesian Analysis
# 8024                     Basics of Statistical Learning
# 8025                               Stochastic Processes
# 8026                                  Survival Analysis
# 8027                        Statistical Data Management
# 8028                            Professional Statistics
# 8029                             Advanced Data Analysis
# 8030                     Math Modeling in Life Sciences
# 8031                           Data Science Foundations
# 8032                          Mathematical Statistics I
# 8033                         Mathematical Statistics II
# 8034                           Computational Statistics
# 8035                       Advanced Regression Analysis
# 8036                                     Bioinformatics
# 8037                         Advanced Survival Analysis
# 8038                        Clinical Trials Methodology
# 8039                               Predictive Analytics
# 8040                               Statistical Learning
# 8041                      Appl. Multivariate Statistics
# 8042                                 Spatial Statistics
# 8043                   Machine Learning in Data Science
# 8044                            Theory of Probability I
# 8045                           Theory of Probability II
# 8046                          Probability and Measure I
# 8047                         Probability and Measure II
# 8048                       Applied Stochastic Processes
# 8049                         Risk Modeling and Analysis
# 8050                              Multivariate Analysis
# 8051                                Large Sample Theory
# 8052                               Topics in Statistics
# 8053                         Hierarchical Linear Models
# 8054                     Covar Struct and Factor Models
# 8055                      Individual Study and Research
# 8056                                    STAT Internship
# 8057                           Preparing Future Faculty
# 8058                                    Thesis Research
#
#                                             Description    Credit Hours  \
# 8002  First course in probability and statistics at ...        3 hours.
# 8003  Data Science Discovery is the intersection of ...        4 hours.
# 8004  See course schedule for topics. Approved for L...   1 TO 5 hours.
# 8005  Survey of statistical concepts, data analysis,...        3 hours.
# 8006  Application of statistical reasoning and stati...        3 hours.
# 8007                        Same as CS 361. See CS 361.        3 hours.
# 8008  Statisticians must be savvy in programming met...        3 hours.
# 8009  May be repeated to a maximum of 8 hours. Prere...   1 OR 2 hours.
# 8010  May be repeated to a maximum of 8 hours. Prere...   1 OR 2 hours.
# 8011  Introduction to mathematical statistics that d...        4 hours.
# 8012  Examines elementary theory of probability, inc...        4 hours.
# 8013  Continuation of STAT 408. Examines parametric ...        4 hours.
# 8014  Continuation of STAT 400. Includes moment-gene...   3 OR 4 hours.
# 8015  Systematic, calculus-based coverage of the mor...   3 OR 4 hours.
# 8016  Estimation and hypotheses testing in linear mo...   3 OR 4 hours.
# 8017  Explores linear regression, least squares esti...   3 OR 4 hours.
# 8018  Sampling: simple random, stratified, systemati...   3 OR 4 hours.
# 8019  Students, working in groups under the supervis...   3 OR 4 hours.
# 8020  Examines statistical packages, numerical analy...   3 OR 4 hours.
# 8021  Studies theory and data analysis for time seri...   3 OR 4 hours.
# 8022  Formulation and analysis of mathematical model...   3 OR 4 hours.
# 8023  Introduction to the concepts and methodology o...   3 OR 4 hours.
# 8024  Topics in supervised and unsupervised learning...   3 OR 4 hours.
# 8025  A stochastic process is a random process that ...   3 OR 4 hours.
# 8026  Introduction to the analysis of time-to-event ...   3 OR 4 hours.
# 8027  The critical elements of data storage, data cl...   3 OR 4 hours.
# 8028  This project-based course emphasizes written, ...   3 OR 4 hours.
# 8029  Several of the most widely used techniques of ...        4 hours.
# 8030         Same as ANSC 448 and IB 487. See ANSC 448.   3 OR 4 hours.
# 8031  Examines the methods of data management and an...   3 OR 4 hours.
# 8032  Distributions, transformations, order-statisti...        4 hours.
# 8033  Bayes estimates, minimaxity, admissibility; ma...        4 hours.
# 8034  Various topics, such as ridge regression; robu...        4 hours.
# 8035  An advanced introduction to regression analysi...        4 hours.
# 8036  Same as ANSC 543, CHBE 571, and MCB 571. See C...        4 hours.
# 8037  Introduction to the analysis of time-to-event ...        4 hours.
# 8038  The topics of the course focus on clinical tri...        4 hours.
# 8039                    Same as ASRM 552. See ASRM 552.        4 hours.
# 8040  Modern techniques of predictive modeling, clas...        4 hours.
# 8041                    Same as CPSC 543. See CPSC 543.        4 hours.
# 8042  Theory and methods for analyzing univariate an...        4 hours.
# 8043  Trains students to analyze large complex data ...        4 hours.
# 8044                    Same as MATH 561. See MATH 561.        4 hours.
# 8045                    Same as MATH 562. See MATH 562.        4 hours.
# 8046  Measures and probabilities; integration and ex...        4 hours.
# 8047  Measure extensions, Lebesque-Stieltjes measure...        4 hours.
# 8048                    Same as MATH 564. See MATH 564.        4 hours.
# 8049                    Same as MATH 563. See MATH 563.        4 hours.
# 8050  Inference in multivariate statistical populati...        4 hours.
# 8051  Limiting distribution of maximum likelihood es...        4 hours.
# 8052  May be repeated if topics vary. Prerequisite: ...        4 hours.
# 8053       Same as PSYC 587 and EPSY 587. See EPSY 587.        4 hours.
# 8054  Same as EPSY 588, PSYC 588, and SOC 588. See P...        4 hours.
# 8055  Directed reading and research. Approved for le...   0 TO 8 hours.
# 8056  Supervised, off-campus experience in a field i...   0 TO 8 hours.
# 8057  Prepares Ph.D. students who are interested in ...        2 hours.
# 8058  Approved for S/U grading only. May be repeated...  0 TO 16 hours.
#
#                                            Section Info  \
# 8002  Credit is not given for both STAT 100 and any ...
# 8003                         Same as CS 107 and IS 107.
# 8004                                                NaN
# 8005  Credit is not given for both STAT 200 and STAT...
# 8006  Credit is not given for both STAT 212 and STAT...
# 8007                        Same as CS 361. See CS 361.
# 8008                Prerequisite: STAT 200 or STAT 212.
# 8009  May be repeated to a maximum of 8 hours. Prere...
# 8010  May be repeated to a maximum of 8 hours. Prere...
# 8011  Same as MATH 463. 4 undergraduate hours. 4 gra...
# 8012                                                NaN
# 8013  Same as ASRM 402. 4 undergraduate hours. 4 gra...
# 8014  Same as MATH 464. 3 undergraduate hours. 4 gra...
# 8015  Same as ASRM 450. 3 undergraduate hours. 4 gra...
# 8016                                                NaN
# 8017  3 undergraduate hours. 4 graduate hours. Prere...
# 8018                                                NaN
# 8019                                                NaN
# 8020  Same as CSE 428. 3 undergraduate hours. 4 grad...
# 8021  3 undergraduate hours. 4 graduate hours. Prere...
# 8022  3 undergraduate hours. 4 graduate hours. May b...
# 8023                                                NaN
# 8024  Same as ASRM 451. 3 undergraduate hours. 4 gra...
# 8025  3 undergraduate hours. 4 graduate hours. Prere...
# 8026  3 undergraduate hours. 4 graduate hours. Prere...
# 8027  Same as CSE 440. 3 undergraduate hours. 4 grad...
# 8028  3 undergraduate hours. 4 graduate hours. Prere...
# 8029  Same as CSE 448. 4 undergraduate hours. 4 grad...
# 8030                                                NaN
# 8031  3 undergraduate hours. 4 graduate hours. Prere...
# 8032                            Prerequisite: STAT 410.
# 8033                                                NaN
# 8034                                                NaN
# 8035  4 graduate hours. No professional credit. Prer...
# 8036                                                NaN
# 8037                                                NaN
# 8038                                                NaN
# 8039                                                NaN
# 8040  Same as ASRM 551 and CSE 542. 4 graduate hours...
# 8041                                                NaN
# 8042                                                NaN
# 8043                                                NaN
# 8044                                                NaN
# 8045                    Same as MATH 562. See MATH 562.
# 8046   Prerequisite: MATH 447 or consent of instructor.
# 8047                                                NaN
# 8048                    Same as MATH 564. See MATH 564.
# 8049                    Same as MATH 563. See MATH 563.
# 8050  Prerequisite: STAT 410 and MATH 415, or consen...
# 8051                                                NaN
# 8052  May be repeated if topics vary. Prerequisite: ...
# 8053                                                NaN
# 8054                                                NaN
# 8055  Approved for letter and S/U grading. May be re...
# 8056  Approved for letter and S/U grading. Prerequis...
# 8057                                                NaN
# 8058  Approved for S/U grading only. May be repeated...
#
#                      Degree Attributes
# 8002  Quantitative Reasoning I course.
# 8003  Quantitative Reasoning I course.
# 8004                               NaN
# 8005  Quantitative Reasoning I course.
# 8006  Quantitative Reasoning I course.
# 8007                               NaN
# 8008                               NaN
# 8009                               NaN
# 8010                               NaN
# 8011                               NaN
# 8012                               NaN
# 8013                               NaN
# 8014                               NaN
# 8015                               NaN
# 8016                               NaN
# 8017                               NaN
# 8018                               NaN
# 8019                               NaN
# 8020                               NaN
# 8021                               NaN
# 8022                               NaN
# 8023                               NaN
# 8024                               NaN
# 8025                               NaN
# 8026                               NaN
# 8027                               NaN
# 8028                               NaN
# 8029                               NaN
# 8030                               NaN
# 8031                               NaN
# 8032                               NaN
# 8033                               NaN
# 8034                               NaN
# 8035                               NaN
# 8036                               NaN
# 8037                               NaN
# 8038                               NaN
# 8039                               NaN
# 8040                               NaN
# 8041                               NaN
# 8042                               NaN
# 8043                               NaN
# 8044                               NaN
# 8045                               NaN
# 8046                               NaN
# 8047                               NaN
# 8048                               NaN
# 8049                               NaN
# 8050                               NaN
# 8051                               NaN
# 8052                               NaN
# 8053                               NaN
# 8054                               NaN
# 8055                               NaN
# 8056                               NaN
# 8057                               NaN
# 8058                               NaN

# %% [markdown]
# ## Part 4: Exploring the DataSet
#
# You now know the basics of `pandas`.  Let's explore the dataset!
#
#
# ### Puzzle 4.1: Selecting your Major's Rows
#
# Select only the rows that have a **Subject** of your current/intended major.  Assign this to the value `mydf`:

# %%
mydf = df[df["Subject"] == "ECE"]
mydf
# Out:
#       Year  Term YearTerm Subject  Number  \
# 2792  2019  Fall  2019-fa     ECE     101
# 2793  2019  Fall  2019-fa     ECE     110
# 2794  2019  Fall  2019-fa     ECE     120
# 2795  2019  Fall  2019-fa     ECE     198
# 2796  2019  Fall  2019-fa     ECE     199
# 2797  2019  Fall  2019-fa     ECE     200
# 2798  2019  Fall  2019-fa     ECE     205
# 2799  2019  Fall  2019-fa     ECE     206
# 2800  2019  Fall  2019-fa     ECE     210
# 2801  2019  Fall  2019-fa     ECE     211
# 2802  2019  Fall  2019-fa     ECE     220
# 2803  2019  Fall  2019-fa     ECE     297
# 2804  2019  Fall  2019-fa     ECE     298
# 2805  2019  Fall  2019-fa     ECE     304
# 2806  2019  Fall  2019-fa     ECE     307
# 2807  2019  Fall  2019-fa     ECE     310
# 2808  2019  Fall  2019-fa     ECE     311
# 2809  2019  Fall  2019-fa     ECE     313
# 2810  2019  Fall  2019-fa     ECE     314
# 2811  2019  Fall  2019-fa     ECE     316
# 2812  2019  Fall  2019-fa     ECE     317
# 2813  2019  Fall  2019-fa     ECE     329
# 2814  2019  Fall  2019-fa     ECE     330
# 2815  2019  Fall  2019-fa     ECE     333
# 2816  2019  Fall  2019-fa     ECE     340
# 2817  2019  Fall  2019-fa     ECE     342
# 2818  2019  Fall  2019-fa     ECE     343
# 2819  2019  Fall  2019-fa     ECE     345
# 2820  2019  Fall  2019-fa     ECE     350
# 2821  2019  Fall  2019-fa     ECE     365
# ...    ...   ...      ...     ...     ...
# 2948  2019  Fall  2019-fa     ECE     561
# 2949  2019  Fall  2019-fa     ECE     562
# 2950  2019  Fall  2019-fa     ECE     563
# 2951  2019  Fall  2019-fa     ECE     564
# 2952  2019  Fall  2019-fa     ECE     565
# 2953  2019  Fall  2019-fa     ECE     566
# 2954  2019  Fall  2019-fa     ECE     567
# 2955  2019  Fall  2019-fa     ECE     568
# 2956  2019  Fall  2019-fa     ECE     569
# 2957  2019  Fall  2019-fa     ECE     570
# 2958  2019  Fall  2019-fa     ECE     571
# 2959  2019  Fall  2019-fa     ECE     572
# 2960  2019  Fall  2019-fa     ECE     573
# 2961  2019  Fall  2019-fa     ECE     574
# 2962  2019  Fall  2019-fa     ECE     576
# 2963  2019  Fall  2019-fa     ECE     577
# 2964  2019  Fall  2019-fa     ECE     579
# 2965  2019  Fall  2019-fa     ECE     580
# 2966  2019  Fall  2019-fa     ECE     581
# 2967  2019  Fall  2019-fa     ECE     582
# 2968  2019  Fall  2019-fa     ECE     584
# 2969  2019  Fall  2019-fa     ECE     585
# 2970  2019  Fall  2019-fa     ECE     586
# 2971  2019  Fall  2019-fa     ECE     588
# 2972  2019  Fall  2019-fa     ECE     590
# 2973  2019  Fall  2019-fa     ECE     594
# 2974  2019  Fall  2019-fa     ECE     596
# 2975  2019  Fall  2019-fa     ECE     597
# 2976  2019  Fall  2019-fa     ECE     598
# 2977  2019  Fall  2019-fa     ECE     599
#
#                                         Name  \
# 2792          Exploring Digital Info Technol
# 2793             Introduction to Electronics
# 2794               Introduction to Computing
# 2795                          Special Topics
# 2796              Undergraduate Open Seminar
# 2797                                 Seminar
# 2798      Electrical and Electronic Circuits
# 2799  Electrical and Electronic Circuits Lab
# 2800                Analog Signal Processing
# 2801           Analog Circuits &amp; Systems
# 2802      Computer Systems &amp; Programming
# 2803                        Individual Study
# 2804                          Special Topics
# 2805                        Photonic Devices
# 2806          Techniques for Engrg Decisions
# 2807               Digital Signal Processing
# 2808           Digital Signal Processing Lab
# 2809           Probability with Engrg Applic
# 2810          Probability in Engineering Lab
# 2811                  Ethics and Engineering
# 2812         ECE Technology &amp; Management
# 2813                      Fields and Waves I
# 2814       Power Ckts &amp; Electromechanics
# 2815                   Green Electric Energy
# 2816               Semiconductor Electronics
# 2817                     Electronic Circuits
# 2818          Electronic Circuits Laboratory
# 2819                   Design and Innovation
# 2820                     Fields and Waves II
# 2821            Data Science and Engineering
# ...                                      ...
# 2948       Detection &amp; Estimation Theory
# 2949          Advanced Digital Communication
# 2950                      Information Theory
# 2951                 Modern Light Microscopy
# 2952          Energy Dissipation Electronics
# 2953    Computational Inference and Learning
# 2954          Communication Network Analysis
# 2955      Model &amp; Cntrl Electromech Syst
# 2956              Inverse Problems in Optics
# 2957                        Nonlinear Optics
# 2958             EM Waves in Inhomogen Media
# 2959                Quantum Opto-Electronics
# 2960                    Power System Control
# 2961                           Nanophotonics
# 2962       Power System Dynm &amp; Stability
# 2963                 Advanced Antenna Theory
# 2964                Computational Complexity
# 2965          Optimiz by Vector Space Methds
# 2966               Advanced Analog IC Design
# 2967                    Physical VLSI Design
# 2968            Embedded System Verification
# 2969        MOS Device Modeling &amp; Design
# 2970          Topics in Decision and Control
# 2971           Electricity Resource Planning
# 2972              Grad Sem in Special Topics
# 2973                 Math Models of Language
# 2974                        Master's Project
# 2975                 Individual Study in ECE
# 2976                   Special Topics in ECE
# 2977                         Thesis Research
#
#                                             Description    Credit Hours  \
# 2792  Principles and processes for the development o...        3 hours.
# 2793  Introduction to selected fundamental concepts ...   1 to 3 hours.
# 2794  Introduction to digital logic, computer system...        4 hours.
# 2795  Lectures and discussions relating to new areas...   1 to 4 hours.
# 2796  Approved for both letter and S/U grading. May ...   1 to 5 hours.
# 2797  Discussions of educational programs, career op...        0 hours.
# 2798  ECE 205 is an introductory course on circuit a...        3 hours.
# 2799  Laboratory experiments in digital logic and co...        1 hours.
# 2800  Analog signal processing, with an emphasis on ...        4 hours.
# 2801  Concepts from circuit and system analysis: lin...        2 hours.
# 2802  Advanced use of LC-3 assembly language for I/O...        4 hours.
# 2803  Individual projects. Approved written applicat...        1 hours.
# 2804  Lectures and discussions relating to new areas...   1 to 4 hours.
# 2805  Introduction to active and passive photonic de...        3 hours.
# 2806  Modeling of decisions in engineering work and ...        3 hours.
# 2807  Introduction to discrete-time systems and disc...        3 hours.
# 2808  Companion laboratory for ECE 310. Prerequisite...        1 hours.
# 2809  Probability theory with applications to engine...        3 hours.
# 2810  Designed to be taken concurrently with ECE 313...        1 hours.
# 2811  Ethical issues in the practice of engineering:...        3 hours.
# 2812  Basic understanding of electrical and computer...        3 hours.
# 2813  Electromagnetic fields and waves fundamentals ...        3 hours.
# 2814  Network equivalents; power and energy fundamen...        3 hours.
# 2815  Electric power grid structure and policy; anal...        3 hours.
# 2816  Modern device electronics: semiconductor funda...        3 hours.
# 2817  Analysis and design of analog and digital elec...        3 hours.
# 2818  Companion laboratory for ECE 342. Credit is no...        1 hours.
# 2819  Students identify a suitable project, build a ...        2 hours.
# 2820  Continuation of ECE 329: radiation theory; ant...        3 hours.
# 2821  Project-based course focused on exploring and ...        3 hours.
# ...                                                 ...             ...
# 2948  Detection and estimation theory, with applicat...        4 hours.
# 2949  Digital communication systems modulation, demo...        4 hours.
# 2950  Mathematical models for channels and sources; ...        4 hours.
# 2951  Current research topics in modern light micros...        4 hours.
# 2952  Power dissipation in modern electronics, from ...        4 hours.
# 2953  Computational inference and machine learning h...        4 hours.
# 2954  Performance analysis and design of multiple-us...        4 hours.
# 2955  Fundamental electrical and mechanical laws for...        4 hours.
# 2956  Physical optics, solution of linear inverse pr...        4 hours.
# 2957  Light propagation in anisotropic crystals; sec...        4 hours.
# 2958  Electromagnetic waves in layered media; plane ...        4 hours.
# 2959  Theoretical approach to quantum mechanics and ...        4 hours.
# 2960  Energy control center functions, state estimat...        4 hours.
# 2961  Nanoscale interaction between light and semico...        4 hours.
# 2962  Detailed modeling of the synchronous machine a...        4 hours.
# 2963  Selected topics from recent engineering litera...        4 hours.
# 2964                        Same as CS 579. See CS 579.        4 hours.
# 2965  Normed, Banach, and Hilbert spaces; applicatio...        4 hours.
# 2966  Advanced topics in modern analog IC design. Em...        4 hours.
# 2967  Basic physical design requirements for VLSI; p...        4 hours.
# 2968  Examines formal analysis an synthesis approach...        4 hours.
# 2969  Techniques for characterizing gate oxide and i...        4 hours.
# 2970  Lectures and discussions related to advanced t...        4 hours.
# 2971  Techniques in electricity resource planning in...        4 hours.
# 2972  Lectures and discussions on current research a...   0 TO 2 hours.
# 2973  Mathematical models of linguistic structure an...   3 OR 4 hours.
# 2974  Individual or team projects in electrical and ...   1 TO 8 hours.
# 2975  Individual projects. Approved written applicat...   1 TO 8 hours.
# 2976  Subject offerings of new and developing areas ...   0 TO 4 hours.
# 2977    Approved for S/U grading only. May be repeated.  0 TO 16 hours.
#
#                                            Section Info  \
# 2792                                                NaN
# 2793                                                NaN
# 2794  Prerequisite: Restricted to Computer Engineeri...
# 2795                                                NaN
# 2796  Approved for both letter and S/U grading. May ...
# 2797  Approved for Letter and S/U grading. May be re...
# 2798  Credit is not given to Computer or Electrical ...
# 2799  Credit is not given to Computer or Electrical ...
# 2800  Credit is not given for both ECE 210 and ECE 2...
# 2801  Credit is not given for both ECE 211 and ECE 2...
# 2802  Prerequisite: ECE 120. Restricted to Computer ...
# 2803  Approved for both letter and S/U grading. May ...
# 2804                                                NaN
# 2805                            Prerequisite: PHYS 214.
# 2806                                                NaN
# 2807                             Prerequisite: ECE 210.
# 2808  Prerequisite: Credit or concurrent registratio...
# 2809  Same as MATH 362. Credit is not given for both...
# 2810  Prerequisite: Concurrent enrollment in ECE 313...
# 2811  Same as PHIL 316. Credit is not given for both...
# 2812                                                NaN
# 2813                             Prerequisite: ECE 210.
# 2814                             Prerequisite: ECE 210.
# 2815                  Prerequisite: ECE 205 or ECE 210.
# 2816  Prerequisite: ECE 210; PHYS 214; credit or con...
# 2817  Credit is not given for both ECE 342 and PHYS ...
# 2818  Credit is not given for both ECE 343 and PHYS ...
# 2819                                                NaN
# 2820                             Prerequisite: ECE 329.
# 2821                             Prerequisite: ECE 313.
# ...                                                 ...
# 2948                                                NaN
# 2949  4 graduate hours. No professional credit. Prer...
# 2950  Prerequisite: One of ECE 534, MATH 464, MATH 564.
# 2951   Prerequisite: One of ECE 460, MSE 405, PHYS 402.
# 2952                                                NaN
# 2953  4 graduate hours. No professional credit. Prer...
# 2954                                                NaN
# 2955                                                NaN
# 2956                             Prerequisite: ECE 460.
# 2957                                                NaN
# 2958                                                NaN
# 2959                                                NaN
# 2960                                                NaN
# 2961  Prerequisite: ECE 455 or ECE 572; ECE 487 or P...
# 2962                                                NaN
# 2963                                                NaN
# 2964                                                NaN
# 2965                                                NaN
# 2966                                                NaN
# 2967                                                NaN
# 2968                                                NaN
# 2969                                                NaN
# 2970                                                NaN
# 2971                                                NaN
# 2972  Approved for S/U grading only. May be repeated...
# 2973                                                NaN
# 2974          May be repeated to a maximum of 16 hours.
# 2975  May be repeated. Prerequisite: Consent of inst...
# 2976  May be repeated in the same or separate terms ...
# 2977    Approved for S/U grading only. May be repeated.
#
#                                       Degree Attributes
# 2792  Nat Sci & Tech - Phys Sciences, and Quantitati...
# 2793                                                NaN
# 2794                                                NaN
# 2795                                                NaN
# 2796                                                NaN
# 2797                                                NaN
# 2798                                                NaN
# 2799                                                NaN
# 2800                                                NaN
# 2801                                                NaN
# 2802                                                NaN
# 2803                                                NaN
# 2804                                                NaN
# 2805                                                NaN
# 2806                                                NaN
# 2807                                                NaN
# 2808                                                NaN
# 2809                                                NaN
# 2810                                                NaN
# 2811  Advanced Composition, and Humanities - Hist & ...
# 2812                                                NaN
# 2813                                                NaN
# 2814                                                NaN
# 2815                                                NaN
# 2816                                                NaN
# 2817                                                NaN
# 2818                                                NaN
# 2819                                                NaN
# 2820                                                NaN
# 2821                                                NaN
# ...                                                 ...
# 2948                                                NaN
# 2949                                                NaN
# 2950                                                NaN
# 2951                                                NaN
# 2952                                                NaN
# 2953                                                NaN
# 2954                                                NaN
# 2955                                                NaN
# 2956                                                NaN
# 2957                                                NaN
# 2958                                                NaN
# 2959                                                NaN
# 2960                                                NaN
# 2961                                                NaN
# 2962                                                NaN
# 2963                                                NaN
# 2964                                                NaN
# 2965                                                NaN
# 2966                                                NaN
# 2967                                                NaN
# 2968                                                NaN
# 2969                                                NaN
# 2970                                                NaN
# 2971                                                NaN
# 2972                                                NaN
# 2973                                                NaN
# 2974                                                NaN
# 2975                                                NaN
# 2976                                                NaN
# 2977                                                NaN
#
# [186 rows x 10 columns]

# %%
# There are no automatic test cases here -- you need to make sure your output is correct!
# Check over it to ensure it is what you expect to see!

# %% [markdown]
# ### Puzzle 4.2: Finding your Upper-Level Courses
#
# An "upper-level" course at Illinois is any and all courses with a number of `300` or greater.  Your major likely has many upper=level courses for you to take.
#
# Using the same idea of a conditional, you will replace the logic of `==` (*which means "exactly equal to"*) with `>=` (*which means greater than or equal to*).  Write a conditional, using `mydf`, to find **all of the upper-level courses in your major** and store it in `mydf_upper_level`.

# %%
mydf_upper_level = mydf[mydf["Number"] >= 300]
mydf_upper_level
# Out:
#       Year  Term YearTerm Subject  Number  \
# 2805  2019  Fall  2019-fa     ECE     304
# 2806  2019  Fall  2019-fa     ECE     307
# 2807  2019  Fall  2019-fa     ECE     310
# 2808  2019  Fall  2019-fa     ECE     311
# 2809  2019  Fall  2019-fa     ECE     313
# 2810  2019  Fall  2019-fa     ECE     314
# 2811  2019  Fall  2019-fa     ECE     316
# 2812  2019  Fall  2019-fa     ECE     317
# 2813  2019  Fall  2019-fa     ECE     329
# 2814  2019  Fall  2019-fa     ECE     330
# 2815  2019  Fall  2019-fa     ECE     333
# 2816  2019  Fall  2019-fa     ECE     340
# 2817  2019  Fall  2019-fa     ECE     342
# 2818  2019  Fall  2019-fa     ECE     343
# 2819  2019  Fall  2019-fa     ECE     345
# 2820  2019  Fall  2019-fa     ECE     350
# 2821  2019  Fall  2019-fa     ECE     365
# 2822  2019  Fall  2019-fa     ECE     374
# 2823  2019  Fall  2019-fa     ECE     380
# 2824  2019  Fall  2019-fa     ECE     385
# 2825  2019  Fall  2019-fa     ECE     391
# 2826  2019  Fall  2019-fa     ECE     395
# 2827  2019  Fall  2019-fa     ECE     396
# 2828  2019  Fall  2019-fa     ECE     397
# 2829  2019  Fall  2019-fa     ECE     398
# 2830  2019  Fall  2019-fa     ECE     399
# 2831  2019  Fall  2019-fa     ECE     401
# 2832  2019  Fall  2019-fa     ECE     402
# 2833  2019  Fall  2019-fa     ECE     403
# 2834  2019  Fall  2019-fa     ECE     408
# ...    ...   ...      ...     ...     ...
# 2948  2019  Fall  2019-fa     ECE     561
# 2949  2019  Fall  2019-fa     ECE     562
# 2950  2019  Fall  2019-fa     ECE     563
# 2951  2019  Fall  2019-fa     ECE     564
# 2952  2019  Fall  2019-fa     ECE     565
# 2953  2019  Fall  2019-fa     ECE     566
# 2954  2019  Fall  2019-fa     ECE     567
# 2955  2019  Fall  2019-fa     ECE     568
# 2956  2019  Fall  2019-fa     ECE     569
# 2957  2019  Fall  2019-fa     ECE     570
# 2958  2019  Fall  2019-fa     ECE     571
# 2959  2019  Fall  2019-fa     ECE     572
# 2960  2019  Fall  2019-fa     ECE     573
# 2961  2019  Fall  2019-fa     ECE     574
# 2962  2019  Fall  2019-fa     ECE     576
# 2963  2019  Fall  2019-fa     ECE     577
# 2964  2019  Fall  2019-fa     ECE     579
# 2965  2019  Fall  2019-fa     ECE     580
# 2966  2019  Fall  2019-fa     ECE     581
# 2967  2019  Fall  2019-fa     ECE     582
# 2968  2019  Fall  2019-fa     ECE     584
# 2969  2019  Fall  2019-fa     ECE     585
# 2970  2019  Fall  2019-fa     ECE     586
# 2971  2019  Fall  2019-fa     ECE     588
# 2972  2019  Fall  2019-fa     ECE     590
# 2973  2019  Fall  2019-fa     ECE     594
# 2974  2019  Fall  2019-fa     ECE     596
# 2975  2019  Fall  2019-fa     ECE     597
# 2976  2019  Fall  2019-fa     ECE     598
# 2977  2019  Fall  2019-fa     ECE     599
#
#                                                    Name  \
# 2805                                   Photonic Devices
# 2806                     Techniques for Engrg Decisions
# 2807                          Digital Signal Processing
# 2808                      Digital Signal Processing Lab
# 2809                      Probability with Engrg Applic
# 2810                     Probability in Engineering Lab
# 2811                             Ethics and Engineering
# 2812                    ECE Technology &amp; Management
# 2813                                 Fields and Waves I
# 2814                  Power Ckts &amp; Electromechanics
# 2815                              Green Electric Energy
# 2816                          Semiconductor Electronics
# 2817                                Electronic Circuits
# 2818                     Electronic Circuits Laboratory
# 2819                              Design and Innovation
# 2820                                Fields and Waves II
# 2821                       Data Science and Engineering
# 2822  Introduction to Algorithms &amp; Models of Com...
# 2823                                 Biomedical Imaging
# 2824                         Digital Systems Laboratory
# 2825                       Computer Systems Engineering
# 2826                      Advanced Digital Projects Lab
# 2827                                     Honors Project
# 2828                            Individual Study in ECE
# 2829                              Special Topics in ECE
# 2830                                     Honors Seminar
# 2831                          Signal and Image Analysis
# 2832                         Electronic Music Synthesis
# 2833                                  Audio Engineering
# 2834                       Applied Parallel Programming
# ...                                                 ...
# 2948                  Detection &amp; Estimation Theory
# 2949                     Advanced Digital Communication
# 2950                                 Information Theory
# 2951                            Modern Light Microscopy
# 2952                     Energy Dissipation Electronics
# 2953               Computational Inference and Learning
# 2954                     Communication Network Analysis
# 2955                 Model &amp; Cntrl Electromech Syst
# 2956                         Inverse Problems in Optics
# 2957                                   Nonlinear Optics
# 2958                        EM Waves in Inhomogen Media
# 2959                           Quantum Opto-Electronics
# 2960                               Power System Control
# 2961                                      Nanophotonics
# 2962                  Power System Dynm &amp; Stability
# 2963                            Advanced Antenna Theory
# 2964                           Computational Complexity
# 2965                     Optimiz by Vector Space Methds
# 2966                          Advanced Analog IC Design
# 2967                               Physical VLSI Design
# 2968                       Embedded System Verification
# 2969                   MOS Device Modeling &amp; Design
# 2970                     Topics in Decision and Control
# 2971                      Electricity Resource Planning
# 2972                         Grad Sem in Special Topics
# 2973                            Math Models of Language
# 2974                                   Master's Project
# 2975                            Individual Study in ECE
# 2976                              Special Topics in ECE
# 2977                                    Thesis Research
#
#                                             Description    Credit Hours  \
# 2805  Introduction to active and passive photonic de...        3 hours.
# 2806  Modeling of decisions in engineering work and ...        3 hours.
# 2807  Introduction to discrete-time systems and disc...        3 hours.
# 2808  Companion laboratory for ECE 310. Prerequisite...        1 hours.
# 2809  Probability theory with applications to engine...        3 hours.
# 2810  Designed to be taken concurrently with ECE 313...        1 hours.
# 2811  Ethical issues in the practice of engineering:...        3 hours.
# 2812  Basic understanding of electrical and computer...        3 hours.
# 2813  Electromagnetic fields and waves fundamentals ...        3 hours.
# 2814  Network equivalents; power and energy fundamen...        3 hours.
# 2815  Electric power grid structure and policy; anal...        3 hours.
# 2816  Modern device electronics: semiconductor funda...        3 hours.
# 2817  Analysis and design of analog and digital elec...        3 hours.
# 2818  Companion laboratory for ECE 342. Credit is no...        1 hours.
# 2819  Students identify a suitable project, build a ...        2 hours.
# 2820  Continuation of ECE 329: radiation theory; ant...        3 hours.
# 2821  Project-based course focused on exploring and ...        3 hours.
# 2822                        Same as CS 374. See CS 374.        4 hours.
# 2823  Physics and engineering principles associated ...        3 hours.
# 2824  Design, build, and test digital systems using ...        3 hours.
# 2825  Concepts and abstractions central to the devel...        4 hours.
# 2826  Planning, designing, executing, and documentin...   2 OR 3 hours.
# 2827  Special project or reading course for James Sc...   1 TO 4 hours.
# 2828  Individual Projects. Approved for both letter ...   0 TO 4 hours.
# 2829  Subject offerings of new and developing areas ...   0 TO 4 hours.
# 2830  Special lecture sequences or discussion groups...   1 TO 4 hours.
# 2831  An introduction to signal analysis and process...        4 hours.
# 2832  Historical survey of electronic and computer m...        3 hours.
# 2833  Resonance and wave phenomena; Acoustics of roo...        3 hours.
# 2834  Parallel programming with emphasis on developi...        4 hours.
# ...                                                 ...             ...
# 2948  Detection and estimation theory, with applicat...        4 hours.
# 2949  Digital communication systems modulation, demo...        4 hours.
# 2950  Mathematical models for channels and sources; ...        4 hours.
# 2951  Current research topics in modern light micros...        4 hours.
# 2952  Power dissipation in modern electronics, from ...        4 hours.
# 2953  Computational inference and machine learning h...        4 hours.
# 2954  Performance analysis and design of multiple-us...        4 hours.
# 2955  Fundamental electrical and mechanical laws for...        4 hours.
# 2956  Physical optics, solution of linear inverse pr...        4 hours.
# 2957  Light propagation in anisotropic crystals; sec...        4 hours.
# 2958  Electromagnetic waves in layered media; plane ...        4 hours.
# 2959  Theoretical approach to quantum mechanics and ...        4 hours.
# 2960  Energy control center functions, state estimat...        4 hours.
# 2961  Nanoscale interaction between light and semico...        4 hours.
# 2962  Detailed modeling of the synchronous machine a...        4 hours.
# 2963  Selected topics from recent engineering litera...        4 hours.
# 2964                        Same as CS 579. See CS 579.        4 hours.
# 2965  Normed, Banach, and Hilbert spaces; applicatio...        4 hours.
# 2966  Advanced topics in modern analog IC design. Em...        4 hours.
# 2967  Basic physical design requirements for VLSI; p...        4 hours.
# 2968  Examines formal analysis an synthesis approach...        4 hours.
# 2969  Techniques for characterizing gate oxide and i...        4 hours.
# 2970  Lectures and discussions related to advanced t...        4 hours.
# 2971  Techniques in electricity resource planning in...        4 hours.
# 2972  Lectures and discussions on current research a...   0 TO 2 hours.
# 2973  Mathematical models of linguistic structure an...   3 OR 4 hours.
# 2974  Individual or team projects in electrical and ...   1 TO 8 hours.
# 2975  Individual projects. Approved written applicat...   1 TO 8 hours.
# 2976  Subject offerings of new and developing areas ...   0 TO 4 hours.
# 2977    Approved for S/U grading only. May be repeated.  0 TO 16 hours.
#
#                                            Section Info  \
# 2805                            Prerequisite: PHYS 214.
# 2806                                                NaN
# 2807                             Prerequisite: ECE 210.
# 2808  Prerequisite: Credit or concurrent registratio...
# 2809  Same as MATH 362. Credit is not given for both...
# 2810  Prerequisite: Concurrent enrollment in ECE 313...
# 2811  Same as PHIL 316. Credit is not given for both...
# 2812                                                NaN
# 2813                             Prerequisite: ECE 210.
# 2814                             Prerequisite: ECE 210.
# 2815                  Prerequisite: ECE 205 or ECE 210.
# 2816  Prerequisite: ECE 210; PHYS 214; credit or con...
# 2817  Credit is not given for both ECE 342 and PHYS ...
# 2818  Credit is not given for both ECE 343 and PHYS ...
# 2819                                                NaN
# 2820                             Prerequisite: ECE 329.
# 2821                             Prerequisite: ECE 313.
# 2822                        Same as CS 374. See CS 374.
# 2823  Same as BIOE 380. Prerequisite: MATH 285 or MA...
# 2824                 Prerequisite: ECE 110 and ECE 220.
# 2825  Credit is not given for both ECE 391 and CS 24...
# 2826  May be repeated in separate terms. Prerequisit...
# 2827  May be repeated. Prerequisite: Consent of inst...
# 2828  Approved for both letter and S/U grading. May ...
# 2829                                                NaN
# 2830                                                NaN
# 2831                                                NaN
# 2832  3 undergraduate hours. 3 graduate hours. Prere...
# 2833                                                NaN
# 2834  Same as CS 483 and CSE 408. 4 undergraduate ho...
# ...                                                 ...
# 2948                                                NaN
# 2949  4 graduate hours. No professional credit. Prer...
# 2950  Prerequisite: One of ECE 534, MATH 464, MATH 564.
# 2951   Prerequisite: One of ECE 460, MSE 405, PHYS 402.
# 2952                                                NaN
# 2953  4 graduate hours. No professional credit. Prer...
# 2954                                                NaN
# 2955                                                NaN
# 2956                             Prerequisite: ECE 460.
# 2957                                                NaN
# 2958                                                NaN
# 2959                                                NaN
# 2960                                                NaN
# 2961  Prerequisite: ECE 455 or ECE 572; ECE 487 or P...
# 2962                                                NaN
# 2963                                                NaN
# 2964                                                NaN
# 2965                                                NaN
# 2966                                                NaN
# 2967                                                NaN
# 2968                                                NaN
# 2969                                                NaN
# 2970                                                NaN
# 2971                                                NaN
# 2972  Approved for S/U grading only. May be repeated...
# 2973                                                NaN
# 2974          May be repeated to a maximum of 16 hours.
# 2975  May be repeated. Prerequisite: Consent of inst...
# 2976  May be repeated in the same or separate terms ...
# 2977    Approved for S/U grading only. May be repeated.
#
#                                       Degree Attributes
# 2805                                                NaN
# 2806                                                NaN
# 2807                                                NaN
# 2808                                                NaN
# 2809                                                NaN
# 2810                                                NaN
# 2811  Advanced Composition, and Humanities - Hist & ...
# 2812                                                NaN
# 2813                                                NaN
# 2814                                                NaN
# 2815                                                NaN
# 2816                                                NaN
# 2817                                                NaN
# 2818                                                NaN
# 2819                                                NaN
# 2820                                                NaN
# 2821                                                NaN
# 2822                                                NaN
# 2823                                                NaN
# 2824                                                NaN
# 2825                                                NaN
# 2826                                                NaN
# 2827                                                NaN
# 2828                                                NaN
# 2829                                                NaN
# 2830                                                NaN
# 2831                                                NaN
# 2832                                                NaN
# 2833                                                NaN
# 2834                                                NaN
# ...                                                 ...
# 2948                                                NaN
# 2949                                                NaN
# 2950                                                NaN
# 2951                                                NaN
# 2952                                                NaN
# 2953                                                NaN
# 2954                                                NaN
# 2955                                                NaN
# 2956                                                NaN
# 2957                                                NaN
# 2958                                                NaN
# 2959                                                NaN
# 2960                                                NaN
# 2961                                                NaN
# 2962                                                NaN
# 2963                                                NaN
# 2964                                                NaN
# 2965                                                NaN
# 2966                                                NaN
# 2967                                                NaN
# 2968                                                NaN
# 2969                                                NaN
# 2970                                                NaN
# 2971                                                NaN
# 2972                                                NaN
# 2973                                                NaN
# 2974                                                NaN
# 2975                                                NaN
# 2976                                                NaN
# 2977                                                NaN
#
# [173 rows x 10 columns]

# %%
# There are no automatic test cases here -- you need to make sure your output is correct!
# Check over it to ensure it is what you expect to see!

# %% [markdown]
# ## Submit Your Work!
#
# You're almost done -- congratulations!
#
# You need to do two more things:
#
# 1. Save your work.  To do this, create a **notebook checkpoint** by using the menu within the notebook to go **File -> Save and Checkpoint**
#
# 2. Choose `File` and then `Close and Halt` from this notebook.
#
# 3. Choose `Quit` on the main notebook webpage.
#
# 4. Return to your command line and follow the directions on the Data Science Discovery page on how to use git to turn this notebook into the course!
